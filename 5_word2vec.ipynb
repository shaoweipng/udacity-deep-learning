# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
print(data[:10])
print(count[:10])
print(dictionary.items()[:10])
print(reverse_dictionary.items()[:10])
# Out:
# [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]
# [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764), ('in', 372201), ('a', 325873), ('to', 316376), ('zero', 264975), ('nine', 250430)]
# [('fawn', 45848), ('homomorphism', 9648), ('nordisk', 39343), ('nunnery', 36075), ('chthonic', 33554), ('sowell', 40562), ('sonja', 38175), ('showa', 32906), ('woods', 6263), ('hsv', 44222)]
# [(0, 'UNK'), (1, 'the'), (2, 'of'), (3, 'and'), (4, 'one'), (5, 'in'), (6, 'a'), (7, 'to'), (8, 'zero'), (9, 'nine')]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:32]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=16, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(16)])
    
for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 1
    batch, labels = generate_batch(batch_size=16, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(16)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'UNK', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term', 'of', 'of', 'abuse', 'abuse', 'first', 'first', 'used', 'used']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'of', 'a', 'term', 'abuse', 'of', 'first', 'abuse', 'used', 'first', 'against']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a', 'term', 'term', 'term', 'term', 'of', 'of', 'of', 'of']
#     labels: ['originated', 'a', 'anarchism', 'term', 'term', 'originated', 'as', 'of', 'a', 'abuse', 'as', 'of', 'a', 'term', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['as', 'as', 'a', 'a', 'term', 'term', 'of', 'of', 'abuse', 'abuse', 'first', 'first', 'used', 'used', 'against', 'against']
#     labels: ['originated', 'a', 'term', 'as', 'a', 'of', 'abuse', 'term', 'of', 'first', 'used', 'abuse', 'against', 'first', 'used', 'early']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['a', 'a', 'a', 'a', 'term', 'term', 'term', 'term', 'of', 'of', 'of', 'of', 'abuse', 'abuse', 'abuse', 'abuse']
#     labels: ['term', 'originated', 'as', 'of', 'of', 'a', 'as', 'abuse', 'a', 'term', 'first', 'abuse', 'used', 'of', 'first', 'term']

# %% [markdown]
# Note: the labels is a sliding random value of the word surrounding the words of the batch.

# %%
print(batch)
print(labels)
# Out:
# [   6    6    6    6  195  195  195  195    2    2    2    2 3137 3137 3137
#  3137]
# [[ 195]
#  [3084]
#  [  12]
#  [   2]
#  [   2]
#  [   6]
#  [  12]
#  [3137]
#  [   6]
#  [ 195]
#  [  46]
#  [3137]
#  [  59]
#  [   2]
#  [  46]
#  [ 195]]

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.221954
# Nearest to between: brock, configurable, draw, triads, monoxide, allusions, salam, occupies,
# Nearest to would: awareness, painless, freeciv, guanine, gyula, uncensored, soriano, parsed,
# Nearest to nine: galli, ethno, pilsener, straining, cezanne, impeded, amalgamation, sanger,
# Nearest to only: cipher, benevolent, yoko, drexler, figurehead, wiring, workings, padma,
# Nearest to all: biscay, inductees, disestablishment, playfulness, archetypes, nozick, stopover, harry,
# Nearest to there: unleashed, inexperience, uncredited, century, alphonso, asimov, frequently, reproduced,
# Nearest to not: vaduz, eligible, aelian, juggling, oe, partement, enveloped, henrik,
# Nearest to was: embargo, carla, mazzola, uniquely, steinmetz, chill, tower, ancestor,
# Nearest to into: modesty, islamic, recalled, kirkwood, odi, girls, nikola, enjoy,
# Nearest to however: lamorna, telegraphic, incredibly, ongoing, liberties, aiken, caspar, terminate,
# Nearest to some: clockless, sulfides, labouring, cassel, germinal, svetlana, childe, unsound,
# Nearest to when: devonian, mysticeti, advaita, buy, creator, fouled, conclave, illyricum,
# Nearest to it: jeopardy, gere, arguing, bottlers, prophesies, hexagram, acrobatics, ellipsis,
# Nearest to during: rebounding, ligase, seminole, wop, grips, xuan, perot, declaration,
# Nearest to used: stanford, plantae, rectal, deduced, patterns, bots, cadbury, pasadena,
# Nearest to also: oscar, philosophies, lords, transcriptions, nlm, stemmed, nair, pergamum,
# Average loss at step 2000: 4.356393
# Average loss at step 4000: 3.864936
# Average loss at step 6000: 3.791488
# Average loss at step 8000: 3.687659
# Average loss at step 10000: 3.620755
# Nearest to between: configurable, unsigned, unam, danville, following, executioner, troughs, triads,
# Nearest to would: can, may, will, occupation, hawthorne, painless, soriano, could,
# Nearest to nine: eight, seven, five, six, three, four, two, zero,
# Nearest to only: finnish, hl, octopussy, yoko, parser, buses, alleviation, homemade,
# Nearest to all: teutoburg, these, protectors, greco, biscay, nozick, playfulness, militarist,
# Nearest to there: it, they, he, never, often, frequently, she, which,
# Nearest to not: they, vaduz, neat, grappelli, horses, it, to, mast,
# Nearest to was: is, had, has, by, were, dixon, be, vanities,
# Nearest to into: with, girls, professional, odi, assurance, striping, from, modesty,
# Nearest to however: terminate, ongoing, citrus, aiken, mannerisms, pubic, unified, sources,
# Nearest to some: many, tolerable, gesellschaft, beef, out, aedile, clockless, chari,
# Nearest to when: werewolves, were, devonian, after, creator, was, avenged, where,
# Nearest to it: he, there, this, that, which, not, harmala, sometimes,
# Nearest to during: after, rebounding, mihdhar, dh, nitroglycerin, from, rump, tubulin,
# Nearest to used: nevertheless, lengthened, cycles, plantae, elsewhere, found, receive, sor,
# Nearest to also: which, lords, malaysian, yoke, transcriptions, often, absurdist, still,
# Average loss at step 12000: 3.598617
# Average loss at step 14000: 3.570190
# Average loss at step 16000: 3.410909
# Average loss at step 18000: 3.460372
# Average loss at step 20000: 3.533946
# Nearest to between: from, configurable, into, following, in, headphones, unsigned, over,
# Nearest to would: can, may, could, will, should, might, must, to,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to only: generosity, hl, buses, algardi, rstenberg, global, it, octopussy,
# Nearest to all: these, teutoburg, those, many, some, nozick, several, intervene,
# Nearest to there: it, they, he, which, often, however, still, frequently,
# Nearest to not: grappelli, they, to, vaduz, also, usually, it, jamaica,
# Nearest to was: is, were, has, had, became, be, when, are,
# Nearest to into: from, with, striping, between, over, odi, cardiff, by,
# Nearest to however: but, there, that, connecting, pubic, terminate, gyeonggi, jeet,
# Nearest to some: many, these, several, tolerable, other, all, any, their,
# Nearest to when: after, where, werewolves, was, dogmatic, imprecise, karlheinz, if,
# Nearest to it: he, there, this, they, which, she, himself, not,
# Nearest to during: after, gateless, geller, newbies, mihdhar, rebounding, speleological, upper,
# Nearest to used: found, described, known, included, elsewhere, nevertheless, patent, restricted,
# Nearest to also: which, lords, still, now, often, malaysian, not, generally,
# Average loss at step 22000: 3.503826
# Average loss at step 24000: 3.488342
# Average loss at step 26000: 3.479754
# Average loss at step 28000: 3.482531
# Average loss at step 30000: 3.504507
# Nearest to between: with, into, configurable, over, following, unsigned, in, bravely,
# Nearest to would: can, may, could, will, should, might, must, to,
# Nearest to nine: eight, seven, six, five, four, three, zero, births,
# Nearest to only: bankers, until, promulgation, ayckbourn, usually, shrouded, buses, imperfective,
# Nearest to all: these, some, those, teutoburg, protectors, nozick, many, several,
# Nearest to there: they, it, he, often, still, she, usually, which,
# Nearest to not: they, grappelli, still, it, disinformation, we, vaduz, also,
# Nearest to was: is, had, has, were, became, when, been, reordering,
# Nearest to into: from, between, striping, over, odi, stansted, animalia, with,
# Nearest to however: but, though, that, accompanies, and, sources, masturbation, maximization,
# Nearest to some: many, these, several, any, all, tolerable, other, designing,
# Nearest to when: where, after, if, before, werewolves, was, during, while,
# Nearest to it: he, there, this, she, which, they, also, never,
# Nearest to during: after, in, before, at, when, roman, newbies, from,
# Nearest to used: known, found, described, included, elsewhere, constans, cycles, sor,
# Nearest to also: which, often, still, sometimes, usually, it, now, generally,
# Average loss at step 32000: 3.500199
# Average loss at step 34000: 3.490481
# Average loss at step 36000: 3.454124
# Average loss at step 38000: 3.306445
# Average loss at step 40000: 3.431844
# Nearest to between: into, over, with, bravely, in, unsigned, deprecated, nico,
# Nearest to would: will, can, could, may, should, might, must, did,
# Nearest to nine: eight, seven, six, five, four, zero, three, births,
# Nearest to only: until, reintroduced, always, not, bankers, even, shrouded, divided,
# Nearest to all: these, wolfe, several, both, rainy, many, playfulness, mithras,
# Nearest to there: it, they, still, he, she, usually, now, which,
# Nearest to not: grappelli, they, it, usually, generally, still, also, vaduz,
# Nearest to was: is, has, were, became, had, be, walras, been,
# Nearest to into: from, between, over, striping, animalia, around, through, cardiff,
# Nearest to however: but, though, that, although, thracians, sources, they, since,
# Nearest to some: many, these, several, any, tolerable, trondheim, refuses, certain,
# Nearest to when: where, if, before, after, while, by, for, werewolves,
# Nearest to it: he, there, she, this, they, which, not, usually,
# Nearest to during: after, before, at, in, when, within, of, until,
# Nearest to used: found, known, referred, included, described, mentioned, held, elsewhere,
# Nearest to also: often, already, which, usually, sometimes, now, still, generally,
# Average loss at step 42000: 3.437350
# Average loss at step 44000: 3.451792
# Average loss at step 46000: 3.452508
# Average loss at step 48000: 3.349569
# Average loss at step 50000: 3.379527
# Nearest to between: into, with, over, from, unsigned, bravely, chronicled, configurable,
# Nearest to would: will, can, may, could, should, might, must, did,
# Nearest to nine: eight, seven, six, four, three, five, zero, two,
# Nearest to only: until, either, reintroduced, always, skilling, ameliorate, shrouded, not,
# Nearest to all: every, some, these, many, both, mudd, those, rainy,
# Nearest to there: they, it, still, he, she, now, these, we,
# Nearest to not: generally, grappelli, usually, they, neat, also, disinformation, vaduz,
# Nearest to was: is, has, became, were, had, be, being, by,
# Nearest to into: from, between, through, striping, around, over, stansted, odi,
# Nearest to however: but, that, although, though, while, where, since, golan,
# Nearest to some: many, several, these, both, the, most, trondheim, all,
# Nearest to when: if, after, before, while, where, but, although, during,
# Nearest to it: he, there, she, this, they, often, which, lice,
# Nearest to during: after, at, before, in, from, within, when, speleological,
# Nearest to used: known, referred, described, found, required, viewed, written, mentioned,
# Nearest to also: which, often, now, already, still, sometimes, generally, usually,
# Average loss at step 52000: 3.436823
# Average loss at step 54000: 3.430516
# Average loss at step 56000: 3.438251
# Average loss at step 58000: 3.394093
# Average loss at step 60000: 3.395915
# Nearest to between: with, in, among, over, into, qe, within, unsigned,
# Nearest to would: will, could, can, may, must, might, should, did,
# Nearest to nine: eight, seven, six, four, five, three, zero, one,
# Nearest to only: until, always, reintroduced, either, even, animaniacs, usually, just,
# Nearest to all: both, those, these, some, various, many, every, mtu,
# Nearest to there: they, it, still, she, now, he, we, this,
# Nearest to not: usually, grappelli, generally, now, vaduz, normally, still, they,
# Nearest to was: is, had, were, became, has, been, being, when,
# Nearest to into: from, through, over, striping, around, between, within, odi,
# Nearest to however: but, although, though, that, which, when, where, while,
# Nearest to some: many, several, these, any, trondheim, all, certain, most,
# Nearest to when: if, after, before, while, where, though, although, because,
# Nearest to it: he, she, there, this, they, which, often, still,
# Nearest to during: after, before, in, at, when, within, until, speleological,
# Nearest to used: known, described, found, referred, included, mentioned, required, seen,
# Nearest to also: now, often, still, sometimes, actually, usually, which, already,
# Average loss at step 62000: 3.237978
# Average loss at step 64000: 3.254204
# Average loss at step 66000: 3.406324
# Average loss at step 68000: 3.395109
# Average loss at step 70000: 3.360016
# Nearest to between: with, within, among, over, in, into, unsigned, from,
# Nearest to would: will, could, can, may, might, must, should, cannot,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to only: until, either, even, warped, still, always, hit, animaniacs,
# Nearest to all: many, some, every, various, these, families, both, several,
# Nearest to there: they, it, still, we, she, now, he, often,
# Nearest to not: usually, now, generally, still, normally, vaduz, grappelli, circe,
# Nearest to was: is, has, were, became, had, been, travolta, desertification,
# Nearest to into: through, from, striping, around, between, across, towards, within,
# Nearest to however: but, although, though, that, where, while, which, and,
# Nearest to some: many, several, these, all, both, any, most, certain,
# Nearest to when: if, while, before, after, where, because, though, weisstein,
# Nearest to it: he, she, there, this, they, still, we, usually,
# Nearest to during: after, before, in, until, at, through, outside, grazing,
# Nearest to used: known, described, found, referred, mentioned, included, available, written,
# Nearest to also: often, now, still, which, sometimes, usually, generally, never,
# Average loss at step 72000: 3.372035
# Average loss at step 74000: 3.346163
# Average loss at step 76000: 3.313801
# Average loss at step 78000: 3.351984
# Average loss at step 80000: 3.383837
# Nearest to between: among, within, with, in, over, unsigned, qe, ghazi,
# Nearest to would: will, could, can, may, must, might, should, cannot,
# Nearest to nine: eight, seven, six, four, five, three, zero, births,
# Nearest to only: until, either, drilled, reintroduced, always, last, harwood, first,
# Nearest to all: both, every, various, many, several, mtu, families, any,
# Nearest to there: they, it, still, he, she, often, believed, we,
# Nearest to not: still, generally, usually, normally, often, now, shlomo, they,
# Nearest to was: is, became, were, has, had, been, being, during,
# Nearest to into: through, from, striping, within, across, towards, back, around,
# Nearest to however: although, but, that, though, while, when, where, towards,
# Nearest to some: many, several, these, both, various, most, any, numerous,
# Nearest to when: after, if, before, while, where, though, although, during,
# Nearest to it: he, she, there, this, they, still, we, fisa,
# Nearest to during: after, in, before, when, until, through, despite, including,
# Nearest to used: known, referred, described, found, mentioned, written, available, seen,
# Nearest to also: often, now, already, still, which, sometimes, occasionally, usually,
# Average loss at step 82000: 3.407537
# Average loss at step 84000: 3.407460
# Average loss at step 86000: 3.386767
# Average loss at step 88000: 3.352058
# Average loss at step 90000: 3.364754
# Nearest to between: with, within, among, in, over, unsigned, from, into,
# Nearest to would: will, could, might, can, may, must, should, did,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to only: either, no, until, reintroduced, even, animaniacs, drilled, looters,
# Nearest to all: both, many, every, some, several, various, these, families,
# Nearest to there: they, it, still, he, she, we, now, believed,
# Nearest to not: still, also, we, ultimately, now, generally, gunmen, shlomo,
# Nearest to was: is, had, became, were, has, be, been, being,
# Nearest to into: through, from, striping, around, within, across, over, out,
# Nearest to however: although, but, that, though, occurs, since, while, which,
# Nearest to some: many, several, these, any, all, most, both, those,
# Nearest to when: if, while, after, before, where, though, although, since,
# Nearest to it: he, there, she, they, this, we, still, itself,
# Nearest to during: after, in, through, under, before, until, although, from,
# Nearest to used: known, referred, described, found, seen, mentioned, available, shown,
# Nearest to also: often, occasionally, now, already, which, never, still, sometimes,
# Average loss at step 92000: 3.394947
# Average loss at step 94000: 3.254780
# Average loss at step 96000: 3.352545
# Average loss at step 98000: 3.243668
# Average loss at step 100000: 3.353534
# Nearest to between: among, with, over, within, unsigned, in, glottis, around,
# Nearest to would: will, could, can, might, may, must, should, cannot,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to only: until, either, reintroduced, even, always, still, animaniacs, severely,
# Nearest to all: both, various, every, these, many, playfulness, several, some,
# Nearest to there: they, he, it, still, we, she, sometimes, often,
# Nearest to not: ultimately, still, generally, almost, never, they, now, usually,
# Nearest to was: is, became, had, were, has, walras, been, although,
# Nearest to into: through, from, striping, within, around, across, towards, back,
# Nearest to however: although, but, that, though, which, where, while, and,
# Nearest to some: many, several, any, these, certain, numerous, those, various,
# Nearest to when: if, while, before, after, although, where, though, because,
# Nearest to it: he, she, there, this, they, which, we, often,
# Nearest to during: in, after, through, until, under, including, at, before,
# Nearest to used: referred, known, found, described, sold, mentioned, seen, held,
# Nearest to also: never, now, actually, occasionally, still, often, sometimes, below,

# %%
print(final_embeddings[0])
# Out:
# [ 0.02948845  0.0212285  -0.02770381  0.06864311  0.04597336 -0.05549842
#  -0.03648649 -0.12933874  0.08792627 -0.03749854  0.0106     -0.12737407
#   0.09247494  0.02230972  0.04422116 -0.10763285  0.12357711 -0.11579036
#   0.11500655 -0.03021723  0.10313877 -0.02167209 -0.10909611 -0.13293831
#  -0.07778085 -0.0646819   0.13738063 -0.15710461 -0.2627022  -0.10834484
#   0.09798954 -0.05671227  0.01879465 -0.14402667 -0.06834499 -0.05760885
#  -0.02238116 -0.14756006  0.00454663  0.11915632 -0.19109784  0.16262962
#  -0.02050367 -0.11160885  0.00471326  0.03055284  0.03798344  0.05494301
#  -0.00409947 -0.04542934  0.01164734 -0.0376456  -0.05146192 -0.14712964
#  -0.04046596 -0.03236024  0.03344017 -0.11671301 -0.04610525  0.14215811
#   0.02368362  0.07565978  0.05546194 -0.0517499  -0.13311119 -0.03355389
#  -0.09916421  0.20775624  0.08612103  0.00855906  0.04810658 -0.02948884
#  -0.04070747 -0.02729909  0.03194188  0.05795127 -0.06473397  0.01058012
#   0.05752429  0.09174853 -0.00475266  0.00055641 -0.00130699  0.10601953
#  -0.04820688 -0.05385605  0.0685261  -0.02745217  0.05125122 -0.1744206
#   0.11464385 -0.07418804 -0.15766226  0.07482743  0.05390682 -0.06941888
#   0.05948     0.06179734  0.06376965 -0.06365677  0.10860081 -0.07180624
#  -0.04665774  0.22908382  0.23907712 -0.06009143 -0.01707729  0.08914876
#   0.16885696 -0.06467678 -0.07488271 -0.02179942  0.06428526  0.02238482
#   0.01906934  0.11401243  0.04450637  0.0552204  -0.04714488  0.00260982
#  -0.05560434  0.00291842 -0.02862457 -0.05106818 -0.08948486 -0.03249595
#  -0.10756842  0.00534443]

# %%
print(np.sum(np.square(final_embeddings[0])))
# Out:
# 1.0

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    # just for testing
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    # iterate to the next buffer
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
  data_index = 0
  batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
  print('\nwith bag_window = %d:' % (bag_window))  
  print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
###skip_window = 1 # How many words to consider left and right.
###num_skips = 2 # How many times to reuse an input to generate a label.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embeds, 1),
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.962677
# Nearest to called: publications, ba, lester, amazigh, alexandria, cricketer, juridical, halls,
# Nearest to was: johnson, initiation, pertaining, hop, monde, isidore, fingertips, isadora,
# Nearest to has: clinging, ztt, residential, obtained, divx, battista, tornadoes, funeral,
# Nearest to their: rains, opaque, gateless, senior, solanaceae, matth, welwyn, arco,
# Nearest to were: galway, echidna, unexplained, ephraim, fateh, contemporaries, pynchon, albany,
# Nearest to th: ssl, yoannis, diminishes, biopsy, transcripts, bowstring, atrium, interstate,
# Nearest to some: incremental, greedy, khosrau, bahasa, stereotypes, paged, prophesied, octave,
# Nearest to or: raids, hashing, inflation, makeover, immolation, jamison, chubut, permit,
# Nearest to will: unter, favourable, separators, museu, favorites, teeming, hendrik, carpathians,
# Nearest to from: fluctuation, prescott, milligrams, differentiates, clue, tautologies, guise, chopping,
# Nearest to on: edged, truetype, hitachi, vaccinium, monody, feng, sympathizers, seduced,
# Nearest to of: loonie, springfield, itosu, epimenides, need, saws, disfigured, doctorow,
# Nearest to states: shahada, cory, ceramics, weblogs, deal, clergymen, denounced, goldsmith,
# Nearest to between: alloy, lcms, porfirio, manuel, fick, hours, sprinkled, mackaye,
# Nearest to been: borough, bistable, execution, germany, lisa, burrito, reigned, experiment,
# Nearest to world: smallest, tisdall, ahaz, paired, robbery, curtailed, mozambique, mizrahi,
# Average loss at step 2000: 5.569420
# Average loss at step 4000: 4.309811
# Average loss at step 6000: 3.891072
# Average loss at step 8000: 3.621025
# Average loss at step 10000: 3.530783
# Nearest to called: considered, beatboxing, olives, booms, used, backdoor, bow, lading,
# Nearest to was: is, were, became, has, are, interstate, postseason, had,
# Nearest to has: had, have, is, was, benchmarking, having, probus, conversely,
# Nearest to their: its, his, guelfs, her, the, our, any, navajo,
# Nearest to were: are, was, is, had, indulgences, intracranial, cto, pokes,
# Nearest to th: snake, christopher, numerals, school, nine, members, nd, genealogy,
# Nearest to some: many, several, these, havas, other, monkees, casanova, various,
# Nearest to or: than, and, randle, stew, exorcism, ions, interglacial, acquisition,
# Nearest to will: would, can, may, could, must, to, might, should,
# Nearest to from: into, gash, through, islington, dozenal, connective, in, jackals,
# Nearest to on: in, denounces, costas, undue, loathing, sympathizers, avert, upon,
# Nearest to of: for, sothoth, in, shorelines, alignments, kurz, to, rat,
# Nearest to states: kingdom, divers, electronegative, disjunction, colonies, everton, bikram, determinism,
# Nearest to between: alloy, porfirio, characterises, meantime, lair, alum, tricyclic, designates,
# Nearest to been: become, devas, populist, be, dwellers, homered, bp, folders,
# Nearest to world: pouches, anxious, second, country, consolidate, encounter, brain, robbery,
# Average loss at step 12000: 3.551129
# Average loss at step 14000: 3.474953
# Average loss at step 16000: 3.468737
# Average loss at step 18000: 3.458681
# Average loss at step 20000: 3.286762
# Nearest to called: named, considered, known, used, beatboxing, there, hurst, found,
# Nearest to was: is, became, were, are, has, interstate, follett, judoka,
# Nearest to has: had, have, having, is, was, contains, conversely, became,
# Nearest to their: its, his, her, the, our, many, various, tribunes,
# Nearest to were: are, was, being, is, indulgences, numerals, many, overdose,
# Nearest to th: st, only, snake, eight, nd, numerals, pays, burgess,
# Nearest to some: many, several, various, all, any, those, most, fallen,
# Nearest to or: than, and, derivates, including, tum, bans, falsity, fanaticism,
# Nearest to will: would, could, can, may, should, must, might, did,
# Nearest to from: through, into, under, before, stillman, between, basement, about,
# Nearest to on: upon, solstice, letterboxes, deutscher, disability, sympathizers, petitioner, undue,
# Nearest to of: shorelines, ebionites, legation, englewood, pubic, ovulation, throughout, ilium,
# Nearest to states: kingdom, nations, divers, promulgation, disjunction, colonies, everton, battleship,
# Nearest to between: alloy, with, from, stoneman, into, in, hush, unfit,
# Nearest to been: become, bp, gone, folders, constructor, spruce, majorana, datum,
# Nearest to world: shaded, pouches, chronicon, city, tisdall, numeration, sprouted, encounter,
# Average loss at step 22000: 3.380106
# Average loss at step 24000: 3.297935
# Average loss at step 26000: 3.269425
# Average loss at step 28000: 3.325771
# Average loss at step 30000: 3.500166
# Nearest to called: considered, named, known, operetta, used, beatboxing, urbanisation, taught,
# Nearest to was: is, became, were, are, becomes, being, has, had,
# Nearest to has: had, have, having, is, was, contains, conversely, includes,
# Nearest to their: its, his, her, the, our, whose, your, both,
# Nearest to were: are, was, is, became, have, wobble, kashima, being,
# Nearest to th: st, nd, nineteenth, twentieth, nine, pays, rd, bayonets,
# Nearest to some: many, several, all, both, most, thousands, numerous, those,
# Nearest to or: and, than, parmenides, clerics, tidy, pwnage, hurt, daytona,
# Nearest to will: would, could, can, must, may, should, might, cannot,
# Nearest to from: through, into, during, obsolescence, within, before, empower, between,
# Nearest to on: upon, nonprofit, in, parcham, under, about, objectives, claudian,
# Nearest to of: colloidal, among, richthofen, throughout, contests, in, fir, shorelines,
# Nearest to states: kingdom, nations, divers, promulgation, disjunction, everton, prussians, countries,
# Nearest to between: with, xa, into, lair, alloy, porfirio, from, cucurbitaceae,
# Nearest to been: become, be, come, purpurea, datum, mappings, gone, antimatter,
# Nearest to world: pouches, shaded, lemming, instigator, batsman, copious, fossil, fta,
# Average loss at step 32000: 3.215666
# Average loss at step 34000: 3.296066
# Average loss at step 36000: 3.301839
# Average loss at step 38000: 3.252753
# Average loss at step 40000: 3.208496
# Nearest to called: considered, named, used, included, known, beatboxing, conceptually, entscheidungsproblem,
# Nearest to was: is, were, became, becomes, has, are, being, includes,
# Nearest to has: had, have, having, includes, was, contains, is, could,
# Nearest to their: its, his, her, our, your, the, my, rapprochement,
# Nearest to were: are, was, rinsing, is, wager, include, boc, had,
# Nearest to th: st, nd, twentieth, nineteenth, nine, rd, pays, claymore,
# Nearest to some: many, several, various, most, all, both, certain, other,
# Nearest to or: and, angst, than, liquor, hodgson, cocoa, including, ions,
# Nearest to will: would, could, may, should, can, might, must, cannot,
# Nearest to from: through, within, during, into, before, looming, in, clue,
# Nearest to on: upon, in, under, mawr, around, across, if, rayleigh,
# Nearest to of: in, during, throughout, stabilize, temps, puddle, including, from,
# Nearest to states: kingdom, nations, divers, everton, electronegative, promulgation, state, disjunction,
# Nearest to between: within, across, alloy, xa, with, in, among, into,
# Nearest to been: become, gone, come, be, dogma, yup, crankshafts, roca,
# Nearest to world: instigator, shaded, gundobad, anxious, pouches, irma, fta, pence,
# Average loss at step 42000: 3.262552
# Average loss at step 44000: 3.172304
# Average loss at step 46000: 3.169712
# Average loss at step 48000: 3.073328
# Average loss at step 50000: 3.082920
# Nearest to called: used, named, known, considered, beatboxing, included, founded, pinkish,
# Nearest to was: is, were, became, had, being, are, took, postseason,
# Nearest to has: had, have, having, contains, includes, is, provides, was,
# Nearest to their: its, his, your, her, our, whose, my, the,
# Nearest to were: are, was, being, had, is, include, have, various,
# Nearest to th: nd, st, rd, twentieth, third, nineteenth, nine, pays,
# Nearest to some: many, several, various, thousands, most, numerous, all, pronouncing,
# Nearest to or: and, than, vesicles, randle, bets, birdman, invincible, tum,
# Nearest to will: would, can, may, could, should, might, must, cannot,
# Nearest to from: into, during, through, in, within, looming, obsolescence, when,
# Nearest to on: upon, around, across, about, in, under, through, within,
# Nearest to of: at, for, temps, sothoth, sender, including, despite, antebellum,
# Nearest to states: kingdom, nations, divers, everton, promulgation, electronegative, affine, battleship,
# Nearest to between: alloy, with, across, xa, lair, into, luang, amps,
# Nearest to been: become, remained, ever, gone, yup, yet, occurred, come,
# Nearest to world: instigator, fta, shaded, houser, lemming, windward, country, irma,
# Average loss at step 52000: 3.115853
# Average loss at step 54000: 3.111398
# Average loss at step 56000: 2.944337
# Average loss at step 58000: 3.041570
# Average loss at step 60000: 3.059254
# Nearest to called: considered, named, used, known, referred, described, beatboxing, included,
# Nearest to was: is, became, had, were, are, becomes, being, remained,
# Nearest to has: had, have, having, includes, is, contains, provides, was,
# Nearest to their: its, his, her, your, our, the, my, whose,
# Nearest to were: are, was, include, had, is, indulgences, various, sloped,
# Nearest to th: st, nd, twentieth, nineteenth, rd, third, punter, pays,
# Nearest to some: many, several, various, all, most, certain, numerous, those,
# Nearest to or: and, than, pwnage, khans, pohjola, but, while, bitumen,
# Nearest to will: would, could, can, should, may, might, must, cannot,
# Nearest to from: into, obsolescence, stillman, through, operettas, eamon, sharm, submitted,
# Nearest to on: upon, around, under, within, across, in, through, throughout,
# Nearest to of: including, paragon, stalking, include, fiennes, like, whose, in,
# Nearest to states: kingdom, nations, divers, promulgation, everton, affine, countries, things,
# Nearest to between: across, with, xa, alloy, around, among, into, snobol,
# Nearest to been: become, remained, come, yet, occurred, emerged, was, asa,
# Nearest to world: england, country, fta, shaded, anxious, sacrifices, irma, pouches,
# Average loss at step 62000: 3.025541
# Average loss at step 64000: 3.001832
# Average loss at step 66000: 2.956646
# Average loss at step 68000: 3.002816
# Average loss at step 70000: 3.024915
# Nearest to called: named, considered, used, there, known, described, placed, referred,
# Nearest to was: is, were, became, becomes, has, had, postseason, are,
# Nearest to has: had, have, having, includes, contains, is, was, maintains,
# Nearest to their: its, his, her, our, your, the, both, my,
# Nearest to were: are, was, is, wager, asperger, had, rinsing, babur,
# Nearest to th: twentieth, st, nineteenth, nd, nine, rd, claymore, ninth,
# Nearest to some: many, several, various, certain, all, numerous, both, these,
# Nearest to or: and, than, lonsdaleite, tum, while, publique, uses, bartle,
# Nearest to will: would, could, can, must, may, should, might, cannot,
# Nearest to from: through, within, before, into, since, between, in, via,
# Nearest to on: upon, about, throughout, under, in, hypothyroidism, across, eratosthenes,
# Nearest to of: including, despite, for, antebellum, saliva, fragrance, throughout, through,
# Nearest to states: kingdom, nations, divers, promulgation, everton, electronegative, aussie, courts,
# Nearest to between: across, xa, with, lair, luang, from, among, therefore,
# Nearest to been: become, be, come, fallen, occurred, remained, was, yet,
# Nearest to world: shaded, competition, city, pouches, country, decade, division, melanogaster,
# Average loss at step 72000: 2.979095
# Average loss at step 74000: 2.881403
# Average loss at step 76000: 3.014946
# Average loss at step 78000: 3.015286
# Average loss at step 80000: 2.866284
# Nearest to called: named, considered, known, used, included, featured, formed, played,
# Nearest to was: is, were, became, becomes, requires, had, are, makes,
# Nearest to has: had, having, have, contains, is, includes, maintains, was,
# Nearest to their: its, his, her, your, our, the, themselves, my,
# Nearest to were: are, was, include, is, various, had, fifths, asperger,
# Nearest to th: st, twentieth, nineteenth, nd, eighteenth, rd, nine, publisher,
# Nearest to some: many, several, various, certain, thousands, most, those, both,
# Nearest to or: and, but, bitumen, gabonese, tokusatsu, deists, comte, prepaid,
# Nearest to will: would, could, can, must, might, may, cannot, should,
# Nearest to from: through, into, via, across, operettas, since, within, prepubescent,
# Nearest to on: upon, under, in, through, favre, parcham, onto, eratosthenes,
# Nearest to of: including, throughout, antebellum, beyond, richthofen, following, shorelines, represents,
# Nearest to states: kingdom, nations, divers, provinces, emirates, electronegative, promulgation, colonies,
# Nearest to between: across, among, xa, with, alloy, around, against, into,
# Nearest to been: become, come, appeared, grown, gone, fallen, emerged, yup,
# Nearest to world: shaded, europe, country, competition, pouches, league, instigator, putatively,
# Average loss at step 82000: 2.948810
# Average loss at step 84000: 2.905922
# Average loss at step 86000: 2.928804
# Average loss at step 88000: 2.950356
# Average loss at step 90000: 2.845566
# Nearest to called: named, considered, known, used, described, referred, included, introduced,
# Nearest to was: is, were, became, becomes, had, are, has, planina,
# Nearest to has: had, have, contains, having, includes, is, maintains, was,
# Nearest to their: its, his, her, your, our, the, my, whose,
# Nearest to were: are, was, various, include, raul, exist, have, is,
# Nearest to th: twentieth, nineteenth, st, nd, third, nine, eighteenth, fourth,
# Nearest to some: many, various, most, several, both, certain, all, numerous,
# Nearest to or: and, than, attends, moguls, though, tum, forcibly, nafta,
# Nearest to will: would, could, can, might, must, should, may, cannot,
# Nearest to from: during, via, obsolescence, into, bypass, lantern, since, rightfully,
# Nearest to on: upon, through, in, onto, within, under, off, among,
# Nearest to of: in, following, beyond, including, despite, among, regarding, antebellum,
# Nearest to states: kingdom, nations, divers, emirates, promulgation, affine, electronegative, consonants,
# Nearest to between: xa, therefore, among, across, within, everyman, then, with,
# Nearest to been: become, occurred, fallen, gone, grown, emerged, increased, purpurea,
# Nearest to world: country, shaded, vietnam, fossil, instigator, universe, decade, scouting,
# Average loss at step 92000: 2.909084
# Average loss at step 94000: 2.893748
# Average loss at step 96000: 2.724634
# Average loss at step 98000: 2.484206
# Average loss at step 100000: 2.719204
# Nearest to called: named, considered, used, known, described, renamed, referred, granted,
# Nearest to was: is, became, were, had, remained, are, requires, makes,
# Nearest to has: had, have, having, contains, is, includes, maintains, provides,
# Nearest to their: its, his, her, your, our, my, whose, interlisp,
# Nearest to were: are, was, is, have, had, include, raul, various,
# Nearest to th: twentieth, nd, nineteenth, st, third, fourth, eighteenth, rd,
# Nearest to some: many, several, various, most, thousands, both, multiple, certain,
# Nearest to or: and, than, though, bitumen, without, but, moguls, permit,
# Nearest to will: would, could, might, should, must, can, shall, cannot,
# Nearest to from: via, across, including, during, in, into, nihilistic, onto,
# Nearest to on: upon, concerning, through, in, about, off, onto, detour,
# Nearest to of: including, in, fir, sothoth, despite, involves, temps, ebionites,
# Nearest to states: kingdom, nations, divers, emirates, promulgation, brilliant, state, berenson,
# Nearest to between: with, among, across, xa, within, involving, cucurbitaceae, alloy,
# Nearest to been: become, occurred, fallen, come, grown, gone, emerged, remained,
# Nearest to world: vietnam, instigator, fossil, shaded, diverge, league, kwan, tornadoes,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# Some clusters are less obvious (like the standalone characters), but it clearly totaly works.

# %% [markdown]
# How does your CBOW model perform compared to the given Word2Vec model? (to be answered)
