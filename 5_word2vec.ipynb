# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
print(data[:10])
print(count[:10])
print(dictionary.items()[:10])
print(reverse_dictionary.items()[:10])
# Out:
# [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]
# [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764), ('in', 372201), ('a', 325873), ('to', 316376), ('zero', 264975), ('nine', 250430)]
# [('fawn', 45848), ('homomorphism', 9648), ('nordisk', 39343), ('nunnery', 36075), ('chthonic', 33554), ('sowell', 40562), ('sonja', 38175), ('showa', 32906), ('woods', 6263), ('hsv', 44222)]
# [(0, 'UNK'), (1, 'the'), (2, 'of'), (3, 'and'), (4, 'one'), (5, 'in'), (6, 'a'), (7, 'to'), (8, 'zero'), (9, 'nine')]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:32]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=16, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(16)])
    
for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 1
    batch, labels = generate_batch(batch_size=16, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(16)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'UNK', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term', 'of', 'of', 'abuse', 'abuse', 'first', 'first', 'used', 'used']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'of', 'a', 'term', 'abuse', 'first', 'of', 'abuse', 'used', 'first', 'against']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a', 'term', 'term', 'term', 'term', 'of', 'of', 'of', 'of']
#     labels: ['anarchism', 'originated', 'a', 'term', 'originated', 'of', 'term', 'as', 'abuse', 'a', 'as', 'of', 'abuse', 'first', 'term', 'a']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['as', 'as', 'a', 'a', 'term', 'term', 'of', 'of', 'abuse', 'abuse', 'first', 'first', 'used', 'used', 'against', 'against']
#     labels: ['originated', 'a', 'as', 'term', 'a', 'of', 'abuse', 'term', 'of', 'first', 'abuse', 'used', 'against', 'first', 'early', 'used']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['a', 'a', 'a', 'a', 'term', 'term', 'term', 'term', 'of', 'of', 'of', 'of', 'abuse', 'abuse', 'abuse', 'abuse']
#     labels: ['term', 'as', 'originated', 'of', 'of', 'as', 'abuse', 'a', 'a', 'first', 'term', 'abuse', 'term', 'used', 'first', 'of']

# %% [markdown]
# Note: the labels is a sliding random value of the word surrounding the words of the batch.

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.835399
# Nearest to on: dc, drawback, alain, kyle, gangster, orbiting, suicide, incompatibilities,
# Nearest to from: ebooks, expansionary, hydroxides, heidegger, plekhanov, charters, theron, incessant,
# Nearest to one: nashville, tren, amg, toned, vax, reilly, joplin, acuity,
# Nearest to many: jl, synonym, vulgar, djinn, australasian, risorgimento, further, emmerdale,
# Nearest to known: asthma, lad, suffered, oxus, weekends, cripps, bazin, soundtracks,
# Nearest to most: pasting, tripping, marrow, chez, garrett, improve, dairy, chroniclers,
# Nearest to at: mutualism, tradesmen, passed, worthwhile, destructive, derry, contrabass, canning,
# Nearest to used: intercal, contravening, brainwashing, functionally, seeker, helping, morricone, hydroelectricity,
# Nearest to first: alloys, illiterate, crimean, algemeen, diena, pg, accordingly, prefrontal,
# Nearest to of: nitrous, plankton, glean, peaches, suck, galton, futurists, subway,
# Nearest to two: cytology, degrades, falk, lies, gerson, jerry, definitional, onion,
# Nearest to these: friendships, thom, stallions, valence, maguire, variably, succulent, egan,
# Nearest to as: chee, hetfield, horrific, loom, studied, scoping, ly, delhi,
# Nearest to after: hills, yahoo, emmylou, featuring, incarnation, laud, memberships, genoa,
# Nearest to united: reared, venice, basket, paso, laughter, abad, fiqh, dogbert,
# Nearest to an: admired, pgs, must, strassburg, heats, undergraduate, mayall, graphemes,
# Average loss at step 2000: 4.364578
# Average loss at step 4000: 3.869095
# Average loss at step 6000: 3.785785
# Average loss at step 8000: 3.684169
# Average loss at step 10000: 3.618217
# Nearest to on: in, by, munich, folketing, allotment, outing, manatee, at,
# Nearest to from: in, into, indemnity, under, charters, reuter, jonas, at,
# Nearest to one: two, three, six, eight, five, seven, four, instrumentalist,
# Nearest to many: some, synonym, exploiting, coffers, these, further, luton, djinn,
# Nearest to known: used, such, categorically, iaea, being, wiser, cegep, larkin,
# Nearest to most: chez, sacrum, tripping, culture, electors, promoted, contemplate, synthesis,
# Nearest to at: in, mutualism, helmut, ombudsman, from, hing, with, slag,
# Nearest to used: known, marxist, recount, able, fanatics, seeker, homosexuality, inject,
# Nearest to first: palo, algemeen, pg, second, ushering, before, nazarian, deluded,
# Nearest to of: in, for, suck, during, plankton, specifying, elevating, designates,
# Nearest to two: three, four, six, eight, five, seven, one, nine,
# Nearest to these: many, some, dracula, variably, friendships, enroll, preterist, camino,
# Nearest to as: disparaging, by, apparently, bandmates, sleepers, chee, tandem, fasts,
# Nearest to after: laud, diameters, hei, genoa, incarnation, memberships, from, loew,
# Nearest to united: venice, laughter, reared, peers, seductive, basket, deviant, abad,
# Nearest to an: the, must, heats, heenan, concubines, arizona, digests, damages,
# Average loss at step 12000: 3.607045
# Average loss at step 14000: 3.572645
# Average loss at step 16000: 3.410353
# Average loss at step 18000: 3.458402
# Average loss at step 20000: 3.545916
# Nearest to on: in, upon, manatee, munich, past, carracci, dc, eyelashes,
# Nearest to from: into, in, under, through, by, between, after, jonas,
# Nearest to one: two, four, three, eight, six, seven, five, nine,
# Nearest to many: some, several, these, all, synonym, exploiting, other, coffers,
# Nearest to known: used, such, regarded, cegep, iaea, being, categorically, ref,
# Nearest to most: promoted, synthesis, many, more, chez, some, contemplate, several,
# Nearest to at: in, infraclass, electroconvulsive, helmut, contributes, near, ombudsman, underestimated,
# Nearest to used: known, held, inject, able, marxist, homosexuality, aphids, decedent,
# Nearest to first: second, palo, algemeen, kr, avoids, next, among, ollie,
# Nearest to of: including, plankton, lans, for, reformation, subway, postulating, volt,
# Nearest to two: four, three, five, six, seven, one, eight, nine,
# Nearest to these: some, many, dracula, all, such, other, variably, they,
# Nearest to as: chee, formosa, charted, indemnity, hitchens, by, assisi, earthworm,
# Nearest to after: before, into, diameters, laud, from, pivot, plot, memberships,
# Nearest to united: laughter, southern, peers, venice, reared, world, formation, paso,
# Nearest to an: anticipating, the, reconcile, automator, dem, heats, arizona, digests,
# Average loss at step 22000: 3.500683
# Average loss at step 24000: 3.490486
# Average loss at step 26000: 3.479321
# Average loss at step 28000: 3.478877
# Average loss at step 30000: 3.502802
# Nearest to on: in, upon, from, under, during, dc, through, around,
# Nearest to from: into, in, under, through, on, after, between, fictions,
# Nearest to one: two, eight, four, seven, six, nine, three, five,
# Nearest to many: some, several, these, all, synonym, most, coffers, were,
# Nearest to known: used, regarded, such, iaea, well, developed, falsified, cegep,
# Nearest to most: synthesis, more, some, many, several, progress, promoted, warmblood,
# Nearest to at: in, near, electroconvulsive, within, possessor, scent, ombudsman, on,
# Nearest to used: known, inject, held, marxist, homosexuality, defined, decedent, able,
# Nearest to first: second, next, palo, algemeen, last, kr, moreau, same,
# Nearest to of: in, for, taipei, including, from, against, and, lcm,
# Nearest to two: four, three, five, eight, one, seven, six, nine,
# Nearest to these: some, many, such, they, their, are, both, all,
# Nearest to as: hitchens, charted, by, earthworm, cure, when, chee, or,
# Nearest to after: before, when, during, from, diameters, into, memberships, pivot,
# Nearest to united: southern, formation, peers, laughter, northwest, reared, venice, throne,
# Nearest to an: automator, honky, qazaqstan, nicol, digests, dem, heats, anticipating,
# Average loss at step 32000: 3.500250
# Average loss at step 34000: 3.492413
# Average loss at step 36000: 3.450956
# Average loss at step 38000: 3.296763
# Average loss at step 40000: 3.434037
# Nearest to on: upon, during, manatee, from, in, includes, through, guessed,
# Nearest to from: into, in, through, on, fictions, of, to, germs,
# Nearest to one: seven, eight, six, four, two, five, nine, three,
# Nearest to many: some, several, these, most, synonym, those, both, various,
# Nearest to known: used, such, regarded, well, iaea, falsified, defined, cegep,
# Nearest to most: more, many, several, synthesis, some, stitch, warmblood, micro,
# Nearest to at: trammell, during, in, newest, near, within, iverson, bonham,
# Nearest to used: known, considered, seen, limited, able, called, defined, inject,
# Nearest to first: second, last, next, moreau, algemeen, palo, ftc, denominated,
# Nearest to of: in, for, original, from, pq, suck, og, indymedia,
# Nearest to two: three, four, five, six, seven, one, eight, nine,
# Nearest to these: many, some, such, they, both, their, several, all,
# Nearest to as: hitchens, neberg, cure, alluding, exciting, av, by, turpin,
# Nearest to after: before, diameters, during, when, spratly, pivot, from, genoa,
# Nearest to united: southern, formation, northwest, peers, usa, reared, laughter, famers,
# Nearest to an: automator, reconcile, saumur, anticipating, another, wainwright, dem, irreversibly,
# Average loss at step 42000: 3.437924
# Average loss at step 44000: 3.450732
# Average loss at step 46000: 3.448848
# Average loss at step 48000: 3.353878
# Average loss at step 50000: 3.381013
# Nearest to on: upon, in, through, under, over, within, into, across,
# Nearest to from: into, through, across, under, in, hostage, between, during,
# Nearest to one: two, eight, six, seven, four, three, nine, five,
# Nearest to many: some, several, these, various, both, most, such, other,
# Nearest to known: used, regarded, such, well, falsified, defined, possible, cegep,
# Nearest to most: more, some, many, less, synthesis, several, stitch, warmblood,
# Nearest to at: during, in, electroconvulsive, near, newest, slag, unofficially, forming,
# Nearest to used: known, considered, seen, held, able, described, explained, responsible,
# Nearest to first: second, last, next, algemeen, moreau, kr, ftc, palo,
# Nearest to of: and, in, including, logically, bradbury, greenery, strauss, taipei,
# Nearest to two: three, one, six, four, seven, eight, five, nine,
# Nearest to these: many, some, both, such, several, those, all, their,
# Nearest to as: chee, neberg, when, classrooms, exciting, lechuck, authorizing, wynette,
# Nearest to after: before, when, during, spratly, from, while, glance, despite,
# Nearest to united: formation, southern, peers, reared, northern, northwest, usa, pours,
# Nearest to an: anticipating, automator, dem, reconcile, honky, saumur, diddley, digests,
# Average loss at step 52000: 3.438805
# Average loss at step 54000: 3.426688
# Average loss at step 56000: 3.439793
# Average loss at step 58000: 3.392060
# Average loss at step 60000: 3.387870
# Nearest to on: upon, under, through, about, in, entitlement, irc, daily,
# Nearest to from: into, through, in, predisposition, during, across, under, between,
# Nearest to one: eight, two, nine, seven, six, four, three, five,
# Nearest to many: some, several, these, various, most, both, other, such,
# Nearest to known: used, regarded, such, well, possible, defined, falsified, cegep,
# Nearest to most: many, more, some, less, synthesis, pokemon, use, remixing,
# Nearest to at: during, in, electroconvulsive, within, university, scent, sheikh, near,
# Nearest to used: known, called, considered, described, found, held, defined, available,
# Nearest to first: second, last, next, moreau, denominated, avoids, same, only,
# Nearest to of: in, for, like, og, and, although, original, unheated,
# Nearest to two: three, four, one, five, seven, eight, six, nine,
# Nearest to these: many, some, both, those, several, such, their, various,
# Nearest to as: when, classrooms, hotbed, allowing, swear, cure, tandem, create,
# Nearest to after: before, during, when, despite, spratly, under, following, until,
# Nearest to united: peers, usa, formation, southern, northwest, reared, famers, illustrations,
# Nearest to an: saumur, automator, dem, reconcile, regulated, anticipating, honky, qazaqstan,
# Average loss at step 62000: 3.239865
# Average loss at step 64000: 3.255340
# Average loss at step 66000: 3.400903
# Average loss at step 68000: 3.393758
# Average loss at step 70000: 3.363263
# Nearest to on: upon, through, in, within, about, irc, at, navigated,
# Nearest to from: through, into, predisposition, during, in, between, by, legates,
# Nearest to one: two, seven, six, four, eight, three, five, nine,
# Nearest to many: some, several, these, various, most, all, other, both,
# Nearest to known: used, regarded, such, defined, falsified, well, cegep, possible,
# Nearest to most: more, less, many, some, synthesis, use, several, stitch,
# Nearest to at: during, within, in, sheikh, electroconvulsive, near, on, hing,
# Nearest to used: known, found, described, available, responsible, written, considered, seen,
# Nearest to first: second, next, last, same, denominated, moreau, only, third,
# Nearest to of: and, original, unborn, in, including, somme, principal, trafalgar,
# Nearest to two: three, four, six, one, five, seven, eight, nine,
# Nearest to these: many, such, some, various, those, several, their, they,
# Nearest to as: authorizing, affixes, when, duluth, suited, vinnie, like, is,
# Nearest to after: before, during, when, despite, spratly, upon, without, through,
# Nearest to united: peers, formation, usa, northwest, reared, illustrations, southern, memorization,
# Nearest to an: automator, saumur, dem, qazaqstan, irreversibly, digests, satem, anticipating,
# Average loss at step 72000: 3.370045
# Average loss at step 74000: 3.349152
# Average loss at step 76000: 3.315367
# Average loss at step 78000: 3.352377
# Average loss at step 80000: 3.379289
# Nearest to on: upon, in, through, at, measles, under, munich, knockout,
# Nearest to from: into, through, during, across, under, in, predisposition, by,
# Nearest to one: seven, two, six, eight, four, three, five, nine,
# Nearest to many: some, several, various, these, most, all, both, few,
# Nearest to known: regarded, used, such, defined, falsified, called, seen, considered,
# Nearest to most: more, many, some, less, several, pokemon, aldiss, slapping,
# Nearest to at: in, on, near, within, slag, during, sheikh, around,
# Nearest to used: known, needed, responsible, referred, available, found, considered, written,
# Nearest to first: second, next, last, third, moreau, same, final, fifth,
# Nearest to of: original, in, including, although, laud, brainiac, volunteer, linspire,
# Nearest to two: three, six, four, five, one, seven, eight, nine,
# Nearest to these: several, many, those, various, both, such, some, are,
# Nearest to as: tampering, proliferated, allowing, like, cure, when, lechuck, exciting,
# Nearest to after: before, during, when, despite, spratly, in, upon, without,
# Nearest to united: peers, usa, constitution, northwest, formation, federal, illustrations, famers,
# Nearest to an: automator, dem, anticipating, qazaqstan, saumur, reconcile, irreversibly, gly,
# Average loss at step 82000: 3.405426
# Average loss at step 84000: 3.409425
# Average loss at step 86000: 3.388109
# Average loss at step 88000: 3.350659
# Average loss at step 90000: 3.362486
# Nearest to on: upon, at, through, under, into, in, trombones, within,
# Nearest to from: through, into, during, within, across, khanum, before, directional,
# Nearest to one: seven, two, eight, four, six, three, five, nine,
# Nearest to many: several, some, various, these, most, all, those, few,
# Nearest to known: regarded, used, such, possible, defined, falsified, called, described,
# Nearest to most: more, many, some, less, several, aldiss, all, obeying,
# Nearest to at: near, during, on, once, after, in, within, conveyor,
# Nearest to used: known, considered, referred, seen, available, described, required, found,
# Nearest to first: second, last, next, moreau, original, originally, fifth, pg,
# Nearest to of: for, including, in, during, marco, despite, adrien, caldwell,
# Nearest to two: three, five, four, six, eight, seven, one, nine,
# Nearest to these: several, many, some, those, such, are, various, both,
# Nearest to as: authorizing, suited, cerf, proliferated, kazakhs, fedora, vinnie, tandem,
# Nearest to after: before, during, despite, when, without, spratly, while, until,
# Nearest to united: constitution, usa, federal, peers, northwest, outlandish, formation, famers,
# Nearest to an: saumur, wainwright, reconcile, another, automator, anticipating, dem, qazaqstan,
# Average loss at step 92000: 3.391108
# Average loss at step 94000: 3.247174
# Average loss at step 96000: 3.352039
# Average loss at step 98000: 3.242034
# Average loss at step 100000: 3.357562
# Nearest to on: upon, in, at, through, under, within, lps, thymus,
# Nearest to from: through, into, during, directional, in, within, dura, across,
# Nearest to one: two, four, seven, eight, six, five, three, nine,
# Nearest to many: some, several, various, these, all, few, numerous, living,
# Nearest to known: such, regarded, used, possible, defined, falsified, seen, referred,
# Nearest to most: more, less, synthesis, some, many, several, especially, aldiss,
# Nearest to at: near, during, on, in, newest, after, within, electroconvulsive,
# Nearest to used: considered, referred, seen, found, required, described, known, applied,
# Nearest to first: second, next, last, third, fifth, moreau, final, fourth,
# Nearest to of: and, in, spline, original, including, cyaxares, unborn, bluffs,
# Nearest to two: four, six, three, five, seven, eight, one, nine,
# Nearest to these: several, some, many, those, various, different, all, numerous,
# Nearest to as: swear, skies, suited, hitchens, av, vientiane, tandem, authorizing,
# Nearest to after: before, during, without, despite, when, spratly, while, following,
# Nearest to united: constitution, usa, federal, peers, northwest, formation, outlandish, reared,
# Nearest to an: saumur, qazaqstan, another, automator, wainwright, dem, reconcile, diddley,

# %%
print(final_embeddings[0])
# Out:
# [ -4.01850156e-02  -1.33045599e-01  -8.89958348e-03   1.92900389e-01
#   -1.95471849e-02   5.34872711e-02  -1.17754474e-01  -1.32032554e-03
#    2.21385598e-01   1.01130180e-01  -1.06697269e-01  -1.06371686e-01
#   -4.75813001e-02   3.74982022e-02  -8.75249878e-02  -5.09503856e-03
#   -8.22821930e-02   1.31118283e-01   7.67485350e-02   5.60912043e-02
#    3.80613469e-02   2.85889488e-02   1.85505390e-01   5.40961251e-02
#    1.04898997e-02   3.19401585e-02   1.49423212e-01  -1.14876861e-02
#   -5.40094823e-02  -8.93631876e-02  -1.18912971e-02  -1.40863374e-01
#    3.78079265e-02   5.98042309e-02   3.29538509e-02   1.92057807e-02
#    1.28988504e-01   3.47710736e-02  -5.52932471e-02   7.89941698e-02
#   -7.09955860e-03   1.32470101e-01   5.69757968e-02   8.96189064e-02
#    3.24688070e-02  -1.24239363e-01   5.06732464e-02   9.15021524e-02
#   -7.60670751e-02   2.72599179e-02   5.38525684e-03   1.60906121e-01
#    1.65289596e-01  -1.21063113e-01  -5.22400718e-03   6.32786378e-02
#    1.23994596e-01  -3.44581343e-02  -5.78016834e-03   5.05225547e-02
#   -8.12561139e-02  -4.29614773e-03   2.11216528e-02  -1.30583763e-01
#    1.02594227e-01   2.78234661e-01  -3.58019061e-02  -7.65688196e-02
#   -8.26502815e-02   3.56240124e-02   1.17481373e-01   3.50587489e-03
#   -2.25415453e-02   5.15329577e-02  -1.21603452e-01  -7.26348162e-02
#   -3.86175583e-04   4.82778735e-02  -4.72544841e-02   1.03483580e-01
#   -8.20515603e-02  -5.51935695e-02  -7.89398327e-02   2.13032458e-02
#    3.75334732e-02  -1.19587602e-02   8.31782296e-02  -6.26867041e-02
#    2.66944505e-02  -6.26416802e-02  -1.30853683e-01  -8.52254704e-02
#    1.14116184e-01   4.79406565e-02  -1.19146556e-01   1.07752353e-01
#   -2.96382196e-02  -1.90873441e-04   1.78631827e-01  -4.78303619e-02
#    6.50036559e-02   4.89498451e-02  -9.87801179e-02   9.94170904e-02
#   -1.76629405e-02   4.74196440e-03  -1.61995262e-01  -2.63067130e-02
#    7.18231797e-02   4.69514951e-02   8.14308897e-02   2.20040902e-02
#    4.71294373e-02  -1.11852340e-01   4.95149568e-02   1.31110936e-01
#   -8.15489963e-02   7.87268206e-02  -1.09787740e-01   1.00266121e-01
#   -1.11630268e-01  -1.01338267e-01  -1.62114184e-02  -3.63043211e-02
#   -1.24889381e-01   1.11200534e-01  -2.87084728e-02  -1.19358942e-01]

# %%
print(np.sum(np.square(final_embeddings[0])))
# Out:
# 1.0

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

#for num_skips, skip_window in [(2, 1), (4, 2)]:
#    data_index = 0
#    batch, labels = generate_batch(batch_size=16, num_skips=num_skips, skip_window=skip_window)
#    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
#    print('    batch:', [reverse_dictionary[bi] for bi in batch])
#    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(16)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
###skip_window = 1 # How many words to consider left and right.
###num_skips = 2 # How many times to reuse an input to generate a label.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 1001 #100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
