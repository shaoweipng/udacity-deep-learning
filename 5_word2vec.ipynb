# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
print(data[:10])
print(count[:10])
print(dictionary.items()[:10])
print(reverse_dictionary.items()[:10])
# Out:
# [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]
# [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764), ('in', 372201), ('a', 325873), ('to', 316376), ('zero', 264975), ('nine', 250430)]
# [('fawn', 45848), ('homomorphism', 9648), ('nordisk', 39343), ('nunnery', 36075), ('chthonic', 33554), ('sowell', 40562), ('sonja', 38175), ('showa', 32906), ('woods', 6263), ('hsv', 44222)]
# [(0, 'UNK'), (1, 'the'), (2, 'of'), (3, 'and'), (4, 'one'), (5, 'in'), (6, 'a'), (7, 'to'), (8, 'zero'), (9, 'nine')]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:32]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=16, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(16)])
    
for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 1
    batch, labels = generate_batch(batch_size=16, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(16)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'UNK', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term', 'of', 'of', 'abuse', 'abuse', 'first', 'first', 'used', 'used']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'a', 'of', 'abuse', 'term', 'first', 'of', 'abuse', 'used', 'against', 'first']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a', 'term', 'term', 'term', 'term', 'of', 'of', 'of', 'of']
#     labels: ['term', 'a', 'originated', 'anarchism', 'as', 'of', 'term', 'originated', 'abuse', 'of', 'as', 'a', 'first', 'abuse', 'a', 'term']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['as', 'as', 'a', 'a', 'term', 'term', 'of', 'of', 'abuse', 'abuse', 'first', 'first', 'used', 'used', 'against', 'against']
#     labels: ['a', 'originated', 'term', 'as', 'of', 'a', 'term', 'abuse', 'of', 'first', 'used', 'abuse', 'first', 'against', 'early', 'used']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['a', 'a', 'a', 'a', 'term', 'term', 'term', 'term', 'of', 'of', 'of', 'of', 'abuse', 'abuse', 'abuse', 'abuse']
#     labels: ['term', 'of', 'as', 'originated', 'abuse', 'of', 'as', 'a', 'term', 'a', 'abuse', 'first', 'term', 'used', 'first', 'of']

# %% [markdown]
# Note: the labels is a sliding random value of the word surrounding the words of the batch.

# %%
print(batch)
print(labels)
# Out:
# [   6    6    6    6  195  195  195  195    2    2    2    2 3137 3137 3137
#  3137]
# [[ 195]
#  [   2]
#  [  12]
#  [3084]
#  [3137]
#  [   2]
#  [  12]
#  [   6]
#  [ 195]
#  [   6]
#  [3137]
#  [  46]
#  [ 195]
#  [  59]
#  [  46]
#  [   2]]

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.026531
# Nearest to eight: cauldron, shimizu, stabilize, spivak, bethune, adema, dimethyl, holidays,
# Nearest to they: recite, hypnotist, parental, godfather, huggins, lomography, xenakis, simpler,
# Nearest to his: hemingway, pen, quirk, canso, indulging, catacomb, gabriel, noether,
# Nearest to only: salesman, drill, tba, rite, nostra, observations, coppola, bju,
# Nearest to many: liberalized, woodpeckers, notorious, attractor, characterises, kurukshetra, chording, tensile,
# Nearest to war: caleb, pampas, reassembled, arming, estis, status, angelina, leveling,
# Nearest to with: hydroxyproline, gilt, willem, facto, worshipping, discovers, uncredited, hbp,
# Nearest to history: disgusting, reds, prussians, spinach, diagnosing, vu, luzon, expellees,
# Nearest to united: blonde, boris, jesuits, sainthood, bilingualism, adjusting, accuracy, ordered,
# Nearest to states: mileva, elvira, montessori, cirque, subcultures, visualized, gallo, mosquitos,
# Nearest to so: panda, lam, pythagorean, dramatically, laodiceans, qui, weicker, chiropractors,
# Nearest to two: monkees, occuring, everlast, zeeland, bibliographic, jsf, miller, raleigh,
# Nearest to also: subsystems, infix, gpled, plots, eyepiece, electrification, xxv, merovingian,
# Nearest to people: ecommerce, establishment, chen, charming, novorossiysk, shuffled, overturning, deleterious,
# Nearest to in: helier, clayton, donuts, evolution, camping, handicraft, breathed, kinsella,
# Nearest to more: reloading, ryle, likely, patch, plunkett, revocation, higgins, amalgam,
# Average loss at step 2000: 4.359532
# Average loss at step 4000: 3.859504
# Average loss at step 6000: 3.795139
# Average loss at step 8000: 3.691922
# Average loss at step 10000: 3.623065
# Nearest to eight: six, nine, seven, four, five, three, zero, two,
# Nearest to they: he, there, it, still, we, frauds, not, parental,
# Nearest to his: their, its, s, the, her, fluctuate, pen, spotless,
# Nearest to only: drill, syndicalism, tba, koichi, softened, gambler, nicaragua, observations,
# Nearest to many: some, several, intake, kimmei, things, these, grandchildren, woodpeckers,
# Nearest to war: caleb, pampas, sasquatch, ment, croat, watered, hyksos, agostino,
# Nearest to with: between, in, for, into, willem, strategies, from, blamed,
# Nearest to history: armenia, expellees, biomechanics, aspire, sheet, spinach, luzon, reds,
# Nearest to united: animating, accuracy, sainthood, adjusting, jesuits, mukherjee, berlusconi, paullus,
# Nearest to states: army, mileva, elvira, writeups, subcultures, vga, ammonius, rumelia,
# Nearest to so: though, presumed, dramatically, panda, relentless, lam, chiropractors, cbm,
# Nearest to two: five, three, four, six, one, seven, eight, nine,
# Nearest to also: sidewalk, who, electrification, generally, it, not, often, he,
# Nearest to people: skyview, overturning, disallowed, ecommerce, chen, oecd, ascii, emission,
# Nearest to in: of, on, at, from, with, during, by, periodic,
# Nearest to more: most, yellowstone, pups, nocs, suckling, how, britannica, reloading,
# Average loss at step 12000: 3.600468
# Average loss at step 14000: 3.570773
# Average loss at step 16000: 3.412530
# Average loss at step 18000: 3.463697
# Average loss at step 20000: 3.542062
# Nearest to eight: nine, six, seven, four, five, three, two, zero,
# Nearest to they: he, there, we, it, you, who, not, she,
# Nearest to his: their, her, its, the, my, poking, our, fastened,
# Nearest to only: archimedes, nicaragua, lone, syndicalism, do, ranked, drill, give,
# Nearest to many: some, several, these, all, other, those, theistic, kimmei,
# Nearest to war: sasquatch, hyksos, agostino, receipt, croat, watered, pampas, degenerative,
# Nearest to with: between, in, for, into, by, under, illuminating, and,
# Nearest to history: armenia, expellees, reds, biomechanics, spite, jody, freshmen, life,
# Nearest to united: southern, animating, accuracy, jesuits, adjusting, sainthood, modularity, berlusconi,
# Nearest to states: elvira, subcultures, rumelia, writeups, army, mileva, unary, rapprochement,
# Nearest to so: relentless, though, panda, dramatically, presumed, haredi, chiropractors, athanasian,
# Nearest to two: three, four, five, six, one, seven, eight, nine,
# Nearest to also: often, which, now, not, who, then, sometimes, it,
# Nearest to people: skyview, those, ecommerce, individuals, prison, overturning, chen, oecd,
# Nearest to in: at, during, from, on, brand, with, until, between,
# Nearest to more: less, most, pups, britannica, suckling, yellowstone, shrunk, reloading,
# Average loss at step 22000: 3.504789
# Average loss at step 24000: 3.493709
# Average loss at step 26000: 3.480056
# Average loss at step 28000: 3.482261
# Average loss at step 30000: 3.504528
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to they: there, he, we, it, who, you, not, she,
# Nearest to his: their, her, its, the, my, s, our, homeostasis,
# Nearest to only: archimedes, syndicalism, consecutively, nicaragua, eac, drill, koichi, households,
# Nearest to many: some, several, these, those, all, kimmei, various, augustus,
# Nearest to war: croat, sasquatch, hyksos, crematorium, agostino, receipt, watered, behalf,
# Nearest to with: between, under, by, in, elicit, jsr, without, saturnalia,
# Nearest to history: reds, foals, armenia, biomechanics, spite, tradition, determinant, philosophy,
# Nearest to united: southern, animating, jesuits, accuracy, berlusconi, multiplicative, petrel, paullus,
# Nearest to states: subcultures, elvira, parliament, rumelia, writeups, army, peas, kingdom,
# Nearest to so: relentless, though, panda, acclaim, athanasian, presumed, lech, haredi,
# Nearest to two: four, three, one, seven, five, eight, six, nine,
# Nearest to also: often, now, sometimes, still, who, which, it, generally,
# Nearest to people: individuals, those, years, prison, skyview, recognizes, reintroduce, oecd,
# Nearest to in: during, at, on, of, until, throughout, within, among,
# Nearest to more: less, most, suckling, britannica, yellowstone, pups, suffocation, greater,
# Average loss at step 32000: 3.499334
# Average loss at step 34000: 3.492697
# Average loss at step 36000: 3.457031
# Average loss at step 38000: 3.301284
# Average loss at step 40000: 3.431618
# Nearest to eight: nine, seven, six, four, five, three, one, zero,
# Nearest to they: we, there, he, you, it, i, she, who,
# Nearest to his: their, her, its, my, the, s, our, daimlerchrysler,
# Nearest to only: archimedes, lone, obtained, nicaragua, irina, levelling, koichi, eac,
# Nearest to many: some, several, these, those, various, suffragist, both, other,
# Nearest to war: hyksos, watered, croat, gendarmerie, distinguishes, misnomer, quantitatively, medlineplus,
# Nearest to with: between, by, when, storytelling, in, gave, slaughterhouse, unrwa,
# Nearest to history: reds, tradition, stopper, variety, vu, cpm, beverly, religion,
# Nearest to united: southern, jesuits, accuracy, paullus, asher, berlusconi, modularity, animating,
# Nearest to states: kingdom, parliament, elvira, subcultures, rumelia, disgraced, outline, ships,
# Nearest to so: relentless, dramatically, athanasian, nicknamed, haredi, acclaim, quite, always,
# Nearest to two: three, four, six, five, seven, eight, one, nine,
# Nearest to also: often, which, sometimes, still, now, then, who, there,
# Nearest to people: individuals, those, prison, recognizes, critics, reintroduce, men, emacs,
# Nearest to in: during, crossbar, overheat, within, and, of, with, dictates,
# Nearest to more: less, most, greater, britannica, suffocation, very, longer, suckling,
# Average loss at step 42000: 3.435329
# Average loss at step 44000: 3.451681
# Average loss at step 46000: 3.451762
# Average loss at step 48000: 3.347449
# Average loss at step 50000: 3.387121
# Nearest to eight: six, seven, nine, four, five, three, two, zero,
# Nearest to they: he, we, there, you, she, it, who, these,
# Nearest to his: her, their, its, my, the, our, fluctuate, some,
# Nearest to only: syndicalism, impersonal, either, always, ranked, archimedes, obtained, gniezno,
# Nearest to many: some, several, those, these, various, both, other, such,
# Nearest to war: hyksos, watered, gendarmerie, battle, behalf, misnomer, sasquatch, skylab,
# Nearest to with: between, by, morgue, when, babe, uncredited, confidentiality, without,
# Nearest to history: beverly, cpm, candy, stopper, orthogonal, retold, vu, kafka,
# Nearest to united: southern, paullus, berlusconi, jesuits, modularity, asher, animating, petrel,
# Nearest to states: kingdom, parliament, subcultures, ships, elvira, peas, rapprochement, cretians,
# Nearest to so: if, nicknamed, before, nov, agnosticism, haredi, athanasian, contraindicated,
# Nearest to two: three, six, four, five, eight, one, seven, nine,
# Nearest to also: often, which, still, sometimes, who, then, now, actually,
# Nearest to people: prison, individuals, men, recognizes, critics, them, ecommerce, handoff,
# Nearest to in: during, from, since, periodic, of, within, and, on,
# Nearest to more: less, most, suffocation, greater, longer, quite, very, britannica,
# Average loss at step 52000: 3.435593
# Average loss at step 54000: 3.427488
# Average loss at step 56000: 3.441796
# Average loss at step 58000: 3.392517
# Average loss at step 60000: 3.391478
# Nearest to eight: nine, six, seven, four, five, three, zero, one,
# Nearest to they: we, there, you, he, she, it, i, who,
# Nearest to his: her, their, its, my, merciful, the, our, your,
# Nearest to only: always, first, impersonal, crete, syndicalism, usually, forget, but,
# Nearest to many: some, several, various, these, those, such, most, including,
# Nearest to war: battle, gendarmerie, hyksos, misnomer, distinguishes, behalf, medlineplus, puente,
# Nearest to with: between, in, by, when, temples, including, into, weekend,
# Nearest to history: stopper, retold, leadership, biomechanics, disproportionate, hardship, settlement, life,
# Nearest to united: southern, paullus, berlusconi, jesuits, modularity, petrel, geodetic, multiplicative,
# Nearest to states: kingdom, subcultures, parliament, nations, ships, cretians, elvira, quadriceps,
# Nearest to so: nicknamed, if, quite, dramatically, something, implies, alike, then,
# Nearest to two: three, five, four, six, eight, one, seven, zero,
# Nearest to also: often, now, still, typically, sometimes, generally, actually, usually,
# Nearest to people: men, individuals, critics, prison, those, recognizes, years, girl,
# Nearest to in: within, during, from, of, between, with, since, among,
# Nearest to more: less, most, greater, suffocation, very, quite, higher, absentia,
# Average loss at step 62000: 3.240343
# Average loss at step 64000: 3.254703
# Average loss at step 66000: 3.402309
# Average loss at step 68000: 3.398758
# Average loss at step 70000: 3.358916
# Nearest to eight: nine, six, seven, five, four, zero, three, two,
# Nearest to they: we, he, there, you, she, it, resonated, these,
# Nearest to his: her, their, my, its, our, your, wealthiest, daimlerchrysler,
# Nearest to only: never, always, impersonal, but, rc, either, crete, equestrian,
# Nearest to many: some, several, various, these, all, those, most, both,
# Nearest to war: battle, distinguishes, gendarmerie, puente, wars, medieval, hyksos, federation,
# Nearest to with: between, in, jn, including, facing, into, slough, ccds,
# Nearest to history: list, stopper, breakdowns, disproportionate, leadership, drenthe, biomechanics, kafka,
# Nearest to united: southern, paullus, whole, modularity, jesuits, petrel, scratching, berlusconi,
# Nearest to states: kingdom, nations, parliament, cretians, subcultures, elvira, writeups, outline,
# Nearest to so: if, nicknamed, agnosticism, athanasian, too, then, thus, xof,
# Nearest to two: three, four, six, seven, five, one, eight, nine,
# Nearest to also: now, often, still, sometimes, which, typically, usually, actually,
# Nearest to people: individuals, men, critics, those, women, prison, children, recognizes,
# Nearest to in: during, within, until, for, on, throughout, dictates, among,
# Nearest to more: less, most, very, suffocation, greater, quite, rather, higher,
# Average loss at step 72000: 3.376375
# Average loss at step 74000: 3.346827
# Average loss at step 76000: 3.311739
# Average loss at step 78000: 3.348562
# Average loss at step 80000: 3.381720
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to they: we, he, there, you, she, it, resonated, these,
# Nearest to his: her, their, my, its, your, our, the, pyrimidine,
# Nearest to only: always, impersonal, either, rake, last, qf, ask, excessive,
# Nearest to many: several, some, various, these, numerous, those, both, all,
# Nearest to war: battle, distinguishes, wars, gendarmerie, comparisons, hyksos, medieval, puente,
# Nearest to with: between, when, by, masonry, mitford, neural, ml, in,
# Nearest to history: kafka, hardship, disproportionate, leadership, because, list, biomechanics, retold,
# Nearest to united: southern, paullus, modularity, berlusconi, petrel, border, jesuits, scratching,
# Nearest to states: kingdom, nations, us, state, parliament, cretians, gediminas, elvira,
# Nearest to so: if, before, however, nicknamed, too, then, xof, distracted,
# Nearest to two: three, four, six, one, seven, five, eight, nine,
# Nearest to also: now, often, still, which, sometimes, actually, commonly, usually,
# Nearest to people: men, women, those, individuals, children, critics, jews, prison,
# Nearest to in: during, until, within, at, on, since, throughout, thorndike,
# Nearest to more: less, most, very, quite, suffocation, yellowstone, rather, greater,
# Average loss at step 82000: 3.406206
# Average loss at step 84000: 3.413116
# Average loss at step 86000: 3.391078
# Average loss at step 88000: 3.352164
# Average loss at step 90000: 3.364667
# Nearest to eight: seven, nine, six, four, five, three, zero, two,
# Nearest to they: we, he, there, you, she, it, resonated, these,
# Nearest to his: her, their, its, my, your, our, the, s,
# Nearest to only: still, always, excessive, impersonal, nothing, decreasing, either, minute,
# Nearest to many: several, some, various, these, all, numerous, most, those,
# Nearest to war: battle, during, distinguishes, wars, comparisons, gendarmerie, skylab, hyksos,
# Nearest to with: between, by, mitford, containing, including, in, jn, for,
# Nearest to history: list, retold, encyclopedia, hardship, eubulides, leadership, tradition, biomechanics,
# Nearest to united: southern, border, modularity, jesuits, paullus, petrel, berlusconi, whole,
# Nearest to states: kingdom, nations, us, state, cretians, parliament, subcultures, songbook,
# Nearest to so: if, before, thus, too, however, xof, bosom, contraindicated,
# Nearest to two: three, four, five, seven, six, eight, one, nine,
# Nearest to also: now, often, still, which, never, sometimes, typically, generally,
# Nearest to people: women, men, children, individuals, those, jews, prison, person,
# Nearest to in: during, within, of, throughout, until, on, tamil, at,
# Nearest to more: less, most, quite, very, rather, greater, suffocation, yellowstone,
# Average loss at step 92000: 3.396822
# Average loss at step 94000: 3.249016
# Average loss at step 96000: 3.358274
# Average loss at step 98000: 3.239521
# Average loss at step 100000: 3.358254
# Nearest to eight: seven, nine, six, four, five, three, zero, two,
# Nearest to they: we, he, you, there, she, it, i, resonated,
# Nearest to his: her, their, my, its, your, our, the, s,
# Nearest to only: areal, never, impersonal, nothing, still, not, always, decreasing,
# Nearest to many: several, some, these, numerous, various, all, those, most,
# Nearest to war: battle, wars, behalf, distinguishes, gendarmerie, hyksos, vytautas, during,
# Nearest to with: between, babe, pearson, into, including, resembling, in, randomization,
# Nearest to history: list, encyclopedia, because, advent, ferromagnetism, retold, kafka, breakdowns,
# Nearest to united: southern, border, modularity, paullus, jesuits, senate, berlusconi, petrel,
# Nearest to states: kingdom, nations, state, us, subcultures, cretians, songbook, peas,
# Nearest to so: too, then, sometimes, thus, if, acclaim, dramatically, something,
# Nearest to two: four, three, six, five, seven, one, eight, zero,
# Nearest to also: now, often, never, still, sometimes, typically, actually, which,
# Nearest to people: women, children, men, individuals, those, jews, persons, fans,
# Nearest to in: during, within, on, throughout, until, at, among, tamil,
# Nearest to more: less, most, very, suffocation, quite, greater, rather, larger,

# %%
print(final_embeddings[0])
# Out:
# [-0.02236783 -0.00856482  0.14151928  0.00142983 -0.08813709  0.0371697
#  -0.16256756  0.05899677  0.05635297 -0.00036356 -0.07002161 -0.14685266
#   0.10754368  0.11081039 -0.06511801 -0.04824754  0.06803522  0.00238673
#  -0.14257695 -0.03679403  0.01010485 -0.1187129  -0.0037905  -0.23021843
#  -0.11251624 -0.09210294 -0.04170579  0.02193638  0.06335948 -0.0106806
#   0.02939821 -0.02070291 -0.00081957 -0.0103541  -0.16245703 -0.01667832
#   0.12022129  0.08760705  0.08245579 -0.04636744 -0.02029429 -0.00960511
#  -0.01018201 -0.02012339 -0.01055317 -0.03562591 -0.09671783  0.00052137
#  -0.12368896  0.09812414  0.0078066   0.08710313  0.04820275 -0.02888388
#  -0.07246662 -0.11465042  0.08133673  0.09469073 -0.0118607   0.04555146
#  -0.17484149  0.04208081 -0.05482872 -0.12971796  0.01167071  0.0116735
#  -0.01347792 -0.24251568  0.12039354  0.13579859 -0.04866121  0.06213858
#  -0.01606924 -0.07955925  0.04276262 -0.11623266  0.03208253 -0.0137078
#   0.02236322 -0.0625276  -0.13269146 -0.02079494 -0.06412609 -0.04535169
#   0.00381023 -0.06812228  0.00621664 -0.06365769  0.1125019   0.02969307
#  -0.07147057  0.17059895  0.00965084  0.28073844  0.03250276 -0.03178148
#   0.03007846  0.1353697   0.15197136 -0.10633573  0.01264774  0.04938465
#   0.07465504 -0.03876068  0.097364   -0.02286502  0.03841389  0.0072057
#   0.04230577  0.13964354 -0.07305004 -0.06148133  0.05081386  0.08633043
#   0.02220013 -0.11501989 -0.02185179  0.07169975  0.14034754  0.15197423
#   0.02009286 -0.03721266  0.14281802  0.06748194 -0.04640419  0.19221029
#  -0.09285414 -0.15725552]

# %%
print(np.sum(np.square(final_embeddings[0])))
# Out:
# 1.0

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    # just for testing
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    # iterate to the next buffer
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
  data_index = 0
  batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
  print('\nwith bag_window = %d:' % (bag_window))  
  print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
###skip_window = 1 # How many words to consider left and right.
###num_skips = 2 # How many times to reuse an input to generate a label.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embeds, 1),
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.955592
# Nearest to years: ziv, displeased, piecewise, conic, trichomes, rijndael, representative, unanswered,
# Nearest to if: ver, gish, parishioners, oxidizing, favour, conditions, alternative, substantially,
# Nearest to and: gegen, merchandising, raw, claudius, unitarian, theobromine, nasi, huber,
# Nearest to some: rulings, cheaply, stromata, maurya, pampas, cognitivism, palo, cystic,
# Nearest to are: maneuverable, karaites, rapidity, englewood, portfolios, edged, rond, mikoto,
# Nearest to than: killer, chandler, affliction, heisenberg, coterminous, nicely, go, shattering,
# Nearest to they: northamptonshire, couch, victories, linguistic, rawlinson, swamps, distraught, aides,
# Nearest to he: bypass, princeto, weeks, curds, pentecost, gesellschaft, unconsciously, bioterrorism,
# Nearest to known: devanagari, cahn, staircase, makkah, excommunication, ucs, prefaced, aoe,
# Nearest to their: orang, humberto, overrun, jama, ensuing, australopithecus, lyman, access,
# Nearest to over: fittingly, monsignor, yehudi, ticketing, levantine, fethry, bleak, calvino,
# Nearest to zero: gurus, ducts, imitative, withstand, imprints, sloane, cynic, transsexual,
# Nearest to five: spotlight, atc, phosphoric, adowa, perennially, eigenvalues, playwright, curly,
# Nearest to will: abbotsford, sumner, detail, uvular, palmas, prevailed, reagents, fell,
# Nearest to of: mycobacterium, engendered, hz, ize, troupe, harriet, bahn, wyman,
# Nearest to from: zfc, dictate, harwood, scarcity, ferroelectric, elevate, thomson, petrarch,
# Average loss at step 2000: 8.797985
# Average loss at step 4000: 5.622428
# Average loss at step 6000: 4.414235
# Average loss at step 8000: 4.604771
# Average loss at step 10000: 3.921084
# Nearest to years: dynasty, alpha, rally, centauri, ambergris, phyla, star, will,
# Nearest to if: teleplay, nanotubes, gaining, fuerteventura, jacques, rix, aerobatic, when,
# Nearest to and: or, but, horde, ifor, bette, clades, sakharov, edifice,
# Nearest to some: many, several, these, other, bolger, those, most, swivel,
# Nearest to are: were, is, rt, rapidity, unwillingness, restraints, include, was,
# Nearest to than: or, panamanian, minos, likely, aron, kneel, corpses, hmong,
# Nearest to they: we, he, you, who, repetitive, there, she, occultist,
# Nearest to he: she, it, they, who, progress, laine, mugwort, architectures,
# Nearest to known: javascript, used, roused, devanagari, gangs, jamaicans, prefaced, dcsd,
# Nearest to their: his, its, her, seinfeld, thou, orang, sucks, the,
# Nearest to over: boito, during, levantine, bongo, few, fittingly, into, kills,
# Nearest to zero: five, nine, atheists, seven, aquarii, galaxy, four, cavities,
# Nearest to five: seven, racing, http, m, www, centauri, alpha, will,
# Nearest to will: centauri, racing, alpha, www, phyla, breeds, waved, http,
# Nearest to of: in, formula, phyla, denying, alpha, literal, racing, prayer,
# Nearest to from: alpha, centauri, racing, beta, www, will, http, waved,
# Average loss at step 12000: 4.341957
# Average loss at step 14000: 3.949663
# Average loss at step 16000: 4.049697
# Average loss at step 18000: 3.628780
# Average loss at step 20000: 3.568869
# Nearest to years: days, months, year, injector, equalize, centuries, dixit, equivocation,
# Nearest to if: when, where, though, nanotubes, quin, that, nostrand, while,
# Nearest to and: while, or, ifor, when, contralto, wharf, redundant, sakharov,
# Nearest to some: many, several, various, those, all, most, different, any,
# Nearest to are: were, is, include, was, cretian, being, have, impetuous,
# Nearest to than: likely, but, angelina, breeds, mythology, bavarian, tdma, literal,
# Nearest to they: it, asset, angelina, run, voight, bavarian, home, tdma,
# Nearest to he: she, who, it, conclusive, leftists, almoravides, chamorros, quotations,
# Nearest to known: used, javascript, referred, described, regarded, seen, such, considered,
# Nearest to their: its, his, the, her, trapper, our, seinfeld, historicism,
# Nearest to over: thoroughly, breeds, asset, cdma, centauri, snow, cavities, softly,
# Nearest to zero: five, eight, seven, two, enix, crumbs, six, kk,
# Nearest to five: zero, six, four, eight, seven, pejoratively, two, unconfirmed,
# Nearest to will: would, can, may, could, must, should, might, cannot,
# Nearest to of: for, altos, punjabi, unadorned, tainted, like, hanafi, screwtape,
# Nearest to from: into, through, fang, topple, towards, eugenicists, gg, supers,
# Average loss at step 22000: 3.629584
# Average loss at step 24000: 3.687446
# Average loss at step 26000: 3.507508
# Average loss at step 28000: 3.584990
# Average loss at step 30000: 3.529735
# Nearest to years: days, year, centuries, months, decades, hoboken, injector, thousand,
# Nearest to if: when, because, though, where, whether, before, urraca, intelligibility,
# Nearest to and: or, although, while, but, including, against, with, sakharov,
# Nearest to some: many, several, various, all, those, these, different, most,
# Nearest to are: were, is, was, include, have, produce, cretian, became,
# Nearest to than: but, or, minos, however, durango, panamanian, although, accountants,
# Nearest to they: we, you, there, these, he, cayuga, microinstruction, assimilation,
# Nearest to he: it, she, they, panza, who, monteverdi, inexpensively, almoravides,
# Nearest to known: regarded, referred, described, seen, used, javascript, defined, classified,
# Nearest to their: its, his, her, the, my, other, remarry, your,
# Nearest to over: through, around, in, throughout, across, bongo, inroads, during,
# Nearest to zero: five, six, eight, three, seven, four, molality, proliferate,
# Nearest to five: six, three, seven, eight, four, zero, academies, mathilde,
# Nearest to will: would, can, could, may, must, should, might, cannot,
# Nearest to of: like, in, among, screwtape, throughout, jud, during, czarist,
# Nearest to from: into, through, across, topple, fang, vald, toward, bridal,
# Average loss at step 32000: 3.279380
# Average loss at step 34000: 3.315828
# Average loss at step 36000: 3.286907
# Average loss at step 38000: 3.346992
# Average loss at step 40000: 3.400047
# Nearest to years: days, months, decades, year, minutes, centuries, times, stages,
# Nearest to if: where, though, when, since, because, therefore, although, however,
# Nearest to and: or, while, including, although, sakharov, orchard, allowable, snap,
# Nearest to some: many, several, various, both, numerous, other, preludes, most,
# Nearest to are: were, is, include, was, unwillingness, lucian, amway, cretian,
# Nearest to than: or, but, fallout, panamanian, durango, much, slogans, robespierre,
# Nearest to they: we, you, he, there, disallowed, botanic, sextus, hibiscus,
# Nearest to he: she, it, they, monteverdi, longbowmen, panza, notch, almoravides,
# Nearest to known: referred, regarded, defined, described, used, such, seen, classified,
# Nearest to their: his, its, her, our, my, your, the, patrilineal,
# Nearest to over: around, across, under, between, joker, at, throughout, bongo,
# Nearest to zero: five, seven, eight, six, four, three, medlineplus, two,
# Nearest to five: six, four, seven, eight, three, nine, zero, slur,
# Nearest to will: would, should, may, must, could, can, cannot, might,
# Nearest to of: throughout, dolphins, concerning, unadorned, eglise, mandelstam, among, justifying,
# Nearest to from: into, through, including, across, beyond, topple, within, eugenicists,
# Average loss at step 42000: 3.345903
# Average loss at step 44000: 3.257191
# Average loss at step 46000: 3.258576
# Average loss at step 48000: 3.139757
# Average loss at step 50000: 3.156398
# Nearest to years: days, decades, months, year, weeks, minutes, centuries, times,
# Nearest to if: where, when, though, because, while, although, since, canonized,
# Nearest to and: or, while, but, including, allowable, although, when, sakharov,
# Nearest to some: many, various, certain, several, these, any, numerous, all,
# Nearest to are: were, is, exist, was, have, include, consultancy, being,
# Nearest to than: much, or, but, celebrates, likely, distant, panamanian, aron,
# Nearest to they: we, you, he, there, she, sextus, notch, piedmont,
# Nearest to he: she, it, they, who, monteverdi, emphatically, liquidation, kathy,
# Nearest to known: referred, defined, used, regarded, described, such, classified, seen,
# Nearest to their: its, his, our, her, your, the, my, patrilineal,
# Nearest to over: across, around, under, through, off, unskilled, contravariant, wahid,
# Nearest to zero: eight, six, seven, nine, corrosive, enclose, manly, two,
# Nearest to five: seven, four, eight, three, six, nine, tau, cp,
# Nearest to will: would, could, must, should, may, might, can, cannot,
# Nearest to of: including, justifying, unadorned, mycobacterium, in, for, among, remit,
# Nearest to from: through, into, beyond, within, without, in, towards, onto,
# Average loss at step 52000: 3.183398
# Average loss at step 54000: 3.211696
# Average loss at step 56000: 2.988940
# Average loss at step 58000: 3.087200
# Average loss at step 60000: 3.133886
# Nearest to years: days, months, decades, weeks, minutes, year, centuries, times,
# Nearest to if: when, though, although, where, before, while, since, whether,
# Nearest to and: while, but, although, or, including, petn, sakharov, viper,
# Nearest to some: many, various, several, all, both, few, numerous, affection,
# Nearest to are: were, is, was, include, exist, contain, have, unwillingness,
# Nearest to than: but, axel, panamanian, or, mico, fallout, durango, humiliation,
# Nearest to they: we, you, he, she, there, bearings, piedmont, these,
# Nearest to he: she, it, they, who, inexpensively, dih, panza, radiosity,
# Nearest to known: used, seen, described, referred, regarded, defined, such, employed,
# Nearest to their: its, his, her, our, the, your, whose, my,
# Nearest to over: across, around, under, bavarians, softly, through, drastic, throughout,
# Nearest to zero: seven, five, four, eight, six, million, nine, three,
# Nearest to five: six, four, seven, eight, three, zero, nine, two,
# Nearest to will: would, must, may, can, could, should, might, does,
# Nearest to of: altos, remit, obsessive, justifying, including, against, for, panics,
# Nearest to from: into, through, within, onto, fang, toward, vald, beyond,
# Average loss at step 62000: 3.103462
# Average loss at step 64000: 2.996051
# Average loss at step 66000: 3.028158
# Average loss at step 68000: 3.061778
# Average loss at step 70000: 3.107037
# Nearest to years: days, months, decades, weeks, year, minutes, centuries, decade,
# Nearest to if: though, when, while, although, where, nevertheless, thus, let,
# Nearest to and: or, but, including, although, sakharov, when, while, however,
# Nearest to some: many, several, various, all, numerous, certain, those, sanguine,
# Nearest to are: were, is, include, was, exist, contain, unwillingness, have,
# Nearest to than: or, but, fallout, much, durango, slogans, unlike, mico,
# Nearest to they: we, you, he, she, muskets, others, there, viruses,
# Nearest to he: she, it, they, taito, accompanying, almoravides, panza, notch,
# Nearest to known: referred, regarded, described, seen, defined, used, such, classified,
# Nearest to their: its, his, her, your, our, both, the, my,
# Nearest to over: across, under, beyond, through, within, inroads, around, exclusive,
# Nearest to zero: five, two, eight, three, six, seven, medlineplus, million,
# Nearest to five: six, seven, four, three, eight, two, zero, decadent,
# Nearest to will: could, must, may, should, might, can, would, cannot,
# Nearest to of: throughout, justifying, in, including, for, bckgr, mycobacterium, affidavit,
# Nearest to from: since, into, through, onto, fang, within, beyond, ascendant,
# Average loss at step 72000: 3.019723
# Average loss at step 74000: 2.920386
# Average loss at step 76000: 3.057012
# Average loss at step 78000: 3.232741
# Average loss at step 80000: 3.205985
# Nearest to years: decades, months, days, minutes, weeks, year, centuries, times,
# Nearest to if: when, though, although, where, unless, perhaps, because, why,
# Nearest to and: or, etc, while, including, but, like, though, sakharov,
# Nearest to some: many, several, various, numerous, certain, all, both, most,
# Nearest to are: were, is, was, contain, exist, have, remain, homeworld,
# Nearest to than: consonants, cable, breeds, lambert, buffalo, m, angelina, frame,
# Nearest to they: you, we, he, she, there, i, bearings, wittelsbach,
# Nearest to he: she, it, they, cantor, notch, panza, inexpensively, who,
# Nearest to known: referred, regarded, described, used, defined, seen, classified, opposed,
# Nearest to their: its, his, her, your, our, my, the, patrilineal,
# Nearest to over: around, drastic, within, through, throughout, about, exclusive, bongo,
# Nearest to zero: frame, consonants, cable, fractal, conference, angelina, centauri, class,
# Nearest to five: four, three, eight, six, seven, nine, deadline, boldsymbol,
# Nearest to will: would, could, must, might, can, may, should, cannot,
# Nearest to of: in, justifying, including, altos, remit, aryabhata, eglise, hanafi,
# Nearest to from: through, into, within, onto, since, gg, fang, towards,
# Average loss at step 82000: 3.043295
# Average loss at step 84000: 2.996804
# Average loss at step 86000: 2.987147
# Average loss at step 88000: 3.015757
# Average loss at step 90000: 2.900379
# Nearest to years: decades, months, weeks, days, year, minutes, centuries, decade,
# Nearest to if: when, though, where, unless, because, thus, before, whether,
# Nearest to and: or, while, but, including, although, though, etc, however,
# Nearest to some: many, several, numerous, various, all, most, certain, both,
# Nearest to are: were, is, exist, was, include, have, contain, militiamen,
# Nearest to than: or, but, durango, unlike, and, distant, fallout, composite,
# Nearest to they: we, you, he, there, she, horses, it, bearings,
# Nearest to he: she, it, they, cantor, radiosity, inexpensively, almoravides, panza,
# Nearest to known: referred, regarded, described, used, defined, seen, opposed, classified,
# Nearest to their: its, his, your, her, my, our, airborne, ciprofloxacin,
# Nearest to over: around, within, across, through, beyond, throughout, premieres, contravariant,
# Nearest to zero: eight, five, seven, six, nine, tzow, four, million,
# Nearest to five: four, six, eight, three, seven, zero, utf, chiles,
# Nearest to will: would, could, might, should, can, may, cannot, shall,
# Nearest to of: in, justifying, for, regarding, basileus, within, pitts, affidavit,
# Nearest to from: into, through, fang, onto, vald, under, toward, during,
# Average loss at step 92000: 2.944899
# Average loss at step 94000: 2.947221
# Average loss at step 96000: 2.956591
# Average loss at step 98000: 2.603743
# Average loss at step 100000: 2.767052
# Nearest to years: months, decades, days, weeks, year, minutes, centuries, versions,
# Nearest to if: when, though, perhaps, indeed, kifl, nevertheless, therefore, stats,
# Nearest to and: or, but, while, although, including, however, though, versus,
# Nearest to some: many, various, several, both, numerous, certain, most, all,
# Nearest to are: were, is, exist, was, include, have, remain, exists,
# Nearest to than: or, but, durango, fallout, like, composite, stella, salah,
# Nearest to they: we, he, you, she, there, eos, these, horses,
# Nearest to he: she, it, they, who, initially, panza, liquors, inexpensively,
# Nearest to known: referred, seen, regarded, described, defined, used, opposed, perceived,
# Nearest to their: its, his, her, your, our, my, these, the,
# Nearest to over: around, across, off, throughout, beyond, within, about, contravariant,
# Nearest to zero: eight, four, five, six, nine, million, seven, children,
# Nearest to five: four, six, seven, three, eight, zero, two, nine,
# Nearest to will: would, should, might, could, can, may, must, shall,
# Nearest to of: tactician, justifying, affidavit, in, represents, remit, jud, mazes,
# Nearest to from: into, toward, fang, through, vald, under, onto, across,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# Some clusters are less obvious (like the standalone characters), but it clearly totaly works.

# %% [markdown]
# How does your CBOW model perform compared to the given Word2Vec model? (to be answered)
