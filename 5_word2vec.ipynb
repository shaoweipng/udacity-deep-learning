# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
print(data[:10])
print(count[:10])
print(dictionary.items()[:10])
print(reverse_dictionary.items()[:10])
# Out:
# [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]
# [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764), ('in', 372201), ('a', 325873), ('to', 316376), ('zero', 264975), ('nine', 250430)]
# [('fawn', 45848), ('homomorphism', 9648), ('nordisk', 39343), ('nunnery', 36075), ('chthonic', 33554), ('sowell', 40562), ('sonja', 38175), ('showa', 32906), ('woods', 6263), ('hsv', 44222)]
# [(0, 'UNK'), (1, 'the'), (2, 'of'), (3, 'and'), (4, 'one'), (5, 'in'), (6, 'a'), (7, 'to'), (8, 'zero'), (9, 'nine')]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:32]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=16, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(16)])
    
for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 1
    batch, labels = generate_batch(batch_size=16, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(16)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'UNK', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term', 'of', 'of', 'abuse', 'abuse', 'first', 'first', 'used', 'used']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'a', 'of', 'abuse', 'term', 'of', 'first', 'abuse', 'used', 'first', 'against']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a', 'term', 'term', 'term', 'term', 'of', 'of', 'of', 'of']
#     labels: ['anarchism', 'originated', 'a', 'term', 'as', 'term', 'originated', 'of', 'as', 'abuse', 'of', 'a', 'abuse', 'a', 'first', 'term']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['as', 'as', 'a', 'a', 'term', 'term', 'of', 'of', 'abuse', 'abuse', 'first', 'first', 'used', 'used', 'against', 'against']
#     labels: ['a', 'originated', 'term', 'as', 'a', 'of', 'term', 'abuse', 'of', 'first', 'used', 'abuse', 'first', 'against', 'early', 'used']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['a', 'a', 'a', 'a', 'term', 'term', 'term', 'term', 'of', 'of', 'of', 'of', 'abuse', 'abuse', 'abuse', 'abuse']
#     labels: ['term', 'as', 'of', 'originated', 'a', 'as', 'abuse', 'of', 'term', 'first', 'abuse', 'a', 'term', 'of', 'first', 'used']

# %% [markdown]
# Note: the labels is a sliding random value of the word surrounding the words of the batch.

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.127973
# Nearest to time: bombs, anthropomorphism, gomoku, colossal, environment, louisiana, synge, reconciling,
# Nearest to about: exchanged, coppa, hervey, instrumentals, defection, freaks, egoism, rpp,
# Nearest to they: eugenicist, frideric, mechanism, patmos, sprache, sith, assimilate, presumes,
# Nearest to UNK: guppy, kipling, agonist, mothra, crowell, reprinting, edited, ecclesiastics,
# Nearest to zero: elimination, landlord, wry, inspiration, millicent, adequacy, eagerly, agathocles,
# Nearest to there: dubois, rank, flowers, pilgrimage, intersections, raleigh, foix, judaizers,
# Nearest to has: september, marvel, nair, famous, photonic, updating, manzarek, farmland,
# Nearest to new: flicker, moro, berber, mont, innovative, imagined, arrears, hellboy,
# Nearest to eight: unaffected, motte, brave, zealot, boulez, equivalent, monteverdi, nightlife,
# Nearest to first: counts, correspondence, crookes, terra, bonn, scriptwriter, projectiles, flavia,
# Nearest to history: criminality, bsa, conspiracies, poses, postures, presses, scale, casing,
# Nearest to for: mathbb, ingeborg, darkened, plays, less, env, rcn, detects,
# Nearest to more: olfactory, smoothed, res, weekend, properties, pilot, wasting, eschatological,
# Nearest to most: adjusting, yoreh, peru, meltzer, fh, serre, potomac, must,
# Nearest to four: haydn, hrvatska, oses, ethnocentric, slugs, te, stanton, dug,
# Nearest to been: rohmer, freie, valid, circumcised, lading, glamour, revolted, aegeus,
# Average loss at step 2000: 4.353592
# Average loss at step 4000: 3.859794
# Average loss at step 6000: 3.789451
# Average loss at step 8000: 3.684437
# Average loss at step 10000: 3.609789
# Nearest to time: environment, millimetre, portals, topographical, gpp, vincendeau, objected, hope,
# Nearest to about: coppa, rosebud, cogito, instrumentals, typically, exchanged, hervey, defection,
# Nearest to they: he, i, it, there, not, tethys, who, we,
# Nearest to UNK: dowry, palliative, eurasian, foals, verbs, bison, cofinality, links,
# Nearest to zero: five, nine, eight, four, three, six, seven, two,
# Nearest to there: it, he, they, flowers, usually, often, rejects, raleigh,
# Nearest to has: had, have, is, was, synaptic, ipx, karamanlis, marvel,
# Nearest to new: sterilization, imagined, democratic, alexandrians, innovative, flicker, beauties, gr,
# Nearest to eight: nine, six, five, seven, four, three, zero, two,
# Nearest to first: counts, cytosol, flavia, projectiles, scriptwriter, iris, correspondence, djs,
# Nearest to history: dwells, woolwich, presses, bsa, dib, deutschlands, crushes, stopover,
# Nearest to for: rupture, of, in, detects, groupoid, and, christus, repentance,
# Nearest to more: properties, partly, tudor, vanished, enjoys, smoothed, trends, heroine,
# Nearest to most: peru, some, invulnerable, positional, potomac, hornblower, compounds, infantile,
# Nearest to four: three, six, five, seven, eight, nine, two, zero,
# Nearest to been: kaifu, ensemble, had, berth, was, specializes, ideally, ker,
# Average loss at step 12000: 3.607633
# Average loss at step 14000: 3.564987
# Average loss at step 16000: 3.406680
# Average loss at step 18000: 3.457967
# Average loss at step 20000: 3.539370
# Nearest to time: millimetre, vincendeau, portals, objected, year, reason, environment, topographical,
# Nearest to about: coppa, typically, cogito, hervey, dame, citric, rosebud, check,
# Nearest to they: he, we, there, it, who, you, i, not,
# Nearest to UNK: deuterocanonical, confocal, silos, severn, pamela, crocker, jagiellon, rightarrow,
# Nearest to zero: six, five, seven, nine, four, eight, three, two,
# Nearest to there: it, they, he, often, usually, flowers, also, asteroids,
# Nearest to has: had, was, have, is, cryptographers, admirer, synaptic, kitchener,
# Nearest to new: sterilization, imagined, democratic, angiotensin, striking, beauties, anthropomorphic, judgment,
# Nearest to eight: seven, nine, four, six, five, three, two, zero,
# Nearest to first: last, second, counts, zurich, iris, thirty, scriptwriter, edirne,
# Nearest to history: development, dib, khaled, woolwich, dwells, westernmost, stopover, frederik,
# Nearest to for: by, of, with, than, plays, or, poignant, tegmark,
# Nearest to more: less, very, most, partly, heroine, vanished, valves, tudor,
# Nearest to most: some, peru, more, many, fallopian, espagnole, hornblower, compounds,
# Nearest to four: six, eight, three, seven, five, two, nine, zero,
# Nearest to been: be, kaifu, was, were, become, fined, ideally, had,
# Average loss at step 22000: 3.503924
# Average loss at step 24000: 3.490738
# Average loss at step 26000: 3.478462
# Average loss at step 28000: 3.479164
# Average loss at step 30000: 3.504354
# Nearest to time: millimetre, vincendeau, reason, objected, year, portals, incentives, topographical,
# Nearest to about: next, abnormalities, typically, coppa, graphemes, cogito, check, leonidas,
# Nearest to they: we, there, he, you, it, not, who, these,
# Nearest to UNK: intersex, rightarrow, peritoneum, amino, minestrone, slaying, hada, ari,
# Nearest to zero: five, seven, eight, four, three, six, nine, two,
# Nearest to there: they, it, he, usually, often, we, still, this,
# Nearest to has: had, have, was, is, tippit, admirer, civitas, mauro,
# Nearest to new: judgment, jacobitism, angiotensin, imagined, discontinuous, vikrant, anthropomorphic, sterilization,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to first: last, second, next, iris, ghibellines, same, zurich, satisfy,
# Nearest to history: development, frederik, clav, management, khaled, westernmost, inositol, dib,
# Nearest to for: against, when, while, than, of, pumice, after, filioque,
# Nearest to more: less, very, most, rather, greater, tudor, better, vanished,
# Nearest to most: some, more, many, among, peru, hornblower, fallopian, espagnole,
# Nearest to four: five, six, three, eight, seven, two, nine, zero,
# Nearest to been: was, become, be, fined, kaifu, already, had, arrange,
# Average loss at step 32000: 3.502038
# Average loss at step 34000: 3.494244
# Average loss at step 36000: 3.454671
# Average loss at step 38000: 3.297057
# Average loss at step 40000: 3.429942
# Nearest to time: millimetre, vincendeau, period, year, reason, incentives, ehr, way,
# Nearest to about: pasting, on, britten, kitty, cogito, abnormalities, typically, hervey,
# Nearest to they: we, there, he, you, it, i, not, who,
# Nearest to UNK: dr, d, guppy, goaltender, fruity, v, kipling, shirt,
# Nearest to zero: five, seven, nine, eight, six, three, four, two,
# Nearest to there: they, it, he, usually, often, these, schoolboy, we,
# Nearest to has: had, have, is, was, tippit, dual, invincible, since,
# Nearest to new: judgment, majority, beauties, democratic, imagined, ngel, discontinuous, sterilization,
# Nearest to eight: nine, seven, six, five, four, three, zero, one,
# Nearest to first: second, last, next, iris, satisfy, ghibellines, scriptwriter, same,
# Nearest to history: management, inositol, westernmost, clav, macbook, development, architecture, list,
# Nearest to for: by, filioque, while, when, including, in, weinstein, against,
# Nearest to more: less, most, very, greater, rather, garnering, better, hundredth,
# Nearest to most: more, among, some, heads, many, luftwaffe, hornblower, espagnole,
# Nearest to four: six, five, seven, three, eight, two, nine, one,
# Nearest to been: become, be, was, already, kaifu, fined, were, arrange,
# Average loss at step 42000: 3.440684
# Average loss at step 44000: 3.455560
# Average loss at step 46000: 3.450720
# Average loss at step 48000: 3.353159
# Average loss at step 50000: 3.384271
# Nearest to time: year, vincendeau, objected, period, downplay, incentives, ravine, invitational,
# Nearest to about: pasting, on, hervey, alright, britten, kn, capitalised, kitty,
# Nearest to they: there, he, we, it, you, she, these, who,
# Nearest to UNK: denounces, et, humphrey, rightarrow, itosu, infidel, ramsey, hada,
# Nearest to zero: five, seven, eight, four, six, nine, three, two,
# Nearest to there: they, it, he, we, these, usually, often, this,
# Nearest to has: had, have, was, is, since, contains, tippit, makes,
# Nearest to new: majority, discontinuous, democratic, reddish, judgment, second, corvette, birger,
# Nearest to eight: six, nine, seven, four, five, three, zero, one,
# Nearest to first: second, last, next, pomp, iris, same, zurich, emilia,
# Nearest to history: list, clav, management, summary, heads, cohen, suppressive, usaf,
# Nearest to for: while, including, against, psi, filioque, of, by, obfuscation,
# Nearest to more: less, most, very, greater, rather, highly, garnering, longer,
# Nearest to most: more, less, some, many, among, fallopian, espagnole, blatantly,
# Nearest to four: six, eight, seven, five, three, nine, zero, two,
# Nearest to been: become, be, already, were, was, had, kaifu, fined,
# Average loss at step 52000: 3.432556
# Average loss at step 54000: 3.429435
# Average loss at step 56000: 3.438882
# Average loss at step 58000: 3.393606
# Average loss at step 60000: 3.392941
# Nearest to time: year, period, vincendeau, incentives, number, reason, downplay, objected,
# Nearest to about: hervey, on, britten, qe, pasting, madrigal, that, next,
# Nearest to they: we, there, he, you, she, i, it, these,
# Nearest to UNK: picturesque, e, et, walloon, alexius, lump, abu, upwards,
# Nearest to zero: five, four, eight, six, seven, nine, three, two,
# Nearest to there: it, they, we, he, now, usually, still, schoolboy,
# Nearest to has: had, have, was, is, roundel, contains, tippit, obsidian,
# Nearest to new: discontinuous, reddish, krzy, separate, conjoined, visicalc, greatest, majority,
# Nearest to eight: nine, six, seven, four, five, three, zero, one,
# Nearest to first: last, second, next, iris, ghibellines, same, pomp, youngest,
# Nearest to history: list, clav, westernmost, axioms, tecumseh, katakana, settlement, options,
# Nearest to for: of, including, when, filioque, tiled, while, against, pumice,
# Nearest to more: less, most, very, greater, rather, longer, better, larger,
# Nearest to most: more, many, some, less, among, use, luftwaffe, heads,
# Nearest to four: six, five, eight, seven, three, nine, zero, two,
# Nearest to been: become, be, was, were, fined, already, grossly, arrange,
# Average loss at step 62000: 3.236481
# Average loss at step 64000: 3.257824
# Average loss at step 66000: 3.405594
# Average loss at step 68000: 3.391221
# Average loss at step 70000: 3.358309
# Nearest to time: vincendeau, year, downplay, incentives, period, planing, before, night,
# Nearest to about: qe, hervey, britten, on, over, alright, madrigal, next,
# Nearest to they: we, there, he, you, it, she, soon, i,
# Nearest to UNK: df, fortress, imac, colorful, server, buoyancy, denounces, raleigh,
# Nearest to zero: five, eight, four, six, seven, nine, three, two,
# Nearest to there: they, it, we, still, he, usually, now, this,
# Nearest to has: had, have, is, was, contains, since, roundel, refueling,
# Nearest to new: sterilization, separate, bijective, iranians, ngel, beauties, reddish, thin,
# Nearest to eight: nine, six, seven, five, four, zero, three, one,
# Nearest to first: last, second, next, ghibellines, same, original, iris, best,
# Nearest to history: list, inositol, tecumseh, harmala, clav, jasmine, junit, serenity,
# Nearest to for: in, including, while, against, to, tiled, weinstein, without,
# Nearest to more: less, most, very, rather, greater, fairly, better, too,
# Nearest to most: more, less, many, some, all, among, espagnole, repellent,
# Nearest to four: five, six, three, seven, eight, nine, zero, two,
# Nearest to been: become, be, was, already, were, fined, had, arrange,
# Average loss at step 72000: 3.375056
# Average loss at step 74000: 3.348759
# Average loss at step 76000: 3.316964
# Average loss at step 78000: 3.349428
# Average loss at step 80000: 3.382477
# Nearest to time: year, incentives, period, vincendeau, codices, curiosities, week, issue,
# Nearest to about: qe, approximately, alright, britten, over, ezek, hervey, glastonbury,
# Nearest to they: we, there, he, you, she, it, soon, who,
# Nearest to UNK: rightarrow, mo, smith, pedro, vii, j, tikal, pastor,
# Nearest to zero: five, six, four, seven, eight, three, nine, two,
# Nearest to there: they, it, he, we, still, usually, now, she,
# Nearest to has: had, have, is, was, tippit, since, contains, constitutionally,
# Nearest to new: jacobitism, cinematic, modern, uniform, beauties, caste, dsn, promo,
# Nearest to eight: nine, six, seven, five, four, three, zero, one,
# Nearest to first: second, last, next, ghibellines, third, same, iris, youngest,
# Nearest to history: list, pedestal, jasmine, harmala, serenity, inositol, memo, junit,
# Nearest to for: filioque, against, bj, psi, sauce, including, sem, naturalists,
# Nearest to more: less, most, very, rather, fairly, longer, greater, too,
# Nearest to most: more, less, many, some, among, particularly, especially, espagnole,
# Nearest to four: five, six, seven, three, eight, nine, two, zero,
# Nearest to been: become, be, was, were, already, had, being, fined,
# Average loss at step 82000: 3.404113
# Average loss at step 84000: 3.411709
# Average loss at step 86000: 3.385653
# Average loss at step 88000: 3.352199
# Average loss at step 90000: 3.364162
# Nearest to time: year, period, vincendeau, incentives, before, gpp, week, downplay,
# Nearest to about: hervey, qe, justified, britten, glastonbury, farouk, over, clearance,
# Nearest to they: we, there, he, you, it, she, soon, who,
# Nearest to UNK: triomphe, imac, rightarrow, droit, internetworking, australes, ces, berle,
# Nearest to zero: five, seven, eight, six, four, nine, three, two,
# Nearest to there: they, it, we, he, still, she, now, therefore,
# Nearest to has: had, have, is, was, since, having, tippit, contains,
# Nearest to new: ngel, jacobitism, particular, beauties, incongruous, gime, ethelbert, krzy,
# Nearest to eight: seven, six, nine, five, four, three, zero, two,
# Nearest to first: last, second, next, original, ghibellines, same, youngest, iris,
# Nearest to history: list, harmala, jasmine, clav, rden, study, junit, provider,
# Nearest to for: including, against, without, filioque, of, after, recounts, when,
# Nearest to more: less, rather, most, very, greater, longer, fairly, better,
# Nearest to most: more, many, less, some, particularly, among, especially, repellent,
# Nearest to four: five, seven, six, eight, three, two, nine, zero,
# Nearest to been: become, be, already, were, being, was, arrange, fined,
# Average loss at step 92000: 3.397696
# Average loss at step 94000: 3.252148
# Average loss at step 96000: 3.362064
# Average loss at step 98000: 3.241904
# Average loss at step 100000: 3.356410
# Nearest to time: year, before, ravine, incentives, week, period, person, isotope,
# Nearest to about: britten, hervey, glastonbury, approximately, qe, farouk, on, over,
# Nearest to they: we, there, he, you, she, it, soon, i,
# Nearest to UNK: pullman, aka, verbs, istanbul, lantern, cronos, demokratische, spader,
# Nearest to zero: five, four, eight, seven, six, nine, two, three,
# Nearest to there: they, he, we, it, still, now, she, often,
# Nearest to has: had, have, is, since, was, tippit, having, contains,
# Nearest to new: ngel, jacobitism, modern, different, conjoined, separate, incongruous, discontinuous,
# Nearest to eight: seven, nine, six, four, five, three, zero, two,
# Nearest to first: last, next, second, third, final, aura, fourth, iris,
# Nearest to history: list, junit, harmala, jasmine, pedestal, inositol, necronomicon, clav,
# Nearest to for: including, when, against, without, while, after, ottonian, tiled,
# Nearest to more: less, most, very, rather, greater, fairly, increasingly, longer,
# Nearest to most: more, less, particularly, especially, many, some, among, use,
# Nearest to four: six, five, seven, eight, three, two, nine, zero,
# Nearest to been: become, be, already, was, fined, being, were, arrange,

# %%
print(final_embeddings[0])
# Out:
# [-0.05044072 -0.11472618  0.03170871  0.05400586 -0.04069505 -0.0361454
#  -0.08909344  0.13328509  0.02190797 -0.12935932  0.08771294  0.08377367
#  -0.01499742  0.00945862  0.12100127 -0.08985902  0.10534949 -0.09125423
#  -0.04648095  0.05871138  0.00061244  0.09497651  0.07149646 -0.01442614
#  -0.02912923  0.08129456  0.22676374 -0.10790474  0.02466139  0.12319753
#  -0.18487802 -0.00558177  0.14012232 -0.10999315 -0.05499752 -0.0911789
#   0.01425692 -0.10829238 -0.01401763  0.01508473  0.05019482  0.04341686
#  -0.2020895  -0.05044213  0.04526621 -0.07365892  0.05406363  0.07236008
#   0.0493513  -0.04480172 -0.01312568  0.19775969 -0.09605264  0.0561785
#  -0.04198503 -0.02626059 -0.00381705 -0.01075246 -0.1511852  -0.0862326
#  -0.00872778 -0.11342725 -0.08870792 -0.1050343   0.00983872  0.0262969
#  -0.00917643  0.08543214  0.06168636 -0.02559471 -0.10556319  0.02109502
#  -0.02107925 -0.03614505  0.15347928 -0.04556167 -0.02381726 -0.06293302
#   0.06702171  0.0709466   0.10354734  0.02113965  0.03100396 -0.01536098
#  -0.05609775 -0.03686489 -0.01556769  0.27871892 -0.04494921 -0.06609853
#   0.03377858  0.07048806  0.01907509  0.03136148 -0.07129479 -0.041748
#  -0.19516799 -0.03371076  0.09186762  0.00878701 -0.08075396 -0.17190394
#  -0.02167791 -0.06920643  0.03184165 -0.06205663  0.06540538  0.09301068
#   0.00779737  0.11697906 -0.11394124 -0.03194354  0.11023831  0.13787007
#  -0.07639223  0.07347514 -0.14594468  0.07230791  0.10838111  0.06018478
#   0.00559025 -0.10830211  0.04154224 -0.13670605  0.01161412  0.12545685
#  -0.1131274   0.19052856]

# %%
print(np.sum(np.square(final_embeddings[0])))
# Out:
# 1.0

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    # just for testing
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    # iterate to the next buffer
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
  data_index = 0
  batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
  print('\nwith bag_window = %d:' % (bag_window))  
  print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
###skip_window = 1 # How many words to consider left and right.
###num_skips = 2 # How many times to reuse an input to generate a label.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embeds, 1),
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.763997
# Nearest to six: antagonistic, ecusa, gascon, magnetization, saud, austria, principal, wrestling,
# Nearest to called: christy, oxidation, saussure, ces, adherents, disembodied, stoiber, rarefied,
# Nearest to war: gallus, astounding, username, ctbt, kanaris, sinusoidal, u, totalling,
# Nearest to would: wroc, pierce, griffon, michele, opengl, facet, amicable, anconia,
# Nearest to his: jarry, program, oedipus, charitable, dey, incursion, spreads, crist,
# Nearest to nine: frodo, gehrig, analog, consideration, studded, libi, furniture, fawlty,
# Nearest to often: mediocre, courbet, cap, predictable, unharmed, insignificant, fear, anglia,
# Nearest to use: teeming, laren, mondial, beneath, wadis, automatic, shipyards, degradation,
# Nearest to five: yoshinkan, bromine, inositol, banquo, botched, adc, bullough, attar,
# Nearest to on: teleplay, scrooge, uncomfortable, conflict, fit, awkward, dooley, cmm,
# Nearest to between: versus, italians, efta, millwall, hilberg, temptation, decays, siddhartha,
# Nearest to their: transmit, automation, compatriots, remains, qos, sinclair, receive, levied,
# Nearest to zero: election, remember, unconsciously, cyclops, cts, placements, arrangers, internationalization,
# Nearest to some: flexibility, coder, fiesta, polytheistic, folk, larwood, bleeding, fighter,
# Nearest to first: ergonomics, stages, wftu, uae, applauded, allis, dreamcast, visionary,
# Nearest to to: structuralist, torch, sleepless, ascetic, therapist, officio, biosynthesis, potable,
# Average loss at step 2000: 8.859431
# Average loss at step 4000: 5.364976
# Average loss at step 6000: 4.424194
# Average loss at step 8000: 4.631452
# Average loss at step 10000: 4.050891
# Nearest to six: nine, four, eight, three, five, seven, zero, width,
# Nearest to called: said, mimic, considered, ruddy, danube, adherents, district, agates,
# Nearest to war: banque, rights, censorware, lune, sins, ticino, pony, poisson,
# Nearest to would: did, could, may, can, will, should, must, findings,
# Nearest to his: darius, amalric, ki, jarry, allosaurus, stuart, their, aluminium,
# Nearest to nine: six, eight, zero, seven, hippocratic, four, five, endocrine,
# Nearest to often: sometimes, commonly, usually, southwards, modernised, incorrectly, blackwood, novelette,
# Nearest to use: automatic, barbados, cadre, filo, humanity, essays, teeming, dissipated,
# Nearest to five: four, zero, three, six, seven, bac, eight, unfettered,
# Nearest to on: during, at, although, in, ki, findings, allosaurus, collapse,
# Nearest to between: storytellers, backed, meatball, wikimedia, from, montezuma, urim, siddhartha,
# Nearest to their: his, its, darius, allosaurus, ki, amalric, august, embodiment,
# Nearest to zero: five, four, three, nine, six, two, eight, trivially,
# Nearest to some: many, their, sources, aegisthus, his, each, we, ki,
# Nearest to first: after, dominion, during, name, it, death, at, ki,
# Nearest to to: will, can, may, must, would, could, should, might,
# Average loss at step 12000: 4.029428
# Average loss at step 14000: 3.814272
# Average loss at step 16000: 3.799367
# Average loss at step 18000: 3.638636
# Average loss at step 20000: 3.500171
# Nearest to six: eight, five, three, punter, intercepting, jud, b, loewe,
# Nearest to called: considered, sensor, danube, known, monarchies, said, used, gladius,
# Nearest to war: iu, elsewhere, poisson, lune, sirach, lonergan, stripping, stirling,
# Nearest to would: will, may, must, should, can, might, could, did,
# Nearest to his: their, her, s, our, readiness, my, its, hume,
# Nearest to nine: seven, eight, four, five, miles, august, somewhere, three,
# Nearest to often: usually, commonly, generally, sometimes, qh, widely, barristers, chevy,
# Nearest to use: form, highlighting, dtft, teeming, filo, cadre, voltaire, material,
# Nearest to five: seven, four, rahman, three, ocular, darius, every, color,
# Nearest to on: upon, rard, stuka, fincher, kornilov, bypassing, through, scrooge,
# Nearest to between: with, ki, shirkuh, abdur, ocular, darius, allosaurus, guitarists,
# Nearest to their: his, her, its, brunt, some, heures, clients, postgraduate,
# Nearest to zero: eight, nine, predominantly, portals, seven, tetum, inducted, knebworth,
# Nearest to some: many, various, several, these, most, their, ternary, gamal,
# Nearest to first: before, second, skin, next, last, every, professional, sky,
# Nearest to to: could, abdur, stuart, mande, wiring, anger, ocular, uruguay,
# Average loss at step 22000: 3.646343
# Average loss at step 24000: 3.735360
# Average loss at step 26000: 3.669660
# Average loss at step 28000: 3.569094
# Average loss at step 30000: 3.389743
# Nearest to six: five, darius, allosaurus, daniel, ocular, wages, pham, cell,
# Nearest to called: considered, used, formed, facilitates, known, wellcome, named, digestive,
# Nearest to war: courteous, adrianople, gestation, kanji, crops, iu, advisors, pronoun,
# Nearest to would: could, will, must, can, should, may, might, cannot,
# Nearest to his: her, their, its, the, s, our, my, schodt,
# Nearest to nine: eight, seven, hippocratic, buteo, six, zero, late, th,
# Nearest to often: sometimes, usually, commonly, generally, frequently, what, widely, also,
# Nearest to use: allosaurus, show, abdur, ki, color, cell, shirkuh, treatment,
# Nearest to five: six, darius, daniel, four, ocular, rahman, ki, amalric,
# Nearest to on: upon, in, altenberg, about, narcotic, fincher, against, bypassing,
# Nearest to between: with, through, wikimedia, piqad, versus, storytellers, barred, catchy,
# Nearest to their: its, his, her, the, our, whose, maronite, karo,
# Nearest to zero: five, six, cargo, darius, election, abdur, wiring, color,
# Nearest to some: many, several, various, both, every, predictive, most, each,
# Nearest to first: last, second, same, next, final, abilities, sprite, margherita,
# Nearest to to: would, will, must, should, can, might, could, hackney,
# Average loss at step 32000: 3.185744
# Average loss at step 34000: 3.534505
# Average loss at step 36000: 3.364828
# Average loss at step 38000: 3.409350
# Average loss at step 40000: 3.349757
# Nearest to six: eight, four, seven, five, nine, zero, three, two,
# Nearest to called: single, pham, cartridge, monarchy, ocular, allosaurus, enemy, darius,
# Nearest to war: iu, adrianople, pony, ia, borders, courteous, christus, atwood,
# Nearest to would: will, can, should, may, could, might, must, cannot,
# Nearest to his: her, their, its, our, the, my, your, beheld,
# Nearest to nine: eight, six, february, th, five, seven, zero, accidently,
# Nearest to often: ocular, animals, cymbals, atheromatous, anger, wiring, mainly, cells,
# Nearest to use: form, teamwork, warn, sense, denny, parts, choose, support,
# Nearest to five: four, six, eight, seven, zero, three, two, nine,
# Nearest to on: upon, through, in, fincher, about, altenberg, inklings, narcotic,
# Nearest to between: through, with, within, over, during, into, fiddle, storytellers,
# Nearest to their: its, his, her, our, the, photographing, eared, humboldt,
# Nearest to zero: eight, five, six, four, seven, travelogues, million, nine,
# Nearest to some: many, several, various, most, these, certain, this, zebrafish,
# Nearest to first: last, second, same, next, third, primary, original, fourth,
# Nearest to to: would, might, will, can, may, should, iskra, trumbo,
# Average loss at step 42000: 3.405344
# Average loss at step 44000: 3.408943
# Average loss at step 46000: 3.355006
# Average loss at step 48000: 3.288025
# Average loss at step 50000: 3.199502
# Nearest to six: four, seven, five, eight, three, nine, two, zero,
# Nearest to called: considered, named, used, created, included, mapmaking, referred, orthonormal,
# Nearest to war: ban, atwood, adrianople, vater, poland, rudolf, serling, courteous,
# Nearest to would: should, may, will, could, can, must, cannot, did,
# Nearest to his: her, their, its, our, s, your, my, the,
# Nearest to nine: eight, seven, six, five, four, february, bellerophon, zero,
# Nearest to often: usually, sometimes, commonly, frequently, generally, typically, still, widely,
# Nearest to use: return, produce, consist, qualities, development, keep, penh, exist,
# Nearest to five: seven, four, six, three, eight, zero, nine, two,
# Nearest to on: upon, astrometric, in, altenberg, across, within, through, against,
# Nearest to between: with, through, during, over, thus, disciplined, within, softness,
# Nearest to their: its, his, her, our, your, the, maronite, microsite,
# Nearest to zero: five, eight, vol, seven, nm, million, nine, six,
# Nearest to some: many, several, various, certain, most, all, those, any,
# Nearest to first: last, third, next, second, final, same, fourth, latter,
# Nearest to to: must, should, would, can, could, will, may, cannot,
# Average loss at step 52000: 3.218803
# Average loss at step 54000: 3.197315
# Average loss at step 56000: 3.077572
# Average loss at step 58000: 3.132139
# Average loss at step 60000: 3.162237
# Nearest to six: five, seven, four, eight, three, zero, nine, million,
# Nearest to called: considered, named, used, referred, known, defined, livingston, asparagales,
# Nearest to war: invasion, ban, vater, atwood, poland, literature, christus, pony,
# Nearest to would: will, could, should, might, may, must, can, cannot,
# Nearest to his: their, its, her, my, s, our, your, the,
# Nearest to nine: eight, five, seven, zero, six, late, four, mid,
# Nearest to often: usually, frequently, commonly, sometimes, generally, typically, widely, still,
# Nearest to use: support, allow, portrayal, development, exist, application, amount, apply,
# Nearest to five: eight, six, seven, four, three, nine, zero, two,
# Nearest to on: upon, stuka, onto, against, philanthropic, fincher, altenberg, cosworth,
# Nearest to between: with, over, disunity, during, educating, into, ensuing, th,
# Nearest to their: its, his, our, your, the, her, whose, my,
# Nearest to zero: seven, five, six, eight, nine, million, four, three,
# Nearest to some: many, several, various, numerous, these, most, all, those,
# Nearest to first: last, next, second, third, latter, final, fourth, same,
# Nearest to to: would, could, might, must, cannot, should, will, may,
# Average loss at step 62000: 3.109351
# Average loss at step 64000: 3.050656
# Average loss at step 66000: 3.027409
# Average loss at step 68000: 3.111868
# Average loss at step 70000: 3.091851
# Nearest to six: seven, five, eight, three, four, two, zero, executors,
# Nearest to called: considered, named, known, referred, included, used, connected, swaps,
# Nearest to war: wars, invasion, vater, notorious, literature, assisi, rudolf, adrianople,
# Nearest to would: could, will, might, may, should, must, can, cannot,
# Nearest to his: their, its, her, your, s, our, my, the,
# Nearest to nine: eight, nr, willughby, february, zero, dalnet, october, december,
# Nearest to often: frequently, sometimes, generally, usually, commonly, widely, typically, now,
# Nearest to use: share, application, support, consist, amount, vicu, allow, operate,
# Nearest to five: seven, six, four, three, eight, zero, two, gly,
# Nearest to on: upon, onto, stuka, fincher, around, in, across, through,
# Nearest to between: within, with, ensuing, versus, through, among, beyond, disunity,
# Nearest to their: its, his, our, her, your, the, both, these,
# Nearest to zero: five, two, eight, three, seven, six, million, nautical,
# Nearest to some: many, several, various, all, certain, most, these, thousands,
# Nearest to first: second, last, next, final, same, latter, third, earliest,
# Nearest to to: will, must, might, could, would, can, toward, may,
# Average loss at step 72000: 3.060508
# Average loss at step 74000: 2.934776
# Average loss at step 76000: 3.120085
# Average loss at step 78000: 3.094532
# Average loss at step 80000: 2.924414
# Nearest to six: seven, four, five, three, eight, zero, nine, nazarian,
# Nearest to called: considered, named, used, formed, made, included, referred, created,
# Nearest to war: wars, ban, invasion, subtitle, atwood, courteous, portugal, rudolf,
# Nearest to would: will, might, could, should, may, must, can, did,
# Nearest to his: their, her, its, your, our, my, the, whose,
# Nearest to nine: eight, zero, seven, six, th, four, december, fanatic,
# Nearest to often: generally, usually, frequently, sometimes, commonly, widely, typically, traditionally,
# Nearest to use: consist, application, support, form, fight, exist, allow, amount,
# Nearest to five: three, six, seven, four, eight, zero, two, assessing,
# Nearest to on: upon, onto, altenberg, in, concerning, fincher, hypoxic, rale,
# Nearest to between: among, across, during, class, gollum, shirkuh, existentialism, caches,
# Nearest to their: its, his, her, your, our, the, whose, vidzeme,
# Nearest to zero: eight, six, nine, five, seven, million, two, four,
# Nearest to some: many, several, various, certain, numerous, those, these, sennett,
# Nearest to first: last, next, same, best, fourth, third, original, earliest,
# Nearest to to: will, might, would, must, could, may, can, should,
# Average loss at step 82000: 2.998139
# Average loss at step 84000: 2.973996
# Average loss at step 86000: 2.985803
# Average loss at step 88000: 2.991189
# Average loss at step 90000: 2.880323
# Nearest to six: seven, five, eight, three, four, nine, zero, two,
# Nearest to called: considered, named, used, termed, described, referred, known, created,
# Nearest to war: wars, subtitle, jdl, serling, pronoun, ban, christus, invasion,
# Nearest to would: could, will, might, may, should, can, must, did,
# Nearest to his: their, her, its, your, my, the, jarry, our,
# Nearest to nine: eight, seven, six, th, zero, mid, five, late,
# Nearest to often: frequently, sometimes, usually, generally, commonly, typically, primarily, actually,
# Nearest to use: amount, consist, form, share, support, because, copies, speak,
# Nearest to five: six, three, seven, eight, four, zero, two, nine,
# Nearest to on: upon, through, stuka, onto, altenberg, fincher, jamaicans, in,
# Nearest to between: with, beyond, into, versus, disunity, within, ensuing, through,
# Nearest to their: its, his, her, our, your, my, whose, the,
# Nearest to zero: eight, five, six, three, nine, seven, four, pm,
# Nearest to some: many, several, various, most, numerous, certain, thousands, few,
# Nearest to first: last, next, second, earliest, original, same, final, latter,
# Nearest to to: will, must, might, may, could, would, can, should,
# Average loss at step 92000: 2.954940
# Average loss at step 94000: 2.945368
# Average loss at step 96000: 2.754454
# Average loss at step 98000: 2.656182
# Average loss at step 100000: 2.765818
# Nearest to six: five, seven, four, eight, three, sixths, gollum, diamonds,
# Nearest to called: considered, named, used, known, referred, described, awarded, formed,
# Nearest to war: wars, organization, vater, confusion, christus, subtitle, invasion, unrest,
# Nearest to would: could, might, will, must, should, can, may, did,
# Nearest to his: her, their, its, s, the, your, whose, my,
# Nearest to nine: eight, seven, lbf, zero, five, chapter, six, mph,
# Nearest to often: generally, sometimes, frequently, usually, commonly, still, primarily, always,
# Nearest to use: support, consist, amount, removable, application, used, happen, allow,
# Nearest to five: four, seven, six, three, eight, two, zero, nine,
# Nearest to on: upon, onto, stuka, fincher, through, boardwalk, in, concerning,
# Nearest to between: with, through, beyond, across, versus, ensuing, within, among,
# Nearest to their: its, his, her, our, your, whose, my, the,
# Nearest to zero: eight, five, four, seven, nine, prerequisites, million, six,
# Nearest to some: many, several, various, numerous, certain, all, both, thousands,
# Nearest to first: last, next, second, earliest, same, final, oldest, best,
# Nearest to to: must, will, might, would, could, can, should, toward,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# Some clusters are less obvious (like the standalone characters), but it clearly totaly works.

# %% [markdown]
# How does your CBOW model perform compared to the given Word2Vec model? (to be answered)
