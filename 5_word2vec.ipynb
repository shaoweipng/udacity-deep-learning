# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
print(data[:10])
print(count[:10])
print(dictionary.items()[:10])
print(reverse_dictionary.items()[:10])
# Out:
# [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]
# [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764), ('in', 372201), ('a', 325873), ('to', 316376), ('zero', 264975), ('nine', 250430)]
# [('fawn', 45848), ('homomorphism', 9648), ('nordisk', 39343), ('nunnery', 36075), ('chthonic', 33554), ('sowell', 40562), ('sonja', 38175), ('showa', 32906), ('woods', 6263), ('hsv', 44222)]
# [(0, 'UNK'), (1, 'the'), (2, 'of'), (3, 'and'), (4, 'one'), (5, 'in'), (6, 'a'), (7, 'to'), (8, 'zero'), (9, 'nine')]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:32]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=16, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(16)])
    
for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 1
    batch, labels = generate_batch(batch_size=16, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(16)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'UNK', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term', 'of', 'of', 'abuse', 'abuse', 'first', 'first', 'used', 'used']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'of', 'a', 'term', 'abuse', 'of', 'first', 'used', 'abuse', 'against', 'first']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a', 'term', 'term', 'term', 'term', 'of', 'of', 'of', 'of']
#     labels: ['anarchism', 'term', 'originated', 'a', 'as', 'term', 'of', 'originated', 'a', 'of', 'as', 'abuse', 'abuse', 'term', 'first', 'a']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['as', 'as', 'a', 'a', 'term', 'term', 'of', 'of', 'abuse', 'abuse', 'first', 'first', 'used', 'used', 'against', 'against']
#     labels: ['originated', 'a', 'term', 'as', 'of', 'a', 'abuse', 'term', 'first', 'of', 'abuse', 'used', 'against', 'first', 'used', 'early']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['a', 'a', 'a', 'a', 'term', 'term', 'term', 'term', 'of', 'of', 'of', 'of', 'abuse', 'abuse', 'abuse', 'abuse']
#     labels: ['as', 'of', 'originated', 'term', 'a', 'as', 'of', 'abuse', 'a', 'term', 'abuse', 'first', 'first', 'term', 'of', 'used']

# %% [markdown]
# Note: the labels is a sliding random value of the word surrounding the words of the batch.

# %%
print(batch)
print(labels)
# Out:
# [   6    6    6    6  195  195  195  195    2    2    2    2 3137 3137 3137
#  3137]
# [[  12]
#  [   2]
#  [3084]
#  [ 195]
#  [   6]
#  [  12]
#  [   2]
#  [3137]
#  [   6]
#  [ 195]
#  [3137]
#  [  46]
#  [  46]
#  [ 195]
#  [   2]
#  [  59]]

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.745848
# Nearest to than: kansas, homophones, kashmiri, migne, tchaikovsky, tajikistan, homicide, johanna,
# Nearest to they: hunchback, thebaid, commune, judith, tandy, helen, surrounded, phosphoric,
# Nearest to UNK: poseidon, bushnell, aviation, bromwich, pournelle, reeves, relation, intractable,
# Nearest to up: constituency, honours, carries, ongoing, labelling, seduce, subpoenaed, ferment,
# Nearest to about: wiens, trained, hatcher, zack, soaked, jsr, minimum, upbringing,
# Nearest to called: howe, infraclass, jeannie, arminius, eschewed, cristae, essenes, secularization,
# Nearest to united: rink, liners, tsunami, toffler, oman, masculinity, chats, clancy,
# Nearest to of: gonzalez, saito, multics, bitches, tsui, interest, fleeting, fuelling,
# Nearest to these: performing, issued, ingalls, vilas, scripts, raven, davidson, cairo,
# Nearest to d: puppet, letter, croydon, crown, paranoia, bolger, kazakhstan, insurers,
# Nearest to for: ldapv, stiles, orchestras, cuttings, disfavor, going, staring, maharashtri,
# Nearest to their: glamour, ht, hidalgo, decency, manco, fujimori, ticket, giscard,
# Nearest to time: soccer, fontane, punishments, density, condenses, kidnapped, transduction, nihilist,
# Nearest to more: palestinians, commemorated, harpist, finnish, absalom, gresham, imagination, oslo,
# Nearest to are: ciii, elisabeth, mcneil, photosynthetic, dismiss, irredentist, everything, previews,
# Nearest to however: delphi, talent, horsemanship, stepped, ger, transitional, midrashim, arteries,
# Average loss at step 2000: 4.364256
# Average loss at step 4000: 3.863682
# Average loss at step 6000: 3.787972
# Average loss at step 8000: 3.683261
# Average loss at step 10000: 3.619396
# Nearest to than: or, immutable, migne, homophones, chandler, executables, abolitionist, chrono,
# Nearest to they: commune, he, there, not, it, demarco, we, burned,
# Nearest to UNK: frottage, succinctly, aardvarks, passau, disclaimer, oswaldo, inflated, gyms,
# Nearest to up: da, subpoenaed, seduce, be, rating, ongoing, grothendieck, unitary,
# Nearest to about: wiens, trained, zack, bondage, gatekeeper, best, pcm, cumann,
# Nearest to called: difranco, incalculable, shtml, eschewed, milhaud, arminius, infraclass, secularization,
# Nearest to united: liners, toffler, teenage, during, benchers, masculinity, emir, khattab,
# Nearest to of: in, for, brewster, and, at, on, mengistu, oort,
# Nearest to these: quantifying, serra, issued, many, alejandro, amplifiers, performing, trypomastigotes,
# Nearest to d: puppet, nye, rel, steffi, bolger, foreign, reportage, delivering,
# Nearest to for: napoleonic, of, sauce, orchestras, synagogues, clips, responsibilities, carte,
# Nearest to their: his, its, glamour, checked, reduce, eddic, kern, crystalline,
# Nearest to time: condenses, year, ixian, punishments, formic, consensual, kidnapped, acapulco,
# Nearest to more: thus, gresham, absalom, charlottetown, cotswold, prost, antipsychotic, elevating,
# Nearest to are: were, is, have, but, include, marischal, van, gunfight,
# Nearest to however: delphi, horsemanship, arteries, wings, talent, distorting, but, pastime,
# Average loss at step 12000: 3.605804
# Average loss at step 14000: 3.570084
# Average loss at step 16000: 3.407072
# Average loss at step 18000: 3.460704
# Average loss at step 20000: 3.540624
# Nearest to than: or, immutable, migne, homophones, executables, abolitionist, chandler, drumming,
# Nearest to they: we, he, there, it, commune, you, not, who,
# Nearest to UNK: aquila, teaming, deviate, alarms, passau, stereochemistry, hellene, com,
# Nearest to up: da, grothendieck, seduce, lublin, vandal, foundry, unitary, him,
# Nearest to about: wiens, pcm, cloudbusting, trained, zack, why, bondage, germanic,
# Nearest to called: milhaud, difranco, secularization, shtml, lamiales, eschewed, medway, cristae,
# Nearest to united: liners, teenage, during, emir, toffler, masculinity, benchers, clocking,
# Nearest to of: at, for, magnificent, facsimile, same, commotion, symbolize, era,
# Nearest to these: many, some, all, quantifying, alejandro, which, conch, kat,
# Nearest to d: b, nye, rel, steffi, exhortation, xia, blooded, bsod,
# Nearest to for: or, and, at, after, with, napoleonic, sauce, of,
# Nearest to their: his, its, the, checked, her, some, them, came,
# Nearest to time: year, condenses, ixian, qoheleth, consensual, half, approximation, proliferation,
# Nearest to more: less, most, very, prost, thus, precocious, gresham, rather,
# Nearest to are: were, is, have, sbc, include, haydn, was, but,
# Nearest to however: but, though, horsemanship, where, negroes, lytton, pastime, delphi,
# Average loss at step 22000: 3.504574
# Average loss at step 24000: 3.485492
# Average loss at step 26000: 3.482737
# Average loss at step 28000: 3.478581
# Average loss at step 30000: 3.509587
# Nearest to than: or, immutable, much, but, treads, drumming, dowland, migne,
# Nearest to they: there, we, he, it, who, you, not, these,
# Nearest to UNK: barnes, jodie, writer, conservatoire, dougal, reincarnation, encountering, brin,
# Nearest to up: him, them, grothendieck, seduce, foundry, vandal, brigadists, falcone,
# Nearest to about: ricardo, pcm, wiens, why, gatekeeper, spilled, underemployment, production,
# Nearest to called: lamiales, referred, secularization, shtml, milhaud, eschewed, bmw, flaherty,
# Nearest to united: teenage, liners, masculinity, toffler, emir, benchers, clocking, chats,
# Nearest to of: in, and, hedley, while, brewster, israeli, including, from,
# Nearest to these: some, many, several, all, their, they, various, which,
# Nearest to d: b, exhortation, nye, steffi, harriet, xia, rel, paranoia,
# Nearest to for: when, napoleonic, with, towards, after, against, responsibilities, sauce,
# Nearest to their: its, his, the, some, her, these, checked, many,
# Nearest to time: year, condenses, half, smiths, dominion, consensual, ixian, browne,
# Nearest to more: less, very, most, rather, prost, disturbances, thus, erythematosus,
# Nearest to are: were, include, is, have, sbc, these, be, creationism,
# Nearest to however: but, though, although, that, clemens, where, lytton, worthies,
# Average loss at step 32000: 3.499659
# Average loss at step 34000: 3.490892
# Average loss at step 36000: 3.454461
# Average loss at step 38000: 3.308573
# Average loss at step 40000: 3.423726
# Nearest to than: or, much, dowland, migne, suppressed, immutable, cfb, disarming,
# Nearest to they: we, he, there, you, it, she, not, these,
# Nearest to UNK: kilimanjaro, anzus, yeltsin, dick, frottage, overheating, toll, j,
# Nearest to up: him, them, grothendieck, vandal, overdrive, falcone, seduce, foundry,
# Nearest to about: why, ricardo, pcm, wiens, radiate, fielders, harassing, spilled,
# Nearest to called: referred, lamiales, secularization, announcements, milhaud, shtml, eschewed, anchoring,
# Nearest to united: teenage, liners, masculinity, clocking, benchers, toffler, during, emir,
# Nearest to of: in, including, nai, brewster, for, prevention, arcseconds, from,
# Nearest to these: many, some, several, which, they, various, such, all,
# Nearest to d: b, nye, c, exhortation, steffi, hh, orlando, xia,
# Nearest to for: napoleonic, in, after, responsibilities, brahmaputra, of, when, by,
# Nearest to their: its, his, her, the, some, eddic, these, them,
# Nearest to time: year, way, half, smiths, condenses, at, dominion, beginning,
# Nearest to more: less, most, very, prost, rather, greater, grossing, erythematosus,
# Nearest to are: were, have, include, is, sbc, be, including, although,
# Nearest to however: but, though, although, that, cases, logistical, where, when,
# Average loss at step 42000: 3.436634
# Average loss at step 44000: 3.451283
# Average loss at step 46000: 3.452834
# Average loss at step 48000: 3.351087
# Average loss at step 50000: 3.382103
# Nearest to than: much, or, dowland, and, cost, homophones, cache, immutable,
# Nearest to they: he, there, we, you, she, it, these, not,
# Nearest to UNK: l, et, saumur, scottsdale, compiling, inflated, hellene, pamela,
# Nearest to up: him, them, out, off, overdrive, vandal, back, down,
# Nearest to about: why, harassing, pcm, laminar, comfort, soaked, trained, best,
# Nearest to called: referred, secularization, lamiales, anchoring, pogo, milhaud, eschewed, oratio,
# Nearest to united: teenage, liners, masculinity, clocking, emir, dd, benchers, radium,
# Nearest to of: in, and, absolution, orchids, where, saville, stewed, auvergne,
# Nearest to these: some, many, several, both, they, those, various, such,
# Nearest to d: b, nye, c, exhortation, m, steffi, xia, rel,
# Nearest to for: napoleonic, despite, synagogues, while, liberia, historical, courtyards, perutz,
# Nearest to their: its, his, her, the, some, checked, those, them,
# Nearest to time: year, way, dominion, smiths, half, storefront, alde, consensual,
# Nearest to more: less, most, very, highly, prost, rather, verification, rogues,
# Nearest to are: were, is, have, include, be, sbc, contain, those,
# Nearest to however: but, though, although, that, while, when, where, cases,
# Average loss at step 52000: 3.432187
# Average loss at step 54000: 3.423155
# Average loss at step 56000: 3.445016
# Average loss at step 58000: 3.395176
# Average loss at step 60000: 3.390677
# Nearest to than: much, or, cost, dowland, and, but, isbns, cache,
# Nearest to they: we, he, there, you, she, it, these, would,
# Nearest to UNK: hardwood, taoism, perihelion, languages, chondrite, promenade, fachhochschule, mcgowan,
# Nearest to up: him, them, off, out, down, back, overdrive, unitary,
# Nearest to about: why, mansi, gilmore, comfort, trained, cannibals, on, laminar,
# Nearest to called: referred, secularization, used, pogo, anchoring, considered, lamiales, named,
# Nearest to united: teenage, liners, masculinity, clocking, benchers, emir, rudi, toffler,
# Nearest to of: in, for, facsimile, current, same, absolution, including, glamorous,
# Nearest to these: many, some, several, those, both, all, such, which,
# Nearest to d: b, nye, c, xia, rated, hh, m, h,
# Nearest to for: of, napoleonic, after, including, despite, brahmaputra, when, while,
# Nearest to their: its, his, her, the, checked, these, your, those,
# Nearest to time: way, year, dominion, thing, half, horseman, jehu, series,
# Nearest to more: less, very, most, rather, highly, longer, prost, increasingly,
# Nearest to are: were, is, have, include, be, those, including, mycoplasma,
# Nearest to however: but, although, though, that, while, which, when, where,
# Average loss at step 62000: 3.234771
# Average loss at step 64000: 3.255717
# Average loss at step 66000: 3.404836
# Average loss at step 68000: 3.391377
# Average loss at step 70000: 3.356656
# Nearest to than: much, or, cost, isbns, cache, elmira, parity, homophones,
# Nearest to they: we, he, there, you, she, it, patriarchates, whisper,
# Nearest to UNK: passau, n, cancerous, brubaker, der, sincerity, aye, fiqh,
# Nearest to up: them, off, him, out, back, down, overdrive, falcone,
# Nearest to about: why, on, around, emphasise, cannibals, mansi, harassing, soaked,
# Nearest to called: referred, named, anchoring, secularization, invasive, pogo, known, considered,
# Nearest to united: teenage, liners, masculinity, clocking, benchers, oa, khattab, rudi,
# Nearest to of: including, and, orchids, include, facsimile, stewed, in, although,
# Nearest to these: such, some, many, several, various, those, the, which,
# Nearest to d: b, nye, xia, rated, h, appreciably, l, violet,
# Nearest to for: after, napoleonic, in, despite, synagogues, while, including, when,
# Nearest to their: its, his, her, the, your, our, checked, these,
# Nearest to time: way, dominion, year, storefront, thing, period, half, jehu,
# Nearest to more: less, most, very, rather, highly, better, larger, higher,
# Nearest to are: were, is, including, include, have, while, although, these,
# Nearest to however: but, although, though, that, while, where, when, which,
# Average loss at step 72000: 3.371822
# Average loss at step 74000: 3.344277
# Average loss at step 76000: 3.313818
# Average loss at step 78000: 3.354255
# Average loss at step 80000: 3.380124
# Nearest to than: much, but, or, cost, while, isbns, stateless, bf,
# Nearest to they: we, he, you, there, she, it, not, these,
# Nearest to UNK: stewart, frottage, architect, dougal, yeltsin, butcher, petri, unlocked,
# Nearest to up: off, out, them, him, down, back, falcone, foundry,
# Nearest to about: laminar, soaked, mansi, why, exaggerating, spilled, expression, best,
# Nearest to called: referred, used, named, secularization, yang, pogo, anchoring, invasive,
# Nearest to united: teenage, masculinity, clocking, liners, benchers, oa, mexica, rudi,
# Nearest to of: including, in, forbes, willughby, from, original, boyer, suitability,
# Nearest to these: several, those, many, both, various, such, some, are,
# Nearest to d: b, nye, pat, rated, m, l, violet, intercourse,
# Nearest to for: despite, after, napoleonic, secrete, protease, woollen, unionist, synagogues,
# Nearest to their: its, his, her, our, your, the, personal, these,
# Nearest to time: year, way, voyage, dominion, unceasing, thing, habilis, alde,
# Nearest to more: less, most, very, rather, highly, larger, longer, increasingly,
# Nearest to are: were, is, have, these, although, include, those, including,
# Nearest to however: but, although, though, that, while, when, dubs, where,
# Average loss at step 82000: 3.410494
# Average loss at step 84000: 3.407180
# Average loss at step 86000: 3.390964
# Average loss at step 88000: 3.356088
# Average loss at step 90000: 3.365445
# Nearest to than: or, much, cost, unidad, even, but, chs, pollinated,
# Nearest to they: we, he, there, you, she, it, these, patriarchates,
# Nearest to UNK: baker, thickened, minibuses, reptile, challenging, lat, anthony, brown,
# Nearest to up: out, off, them, back, him, down, falcone, overdrive,
# Nearest to about: laminar, soaked, why, around, expression, mansi, stooges, trained,
# Nearest to called: referred, used, named, anchoring, pogo, known, secularization, yang,
# Nearest to united: teenage, masculinity, benchers, clocking, rudi, oa, dd, spirits,
# Nearest to of: including, for, accordions, include, same, current, original, from,
# Nearest to these: several, many, various, some, those, both, such, are,
# Nearest to d: b, nye, theodore, rated, violet, letter, pat, m,
# Nearest to for: including, napoleonic, after, of, despite, when, by, against,
# Nearest to their: its, his, her, our, your, whose, the, my,
# Nearest to time: unceasing, way, powerplant, year, alde, dominion, period, storefront,
# Nearest to more: less, very, most, rather, highly, longer, increasingly, particularly,
# Nearest to are: were, is, have, these, include, although, xs, those,
# Nearest to however: but, although, though, that, while, and, especially, since,
# Average loss at step 92000: 3.396132
# Average loss at step 94000: 3.252544
# Average loss at step 96000: 3.355465
# Average loss at step 98000: 3.248348
# Average loss at step 100000: 3.357558
# Nearest to than: or, much, ccc, chs, tucum, reach, framing, dowland,
# Nearest to they: we, he, there, you, she, it, i, these,
# Nearest to UNK: teammate, das, waxing, woodruff, examined, et, treviso, alarms,
# Nearest to up: out, off, them, back, him, down, overdrive, falcone,
# Nearest to about: why, soaked, around, over, exaggerating, ricardo, mansi, trained,
# Nearest to called: named, referred, used, anchoring, secularization, known, pogo, oratio,
# Nearest to united: teenage, masculinity, benchers, clocking, usa, generic, oa, chats,
# Nearest to of: in, and, including, stewed, original, nai, merz, delusion,
# Nearest to these: several, many, various, some, those, all, which, such,
# Nearest to d: b, nye, rated, intercourse, pat, c, conservancy, hh,
# Nearest to for: when, after, despite, napoleonic, if, before, including, unionist,
# Nearest to their: its, his, her, our, your, the, whose, these,
# Nearest to time: way, year, powerplant, thing, sort, unceasing, newsletters, storefront,
# Nearest to more: less, very, most, highly, rather, larger, smaller, longer,
# Nearest to are: were, have, those, although, these, is, include, contain,
# Nearest to however: but, although, though, that, while, especially, which, when,

# %%
print(final_embeddings[0])
# Out:
# [-0.03102845  0.18469363  0.0441338  -0.07082509 -0.04192193 -0.02363926
#   0.04985272 -0.05340959 -0.04991143  0.04169796  0.00027954  0.16257635
#  -0.13572431  0.00841555 -0.05478051  0.09359286  0.03716859  0.06334019
#  -0.06252235 -0.01800506 -0.0543941  -0.1482473  -0.03452137 -0.07487782
#   0.07147434 -0.01848191  0.08755131 -0.06603089  0.02410508  0.09299255
#  -0.09668615 -0.07863677 -0.18135768  0.07727248  0.11004917 -0.02610058
#  -0.00640311  0.07058094 -0.1337233   0.03407545  0.17105722  0.04272709
#   0.14203392  0.00698637 -0.08694069 -0.11766193 -0.20537466 -0.11743524
#  -0.06930152  0.12554021  0.05733837 -0.02321491  0.05821052 -0.11010105
#  -0.0279725   0.02863141  0.05937718  0.06726865  0.02779515  0.05933564
#   0.10942695  0.05117136  0.11226535 -0.01374661 -0.06661736 -0.04133542
#  -0.17026374  0.18440121 -0.10911045  0.07349414  0.05667135  0.08204723
#  -0.00421435  0.05907166 -0.00318978 -0.03341759  0.00358135  0.08980413
#   0.14746051 -0.17344269  0.10113501 -0.14815983  0.14491108  0.11355943
#   0.03730112  0.18053898 -0.01367207  0.08834919 -0.08116475  0.12951797
#   0.07422562 -0.11480203  0.08026337  0.10594239 -0.01794095  0.01674687
#   0.05662731  0.09008286 -0.10121243  0.12790473  0.01857099  0.1438217
#   0.08946178 -0.02793122 -0.04077107 -0.07269105 -0.06352056  0.06431018
#  -0.12294728  0.06353736 -0.04771186  0.04833494 -0.12734196  0.09577271
#   0.06957315  0.09748136  0.0089484   0.10549364  0.00889502 -0.08208582
#   0.05528218 -0.01355169 -0.04843138 -0.06061208  0.04983041  0.0805649
#   0.07608294  0.0496248 ]

# %%
print(np.sum(np.square(final_embeddings[0])))
# Out:
# 1.0

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    # just for testing
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    # iterate to the next buffer
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
  data_index = 0
  batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
  print('\nwith bag_window = %d:' % (bag_window))  
  print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
###skip_window = 1 # How many words to consider left and right.
###num_skips = 2 # How many times to reuse an input to generate a label.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embeds, 1),
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.869804
# Nearest to not: daffodils, sexual, familia, postcard, ecb, traitor, xp, dynamically,
# Nearest to been: fon, hoc, apology, menelik, chen, chatter, nara, ebu,
# Nearest to for: greater, werth, ailments, assuring, speedily, kuznetsov, kd, characterises,
# Nearest to at: meson, cronenberg, factoring, shrine, crimson, catalunya, kw, cca,
# Nearest to about: dmt, lumped, symmetrical, instantaneously, conjecture, cycle, derivation, symbolic,
# Nearest to two: devanagari, compaor, raccoon, ekaterina, router, hess, lockheed, bnp,
# Nearest to in: loosely, abhidhamma, cabbage, succumbed, belshazzar, lag, exam, kernighan,
# Nearest to of: bsi, hitchcock, covenants, bleach, goldstein, wallach, mysteriously, aftermath,
# Nearest to this: atheist, novella, ozzfest, appendix, precedence, carbohydrate, chromaticity, regulate,
# Nearest to however: organically, ether, representational, dissolved, karaites, oss, sothoth, blackadder,
# Nearest to were: tigre, unwin, regrouped, grasped, peso, klang, adjective, curving,
# Nearest to new: atzma, mais, affine, paper, idempotent, penh, sanhedrin, breast,
# Nearest to united: gne, wrestler, privateer, laborers, virology, purport, benevento, latter,
# Nearest to would: concerts, interpretive, grievous, kurt, mild, omen, narratives, atom,
# Nearest to there: marjorie, biblical, xlii, critic, pomerania, ner, harpo, delimited,
# Nearest to four: reacts, announcers, starting, sacra, benches, changes, comprises, malenkov,
# Average loss at step 2000: 6.744318
# Average loss at step 4000: 4.225562
# Average loss at step 6000: 3.919592
# Average loss at step 8000: 3.800010
# Average loss at step 10000: 3.623944
# Nearest to not: what, it, rau, holyrood, swamp, quadrant, also, still,
# Nearest to been: become, diminished, xenophobic, run, monad, facilitates, gerard, weinberg,
# Nearest to for: of, with, apt, postgraduate, emeralds, workload, after, oklahoma,
# Nearest to at: tanner, stately, bde, tenuous, on, jonny, cyprian, combative,
# Nearest to about: garrison, mimicking, scotsman, dunn, trivial, invisibly, awacs, planetarium,
# Nearest to two: five, four, three, seven, nims, zero, counterparts, eight,
# Nearest to in: on, within, of, descending, kat, where, throughout, tungsten,
# Nearest to of: in, for, brownish, aikman, samsara, lunches, escorting, pao,
# Nearest to this: it, any, unconsciously, which, a, what, the, eritrean,
# Nearest to however: but, uvular, integrative, today, insisting, mellaart, hyundai, rigidly,
# Nearest to were: are, had, was, fulfill, blackjack, is, docked, speyer,
# Nearest to new: penh, medford, dolly, africaine, checks, affine, geothermal, dhekelia,
# Nearest to united: bribery, lacquer, latter, om, future, tenochtitlan, kee, purport,
# Nearest to would: will, could, can, may, must, to, should, might,
# Nearest to there: it, candidates, sternum, able, considered, commons, wages, he,
# Nearest to four: six, zero, three, eight, five, seven, nine, two,
# Average loss at step 12000: 3.665794
# Average loss at step 14000: 3.589143
# Average loss at step 16000: 3.532186
# Average loss at step 18000: 3.447159
# Average loss at step 20000: 3.303575
# Nearest to not: still, holyrood, what, counteracting, now, romanticism, haggis, rebbe,
# Nearest to been: become, weinberg, xenophobic, monad, diminished, tactile, gerard, disruptions,
# Nearest to for: postgraduate, bowden, louth, overflows, workload, when, intensity, alluding,
# Nearest to at: during, since, sichuan, over, commodus, gubernatorial, reclassified, arslan,
# Nearest to about: sabine, affricate, zwingli, symmetrical, main, termed, civilize, conjecture,
# Nearest to two: three, four, six, nine, appeared, seven, langerhans, joanie,
# Nearest to in: list, problem, people, of, real, penguin, compressibility, wages,
# Nearest to of: people, problem, mate, real, wages, list, compressibility, penguin,
# Nearest to this: it, alexander, there, only, which, apparent, list, people,
# Nearest to however: although, but, though, sulla, sporadic, falklands, mack, gilded,
# Nearest to were: are, was, is, merge, gms, had, being, rushton,
# Nearest to new: mad, military, cegep, terribly, conceptual, radbruch, ux, inner,
# Nearest to united: kee, corner, latter, songbook, bribery, tenochtitlan, memorized, lacquer,
# Nearest to would: could, will, may, can, must, should, might, did,
# Nearest to there: they, this, it, found, sb, longer, wages, tiered,
# Nearest to four: three, eight, base, people, southerly, real, six, list,
# Average loss at step 22000: 3.456933
# Average loss at step 24000: 3.339565
# Average loss at step 26000: 3.328428
# Average loss at step 28000: 3.345966
# Average loss at step 30000: 3.266490
# Nearest to not: still, martinez, kilns, now, romanticism, tort, never, theological,
# Nearest to been: become, be, existed, pluck, come, diminished, xenophobic, irgun,
# Nearest to for: after, of, louth, bowden, against, oklahoma, lem, postgraduate,
# Nearest to at: seventeen, around, pauline, novelette, niggers, semantically, unaccustomed, multiplexed,
# Nearest to about: awesome, symmetrical, births, on, femininity, over, ravalomanana, rambla,
# Nearest to two: six, five, three, one, eva, naturalistic, seven, innocents,
# Nearest to in: within, during, since, between, angina, kemerovo, on, after,
# Nearest to of: nanomachines, indulgent, concerning, messalina, for, in, following, thrower,
# Nearest to this: it, that, which, what, devoutly, another, an, the,
# Nearest to however: while, when, because, although, monopolized, and, that, bogomils,
# Nearest to were: are, was, is, include, docked, be, remain, bhfuil,
# Nearest to new: cleartype, inner, cegep, nfc, conceptual, military, arcs, guignol,
# Nearest to united: kee, latter, vibration, worms, encircled, subtracting, ugle, corner,
# Nearest to would: could, will, should, may, might, must, can, cannot,
# Nearest to there: they, it, she, longer, considered, you, sternum, true,
# Nearest to four: boat, wages, tejada, b, liberals, lsi, eight, ghz,
# Average loss at step 32000: 3.044044
# Average loss at step 34000: 3.240840
# Average loss at step 36000: 3.237143
# Average loss at step 38000: 3.201975
# Average loss at step 40000: 3.199691
# Nearest to not: still, now, sampras, behaved, rebbe, sidecar, romanticism, martens,
# Nearest to been: become, existed, be, occurred, diminished, samsung, was, come,
# Nearest to for: bowden, without, familial, during, after, including, although, font,
# Nearest to at: during, over, near, while, high, after, expeditionary, throughout,
# Nearest to about: awesome, approximately, on, circumventing, over, conceives, crag, femininity,
# Nearest to two: three, five, xli, surprises, four, niall, confronted, six,
# Nearest to in: within, during, throughout, since, between, on, into, tolstoy,
# Nearest to of: during, aikman, brownish, atc, in, jonny, idioms, after,
# Nearest to this: it, which, what, each, any, the, main, applicants,
# Nearest to however: although, but, since, that, while, where, and, though,
# Nearest to were: are, was, is, being, became, be, include, remain,
# Nearest to new: southerly, checks, original, former, cannibalism, oaths, wages, signed,
# Nearest to united: latter, kee, bouvines, subtracting, gne, commonwealth, ambiguous, lacquer,
# Nearest to would: will, could, should, may, might, must, can, cannot,
# Nearest to there: longer, it, considered, sternum, intersputnik, added, spate, whiteface,
# Nearest to four: six, three, five, eight, seven, zero, gathers, samadhi,
# Average loss at step 42000: 3.241295
# Average loss at step 44000: 3.164914
# Average loss at step 46000: 3.163579
# Average loss at step 48000: 3.059309
# Average loss at step 50000: 3.084368
# Nearest to not: never, now, still, nothing, nor, almost, canter, rau,
# Nearest to been: become, occurred, existed, diminished, remained, chats, be, begun,
# Nearest to for: postgraduate, when, markham, font, bowden, ovule, without, including,
# Nearest to at: near, from, whitehouse, around, bde, rinehart, pauline, during,
# Nearest to about: awesome, approximately, over, kermit, around, within, termed, births,
# Nearest to two: three, five, four, eight, nine, six, cde, jeep,
# Nearest to in: during, throughout, within, on, into, from, when, despite,
# Nearest to of: including, ibiza, regarding, joker, ime, messalina, include, brownish,
# Nearest to this: another, which, it, what, gardening, that, devoutly, rosslyn,
# Nearest to however: although, though, because, but, while, where, since, that,
# Nearest to were: are, was, being, is, rushton, be, have, exist,
# Nearest to new: gdansk, different, tubas, sculptured, cleartype, nfc, paphos, mad,
# Nearest to united: addition, future, modems, bouvines, subtracting, gne, kee, abdicating,
# Nearest to would: will, could, may, might, should, can, must, did,
# Nearest to there: considered, they, longer, sternum, spat, awarded, true, it,
# Nearest to four: five, seven, six, three, eight, two, bonaparte, comiskey,
# Average loss at step 52000: 3.118504
# Average loss at step 54000: 3.133990
# Average loss at step 56000: 2.950294
# Average loss at step 58000: 3.049632
# Average loss at step 60000: 3.061377
# Nearest to not: never, kilns, still, now, resilient, debated, canter, nothing,
# Nearest to been: become, occurred, existed, diminished, come, fallen, evolved, begun,
# Nearest to for: balloons, despite, beelzebub, louth, against, administratives, bowden, restorative,
# Nearest to at: near, around, during, harnessing, enjoys, coursing, lederman, leda,
# Nearest to about: on, kermit, approximately, over, femininity, awesome, housekeeper, krajina,
# Nearest to two: three, five, four, eight, six, nine, seven, several,
# Nearest to in: during, since, throughout, against, under, within, tolstoy, on,
# Nearest to of: caius, concerning, aikman, idioms, indulgent, ichi, polluting, nemo,
# Nearest to this: it, which, another, what, occidentalis, pali, each, any,
# Nearest to however: although, while, that, particularly, but, congressmen, kovacs, since,
# Nearest to were: are, was, is, remain, became, including, several, include,
# Nearest to new: gdansk, conceptual, particular, cleartype, secret, paphos, sculptured, boudin,
# Nearest to united: member, gne, modems, addition, lom, dogmatically, biophysics, kee,
# Nearest to would: could, will, might, should, may, must, can, did,
# Nearest to there: longer, they, it, awarded, arrested, glacier, true, unknown,
# Nearest to four: three, six, seven, five, eight, two, zero, nine,
# Average loss at step 62000: 3.040301
# Average loss at step 64000: 2.944685
# Average loss at step 66000: 2.947967
# Average loss at step 68000: 2.997052
# Average loss at step 70000: 3.050142
# Nearest to not: never, still, now, nothing, tort, fairly, respected, tait,
# Nearest to been: become, existed, occurred, fallen, diminished, come, be, remained,
# Nearest to for: after, when, despite, andrade, however, postgraduate, krag, of,
# Nearest to at: near, around, during, in, towards, throughout, on, before,
# Nearest to about: concerning, on, lameness, regarding, genome, hinckley, over, indiscriminately,
# Nearest to two: three, five, six, eight, zero, seven, four, nine,
# Nearest to in: during, throughout, within, on, since, into, through, around,
# Nearest to of: in, following, despite, including, gives, throughout, polluting, ime,
# Nearest to this: another, it, which, what, a, analyte, that, valiantly,
# Nearest to however: although, but, while, because, though, stara, if, when,
# Nearest to were: are, was, is, had, include, fulfill, exist, been,
# Nearest to new: different, conceptual, secret, gdansk, cleartype, keefe, pictish, iigs,
# Nearest to united: modems, lom, u, commonwealth, nde, gne, soundboard, biophysics,
# Nearest to would: will, could, might, should, may, can, must, does,
# Nearest to there: they, given, longrightarrow, sternum, qualified, considered, typical, syndicates,
# Nearest to four: six, five, seven, three, two, steffi, reruns, patmos,
# Average loss at step 72000: 2.963769
# Average loss at step 74000: 2.892854
# Average loss at step 76000: 3.005812
# Average loss at step 78000: 3.030053
# Average loss at step 80000: 2.865882
# Nearest to not: never, nothing, now, almost, already, cumbersome, buried, resilient,
# Nearest to been: become, diminished, occurred, come, existed, fallen, connell, appeared,
# Nearest to for: meanwhile, without, unep, towards, mellon, weavers, defraud, electroconvulsive,
# Nearest to at: near, during, enact, lowest, around, peck, towards, daley,
# Nearest to about: concerning, regarding, approximately, over, kermit, awesome, sephardim, further,
# Nearest to two: three, six, four, zero, five, harlan, canc, dtv,
# Nearest to in: within, during, throughout, including, under, on, from, digesting,
# Nearest to of: following, including, while, concerning, nanomachines, behind, regarding, aikman,
# Nearest to this: which, another, it, what, that, the, itself, a,
# Nearest to however: although, though, but, because, while, where, since, that,
# Nearest to were: are, was, is, misanthropy, had, paradoxical, remained, newly,
# Nearest to new: different, conceptual, separate, local, secret, superiors, small, sculptured,
# Nearest to united: lom, modems, confederate, german, intergovernmental, abdicating, biophysics, u,
# Nearest to would: could, might, will, can, must, may, should, shall,
# Nearest to there: they, it, longer, still, she, whiteface, clergyman, sternum,
# Nearest to four: five, six, seven, three, eight, zero, nine, two,
# Average loss at step 82000: 2.952354
# Average loss at step 84000: 2.914990
# Average loss at step 86000: 2.939536
# Average loss at step 88000: 2.956427
# Average loss at step 90000: 2.844173
# Nearest to not: never, nothing, still, now, almost, already, informs, also,
# Nearest to been: become, occurred, diminished, existed, fallen, begun, already, come,
# Nearest to for: after, emigrants, font, balloons, markham, bony, culminate, truce,
# Nearest to at: near, around, during, novelette, croat, district, enact, fittings,
# Nearest to about: approximately, awesome, over, catchers, omer, teammates, cth, hypothermia,
# Nearest to two: six, three, five, seven, four, nine, zero, one,
# Nearest to in: throughout, during, since, within, on, outside, of, after,
# Nearest to of: concerning, following, in, including, regarding, include, without, despite,
# Nearest to this: it, which, another, what, a, any, everlast, the,
# Nearest to however: although, though, but, if, where, until, when, etc,
# Nearest to were: are, was, is, include, newly, various, rushton, have,
# Nearest to new: gdansk, local, conceptual, inseparable, paphos, separate, photograph, sculptured,
# Nearest to united: lom, abdicating, u, venom, confederate, modems, biophysics, arizona,
# Nearest to would: will, might, could, should, may, can, must, cannot,
# Nearest to there: it, they, she, longer, still, considered, sternum, cura,
# Nearest to four: six, three, seven, five, zero, eight, two, nine,
# Average loss at step 92000: 2.909136
# Average loss at step 94000: 2.890862
# Average loss at step 96000: 2.718893
# Average loss at step 98000: 2.469636
# Average loss at step 100000: 2.729365
# Nearest to not: nothing, never, almost, now, therefore, still, fairly, rarely,
# Nearest to been: become, occurred, gone, existed, diminished, fallen, come, grown,
# Nearest to for: including, after, counterattacks, krag, markham, electroconvulsive, louth, meanwhile,
# Nearest to at: near, during, around, in, outside, napo, spaulding, novelette,
# Nearest to about: concerning, regarding, entitled, teammates, awesome, indiscriminately, krajina, on,
# Nearest to two: three, five, four, six, seven, joanie, zero, starcraft,
# Nearest to in: outside, during, within, throughout, near, at, of, on,
# Nearest to of: in, including, represents, polluting, containing, sees, ime, ichi,
# Nearest to this: which, another, some, it, devoutly, any, griffon, that,
# Nearest to however: but, although, though, while, since, that, unlike, until,
# Nearest to were: are, was, have, had, include, being, various, valproate,
# Nearest to new: conceptual, cryptanalytic, local, paphos, housewives, keefe, iigs, cleartype,
# Nearest to united: confederate, faction, lom, arizona, venom, abdicating, durable, us,
# Nearest to would: will, might, could, should, must, can, may, shall,
# Nearest to there: they, still, longer, it, sternum, he, clergyman, awarded,
# Nearest to four: seven, six, three, five, eight, zero, two, nine,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# Some clusters are less obvious (like the standalone characters), but it clearly totaly works.

# %% [markdown]
# How does your CBOW model perform compared to the given Word2Vec model? (to be answered)
