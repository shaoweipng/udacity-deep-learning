# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
print(data[:10])
print(count[:10])
print(dictionary.items()[:10])
print(reverse_dictionary.items()[:10])
# Out:
# [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]
# [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764), ('in', 372201), ('a', 325873), ('to', 316376), ('zero', 264975), ('nine', 250430)]
# [('fawn', 45848), ('homomorphism', 9648), ('nordisk', 39343), ('nunnery', 36075), ('chthonic', 33554), ('sowell', 40562), ('sonja', 38175), ('showa', 32906), ('woods', 6263), ('hsv', 44222)]
# [(0, 'UNK'), (1, 'the'), (2, 'of'), (3, 'and'), (4, 'one'), (5, 'in'), (6, 'a'), (7, 'to'), (8, 'zero'), (9, 'nine')]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:32]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=16, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(16)])
    
for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 1
    batch, labels = generate_batch(batch_size=16, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(16)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'UNK', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term', 'of', 'of', 'abuse', 'abuse', 'first', 'first', 'used', 'used']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'of', 'a', 'abuse', 'term', 'of', 'first', 'abuse', 'used', 'against', 'first']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a', 'term', 'term', 'term', 'term', 'of', 'of', 'of', 'of']
#     labels: ['term', 'a', 'originated', 'anarchism', 'of', 'as', 'originated', 'term', 'a', 'abuse', 'of', 'as', 'a', 'first', 'term', 'abuse']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['as', 'as', 'a', 'a', 'term', 'term', 'of', 'of', 'abuse', 'abuse', 'first', 'first', 'used', 'used', 'against', 'against']
#     labels: ['a', 'originated', 'as', 'term', 'a', 'of', 'term', 'abuse', 'of', 'first', 'abuse', 'used', 'first', 'against', 'early', 'used']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['a', 'a', 'a', 'a', 'term', 'term', 'term', 'term', 'of', 'of', 'of', 'of', 'abuse', 'abuse', 'abuse', 'abuse']
#     labels: ['term', 'of', 'originated', 'as', 'as', 'abuse', 'a', 'of', 'a', 'first', 'abuse', 'term', 'used', 'of', 'term', 'first']

# %% [markdown]
# Note: the labels is a sliding random value of the word surrounding the words of the batch.

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.947935
# Nearest to history: spray, commencement, lr, peacock, fournier, undergoing, philia, ced,
# Nearest to known: austral, programmatic, circles, remark, queenie, ashton, tess, sorbonne,
# Nearest to with: sarajevo, faire, blitz, gibbs, maradona, meson, setback, takes,
# Nearest to most: bobby, atlantic, laypeople, ting, prana, mononoke, marque, hirschfeld,
# Nearest to these: electromechanical, anecdotal, renal, verbs, makran, pilgrimage, coriander, commuted,
# Nearest to state: tris, morava, ftp, multics, inanna, fees, cornerstone, gwen,
# Nearest to at: lofty, rough, communism, nursultan, something, columnists, mawson, copperfield,
# Nearest to are: conformity, cryopreservation, zurich, supergravity, mitigation, father, buckyballs, revocation,
# Nearest to from: follett, globalization, avenged, beagle, prolog, ing, mas, objectively,
# Nearest to d: failing, umlauts, boreal, brandon, apparel, but, plugins, ruth,
# Nearest to this: phishing, gregorio, foundry, portillo, jerry, likud, tacit, eh,
# Nearest to an: beef, synchronisation, mendel, subclasses, threshold, stands, benito, poised,
# Nearest to they: ims, formatting, drop, intermittent, opposition, fluctuate, tracking, determinate,
# Nearest to states: maury, krakatoa, mottled, hj, bilirubin, deianira, foodcrops, cowley,
# Nearest to so: releasing, northerners, kyrgyz, honey, mouths, chubut, ojibwa, viscous,
# Nearest to some: tenzin, decarlo, prisoner, xanadu, ohio, toolbars, rosalyn, wholly,
# Average loss at step 2000: 4.365612
# Average loss at step 4000: 3.862896
# Average loss at step 6000: 3.792907
# Average loss at step 8000: 3.685474
# Average loss at step 10000: 3.614118
# Nearest to history: philia, phillies, our, man, rufinus, besiege, form, portuguese,
# Nearest to known: circles, scandalous, remark, queenie, methadone, swampy, ashton, toy,
# Nearest to with: between, in, on, by, counter, into, for, bodhi,
# Nearest to most: mononoke, laypeople, prana, okavango, reminder, unenforceable, unwieldy, sigurd,
# Nearest to these: commuted, imitates, arnstadt, some, mammoth, athlete, other, verbs,
# Nearest to state: multics, morava, regan, service, caving, africa, gwen, tris,
# Nearest to at: in, under, handbook, of, della, prep, on, reduplication,
# Nearest to are: were, is, have, asian, thwart, sinti, adjacency, chic,
# Nearest to from: in, beck, ing, globalization, objectively, veritable, bagpuss, goal,
# Nearest to d: ruth, boreal, majlis, b, umlauts, instructs, targum, monomer,
# Nearest to this: it, the, which, that, hamill, grafton, a, strolling,
# Nearest to an: poised, beef, subclasses, diplomat, belzec, broken, browse, threshold,
# Nearest to they: he, we, not, there, it, fluctuate, determinate, tracking,
# Nearest to states: pepsi, maury, mottled, troops, isometric, hj, laird, foodcrops,
# Nearest to so: zinn, kyrgyz, consistent, suspect, michelob, stresemann, austria, carvings,
# Nearest to some: many, toolbars, pillar, xanadu, imitates, brumaire, inapplicable, gentile,
# Average loss at step 12000: 3.605054
# Average loss at step 14000: 3.569819
# Average loss at step 16000: 3.407774
# Average loss at step 18000: 3.463417
# Average loss at step 20000: 3.535700
# Nearest to history: phillies, rufinus, philia, action, man, form, lr, editorial,
# Nearest to known: circles, remark, described, scandalous, swampy, such, used, well,
# Nearest to with: between, in, interbreeding, ballad, tithes, acute, counter, sector,
# Nearest to most: more, mononoke, many, some, laypeople, prana, unwieldy, unenforceable,
# Nearest to these: many, some, other, all, commuted, imitates, heeled, which,
# Nearest to state: gwen, fees, unbalanced, regan, sequences, faramir, tris, caving,
# Nearest to at: in, under, on, around, horrors, cao, like, cornerstones,
# Nearest to are: were, have, is, sinti, chic, asian, other, suharto,
# Nearest to from: into, between, veritable, through, in, and, photo, moths,
# Nearest to d: b, majlis, blaze, apparel, yielding, ruth, woolly, j,
# Nearest to this: it, which, the, a, any, seymour, what, curium,
# Nearest to an: the, subclasses, poised, dissociative, belzec, beef, harbin, successfully,
# Nearest to they: we, he, there, you, who, it, not, fluctuate,
# Nearest to states: pepsi, laird, troops, isometric, countries, foodcrops, hj, iowa,
# Nearest to so: zinn, michelob, stresemann, kyrgyz, nouakchott, consistent, ear, suspect,
# Nearest to some: many, these, several, most, any, all, their, gaeilge,
# Average loss at step 22000: 3.503554
# Average loss at step 24000: 3.493263
# Average loss at step 26000: 3.482399
# Average loss at step 28000: 3.477745
# Average loss at step 30000: 3.503830
# Nearest to history: action, rufinus, analysis, form, philia, alliance, madhuri, transportation,
# Nearest to known: described, well, circles, used, such, keflav, remark, swampy,
# Nearest to with: between, outfielders, gothenburg, in, among, tithes, for, pashtuns,
# Nearest to most: more, mononoke, many, some, laypeople, reminder, prana, extremism,
# Nearest to these: some, many, such, all, other, they, several, imitates,
# Nearest to state: gwen, regan, fees, matriculation, sequences, brittany, government, barracuda,
# Nearest to at: in, under, during, around, metabolites, horrors, prep, ct,
# Nearest to are: were, have, is, chic, intrigue, grok, other, be,
# Nearest to from: into, through, under, in, between, during, veritable, painfully,
# Nearest to d: b, j, majlis, gradient, herm, latvia, wa, ruth,
# Nearest to this: it, which, what, seymour, any, strolling, not, protest,
# Nearest to an: subclasses, synchronisation, poised, belzec, diplomat, beef, dissociative, binding,
# Nearest to they: we, there, he, you, who, it, not, these,
# Nearest to states: pepsi, laird, troops, countries, maury, quarreled, iowa, isometric,
# Nearest to so: zinn, whey, combinatorics, michelob, superconducting, ear, ascends, stresemann,
# Nearest to some: many, these, several, any, most, all, such, their,
# Average loss at step 32000: 3.496974
# Average loss at step 34000: 3.493194
# Average loss at step 36000: 3.456058
# Average loss at step 38000: 3.305612
# Average loss at step 40000: 3.429902
# Nearest to history: action, rufinus, analysis, philia, form, alternates, stairway, balkan,
# Nearest to known: used, such, described, well, remark, circles, keflav, methadone,
# Nearest to with: between, outfielders, tithes, upsurge, fas, gothenburg, setback, by,
# Nearest to most: more, some, mononoke, many, laypeople, reminder, less, abhidharma,
# Nearest to these: many, some, they, such, both, several, numerous, all,
# Nearest to state: government, gwen, regan, premier, barracuda, nepotism, fees, sequences,
# Nearest to at: during, under, on, in, ct, around, cornerstones, bestiary,
# Nearest to are: were, have, is, while, be, include, intrigue, grok,
# Nearest to from: into, through, veritable, of, by, cao, during, under,
# Nearest to d: b, UNK, j, majlis, novello, herm, ruth, gradient,
# Nearest to this: which, it, the, that, what, strolling, curium, another,
# Nearest to an: subclasses, synchronisation, gesserit, zubaydah, dissociative, update, poised, payback,
# Nearest to they: we, there, you, he, it, these, who, she,
# Nearest to states: countries, pepsi, laird, kingdom, isometric, troops, foodcrops, equalized,
# Nearest to so: combinatorics, whey, zinn, soils, superconducting, sulfate, ear, auras,
# Nearest to some: many, these, several, any, certain, pentagonal, most, those,
# Average loss at step 42000: 3.435997
# Average loss at step 44000: 3.451936
# Average loss at step 46000: 3.454169
# Average loss at step 48000: 3.357529
# Average loss at step 50000: 3.387780
# Nearest to history: rufinus, balkan, analysis, portuguese, harpercollins, bix, stairway, yitzchak,
# Nearest to known: used, such, described, well, regarded, defined, swampy, keflav,
# Nearest to with: between, outfielders, by, without, pashtuns, streptococcus, bodhi, upsurge,
# Nearest to most: more, mononoke, less, many, some, reminder, prana, archetypical,
# Nearest to these: some, many, both, such, those, all, several, various,
# Nearest to state: government, gwen, premier, ami, rheingold, fees, steamboat, barracuda,
# Nearest to at: during, around, under, on, in, near, earths, ct,
# Nearest to are: were, is, have, intrigue, pineapples, thwart, be, grok,
# Nearest to from: through, into, during, in, veritable, under, between, ing,
# Nearest to d: b, j, novello, e, triomphe, apparel, gradient, saviour,
# Nearest to this: which, it, burn, the, some, he, corpora, that,
# Nearest to an: subclasses, diplomat, jg, synchronisation, belzec, zubaydah, grieg, dissociative,
# Nearest to they: we, there, he, you, she, it, these, eventually,
# Nearest to states: laird, kingdom, countries, isometric, pepsi, foodcrops, equalized, formalization,
# Nearest to so: then, combinatorics, too, if, sunspot, usgs, accommodate, androgens,
# Nearest to some: many, several, these, any, those, their, both, numerous,
# Average loss at step 52000: 3.433077
# Average loss at step 54000: 3.426122
# Average loss at step 56000: 3.434343
# Average loss at step 58000: 3.391593
# Average loss at step 60000: 3.393088
# Nearest to history: demographics, list, rufinus, action, transportation, analysis, balkan, pleasuredome,
# Nearest to known: used, such, described, defined, regarded, well, methadone, circles,
# Nearest to with: between, in, gothenburg, when, including, among, into, outfielders,
# Nearest to most: more, many, some, mononoke, oldest, reminder, all, prana,
# Nearest to these: some, both, many, those, such, several, all, they,
# Nearest to state: government, premier, gwen, labour, fees, city, ami, states,
# Nearest to at: under, around, near, in, metabolites, during, ct, chronically,
# Nearest to are: were, is, have, intrigue, include, be, boisbaudran, although,
# Nearest to from: through, into, in, veritable, favoritism, including, quakers, prescriptive,
# Nearest to d: b, j, saviour, triomphe, e, novello, herm, p,
# Nearest to this: it, which, that, there, the, burn, still, what,
# Nearest to an: subclasses, diplomat, dissociative, gesserit, broken, browse, implied, astronomers,
# Nearest to they: we, there, he, you, she, it, these, who,
# Nearest to states: kingdom, countries, laird, pepsi, nations, isometric, troops, formalization,
# Nearest to so: too, if, then, np, something, duff, gunnar, accommodate,
# Nearest to some: many, several, these, any, all, most, certain, their,
# Average loss at step 62000: 3.237103
# Average loss at step 64000: 3.257991
# Average loss at step 66000: 3.405030
# Average loss at step 68000: 3.395142
# Average loss at step 70000: 3.360952
# Nearest to history: list, demographics, analysis, spectrum, rufinus, stairway, replication, form,
# Nearest to known: used, regarded, such, defined, described, well, seen, methadone,
# Nearest to with: between, among, outfielders, when, while, ballad, upsurge, swedenborg,
# Nearest to most: more, some, many, less, mononoke, abhidharma, all, prana,
# Nearest to these: some, such, various, many, those, several, all, their,
# Nearest to state: government, premier, gwen, city, states, unbalanced, northwest, kes,
# Nearest to at: pogrom, during, around, on, under, after, in, near,
# Nearest to are: were, is, have, include, although, including, be, grok,
# Nearest to from: through, into, under, veritable, lingus, using, during, in,
# Nearest to d: b, j, saviour, novello, herm, z, apparel, triomphe,
# Nearest to this: it, which, that, the, what, itself, reinterpretation, burn,
# Nearest to an: subclasses, dissociative, the, gesserit, fricatives, diplomat, obeying, binding,
# Nearest to they: we, there, he, you, it, she, eventually, who,
# Nearest to states: kingdom, nations, laird, countries, iowa, isometric, quarreled, state,
# Nearest to so: too, then, if, duff, androgens, gunnar, digests, therefore,
# Nearest to some: many, several, these, all, most, any, various, pentagonal,
# Average loss at step 72000: 3.369307
# Average loss at step 74000: 3.348458
# Average loss at step 76000: 3.305026
# Average loss at step 78000: 3.351554
# Average loss at step 80000: 3.375872
# Nearest to history: list, stairway, spectrum, emergence, replication, abeda, analysis, rufinus,
# Nearest to known: used, regarded, described, defined, such, seen, called, classified,
# Nearest to with: between, swedenborg, when, among, into, against, in, or,
# Nearest to most: more, some, many, less, abhidharma, especially, among, oldest,
# Nearest to these: several, various, some, those, many, such, both, different,
# Nearest to state: government, city, premier, ami, pln, college, states, gwen,
# Nearest to at: in, around, during, after, on, cornerstones, indeterminate, wandering,
# Nearest to are: were, although, include, have, is, intrigue, pineapples, chic,
# Nearest to from: into, through, under, veritable, beck, after, by, between,
# Nearest to d: b, saviour, j, z, p, unsurprisingly, f, novello,
# Nearest to this: it, which, the, itself, that, what, some, he,
# Nearest to an: subclasses, belzec, poised, diplomat, dissociative, browse, gesserit, implied,
# Nearest to they: we, he, there, she, you, it, not, these,
# Nearest to states: kingdom, laird, nations, countries, iowa, equalized, troops, jacksonville,
# Nearest to so: if, then, too, accommodate, androgens, enough, something, digests,
# Nearest to some: many, several, various, these, most, any, numerous, certain,
# Average loss at step 82000: 3.408700
# Average loss at step 84000: 3.409068
# Average loss at step 86000: 3.390646
# Average loss at step 88000: 3.350771
# Average loss at step 90000: 3.363914
# Nearest to history: list, lists, stairway, tanning, definition, review, demographics, spectrum,
# Nearest to known: used, such, described, regarded, defined, called, seen, part,
# Nearest to with: between, in, including, by, when, misalignment, among, while,
# Nearest to most: some, more, many, less, reminder, oldest, especially, gadamer,
# Nearest to these: many, various, several, such, some, both, those, which,
# Nearest to state: government, city, premier, jets, pln, aravalli, gwen, regan,
# Nearest to at: around, during, on, under, near, while, cornerstones, in,
# Nearest to are: were, include, is, have, although, these, those, intrigue,
# Nearest to from: through, during, under, into, between, quakers, favoritism, before,
# Nearest to d: b, unsurprisingly, kg, z, novello, apparel, heather, herm,
# Nearest to this: it, which, the, some, another, itself, burn, eschatological,
# Nearest to an: subclasses, diplomat, dissociative, gesserit, poised, humanly, browse, belzec,
# Nearest to they: we, he, there, you, she, it, but, not,
# Nearest to states: kingdom, nations, laird, countries, equalized, jacksonville, iowa, state,
# Nearest to so: too, if, later, androgens, then, although, therefore, thoroughfare,
# Nearest to some: many, several, most, these, any, both, all, certain,
# Average loss at step 92000: 3.397427
# Average loss at step 94000: 3.248209
# Average loss at step 96000: 3.356282
# Average loss at step 98000: 3.238855
# Average loss at step 100000: 3.355578
# Nearest to history: list, science, demographics, pharmacological, stairway, galatia, replication, definition,
# Nearest to known: such, regarded, used, described, defined, seen, part, possible,
# Nearest to with: between, including, when, into, upsurge, among, swedenborg, for,
# Nearest to most: more, less, reminder, especially, some, many, oldest, gadamer,
# Nearest to these: several, various, some, many, those, all, such, numerous,
# Nearest to state: city, government, premier, pln, jets, aravalli, gwen, college,
# Nearest to at: during, near, in, on, around, cornerstones, rowland, bulb,
# Nearest to are: were, although, include, have, while, is, including, those,
# Nearest to from: through, in, into, favoritism, veritable, during, including, quakers,
# Nearest to d: b, unsurprisingly, z, sqrt, kg, reine, j, lemming,
# Nearest to this: which, it, itself, ethiopic, another, popularize, he, what,
# Nearest to an: subclasses, diplomat, dissociative, gesserit, poised, hollis, belzec, harbin,
# Nearest to they: we, he, there, you, it, she, i, not,
# Nearest to states: kingdom, nations, laird, countries, equalized, iowa, state, quarreled,
# Nearest to so: then, if, too, thus, therefore, sometimes, when, androgens,
# Nearest to some: many, several, these, any, various, numerous, all, certain,

# %%
print(final_embeddings[0])
# Out:
# [ 0.1941034  -0.0845267  -0.12426488  0.1840165   0.17685007 -0.014712
#   0.01661829 -0.03610488  0.10705339 -0.04112897 -0.00362786 -0.06850139
#  -0.05170843  0.00687794  0.12981299  0.01702328 -0.11221832 -0.04680927
#   0.03975043 -0.02251458 -0.13714688  0.00643358 -0.00097667 -0.11321861
#   0.02347721  0.06076517 -0.02010881 -0.1149926  -0.19876391 -0.05356849
#   0.00323464  0.10836592 -0.15115424 -0.06587104 -0.00661932 -0.01062037
#  -0.09234126  0.04135265  0.02622768  0.15823542 -0.07745458  0.10745096
#  -0.0502804  -0.01965179  0.0298692  -0.07216269 -0.09705626  0.04379353
#  -0.05333636 -0.02829226  0.07750987 -0.08677343  0.13432182 -0.03600266
#   0.07114012 -0.06509603 -0.02385535  0.09125306 -0.07266849 -0.00960893
#  -0.05043237 -0.04008224  0.06555638  0.00523916 -0.01498869  0.08444336
#   0.06140398 -0.09697893  0.07406411 -0.02246837 -0.32179689 -0.02901259
#   0.01144159 -0.0702516  -0.22669008  0.0259337  -0.1349595   0.0895275
#  -0.00431831  0.00047554  0.00747186 -0.08624758  0.07235151 -0.12335134
#   0.13279772  0.14650905  0.0531266  -0.0829088   0.02980069  0.05570659
#  -0.13979563 -0.10035203  0.02435454 -0.11309049 -0.01933759  0.07002781
#  -0.00583385  0.0557126   0.04145043 -0.03946318  0.04327407 -0.11085839
#  -0.04609756 -0.11946728  0.07410513 -0.04232362  0.13391533 -0.00627821
#   0.06166793  0.07762199  0.14347908 -0.05107509  0.02463106  0.00764135
#   0.02438529  0.04863849 -0.17073832  0.11127561 -0.05400115 -0.13102314
#   0.06317039  0.0270542   0.10170386  0.07907061 -0.0650945   0.1039783
#  -0.02721491 -0.06224164]

# %%
print(np.sum(np.square(final_embeddings[0])))
# Out:
# 1.0

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    # just for testing
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    # iterate to the next buffer
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
  data_index = 0
  batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
  print('\nwith bag_window = %d:' % (bag_window))  
  print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
###skip_window = 1 # How many words to consider left and right.
###num_skips = 2 # How many times to reuse an input to generate a label.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embeds, 1),
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 6.640427
# Nearest to such: fontsize, bucks, awakened, erm, ietf, stipulate, steve, terminated,
# Nearest to can: implanted, thirst, estrogen, teardrop, short, serine, hussars, scenery,
# Nearest to at: grammatically, tensile, abl, debate, uncircumcised, betray, workability, fangio,
# Nearest to people: pretence, reasoner, chennai, compiles, prevalence, patterning, shatz, clause,
# Nearest to united: strictest, tiberius, intended, ncia, davids, tonga, restores, fraudulent,
# Nearest to will: tulsa, lusitania, unshielded, darby, explorers, benchmark, softly, cpan,
# Nearest to a: cigar, baccalaureate, csce, saarc, philharmonic, claudine, impart, butane,
# Nearest to that: devas, biggs, bg, chancellor, tempos, columbo, coptic, dwight,
# Nearest to their: acrimonious, somali, condone, objective, motherboard, clp, hovercraft, magee,
# Nearest to during: combinatorial, true, atherosclerosis, hilbert, limericks, organiser, cond, holiday,
# Nearest to other: virus, preparing, gerald, cnidarians, gulliver, pmod, tight, reinforcing,
# Nearest to american: dawn, julius, marched, glider, suckling, smokeless, rare, bases,
# Nearest to used: ghee, expel, barricade, icy, panentheistic, keen, dionysus, lucian,
# Nearest to zero: freedmen, hijra, outing, nest, decades, ro, giga, colonisation,
# Nearest to three: derogatory, exploring, fiennes, oblivious, lombard, beefheart, barfield, expositor,
# Nearest to been: paths, detector, inhaled, physiologically, biosphere, recompilation, presto, moonraker,
# Average loss at step 2000: 4.601866
# Average loss at step 4000: 3.981472
# Average loss at step 6000: 3.649702
# Average loss at step 8000: 3.680004
# Average loss at step 10000: 3.628669
# Nearest to such: well, matilda, many, middlesex, result, known, described, spaniards,
# Nearest to can: may, will, would, could, must, should, might, cannot,
# Nearest to at: in, during, greco, before, chios, over, coastal, troubleshooting,
# Nearest to people: years, ink, symmetrically, feed, conquistador, neko, ghb, jocular,
# Nearest to united: grimoires, objector, kon, philosophers, lining, parry, retreat, tonga,
# Nearest to will: can, would, may, must, should, could, graduating, did,
# Nearest to a: any, the, an, another, each, falconer, emissary, echolocation,
# Nearest to that: which, however, this, feuding, medication, logarithmically, fishers, cru,
# Nearest to their: its, his, her, the, iggy, maddox, debug, shotgun,
# Nearest to during: after, in, at, hilbert, over, norsemen, sheepdog, watercolors,
# Nearest to other: different, these, materia, sherbrooke, freestyle, asa, those, door,
# Nearest to american: cody, marched, bowell, mit, litchfield, dawn, cranston, spate,
# Nearest to used: referred, considered, known, available, found, said, veracity, basel,
# Nearest to zero: eight, nine, six, five, two, seven, ionosphere, four,
# Nearest to three: four, six, seven, eight, nine, one, two, uris,
# Nearest to been: become, consistory, mailer, ambients, rubble, mycoplasma, kyrgyz, independently,
# Average loss at step 12000: 3.491149
# Average loss at step 14000: 3.469396
# Average loss at step 16000: 3.453882
# Average loss at step 18000: 3.392412
# Average loss at step 20000: 3.234035
# Nearest to such: well, known, ignaz, regarded, jagie, beja, result, alpacas,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to at: after, fangio, sacrificed, before, until, micros, forma, spokes,
# Nearest to people: smyth, ink, reconstructionism, letters, brainchild, those, players, lighted,
# Nearest to united: grimoires, objector, taxa, constituted, kon, retreat, tonga, anxious,
# Nearest to will: would, can, may, must, could, should, might, does,
# Nearest to a: the, another, any, every, attesting, dell, each, an,
# Nearest to that: which, what, where, this, when, who, fez, glassy,
# Nearest to their: its, his, her, these, the, iggy, debug, maddox,
# Nearest to during: until, before, in, after, throughout, segment, since, blossom,
# Nearest to other: various, different, these, many, those, some, tremendous, prophesied,
# Nearest to american: cody, spate, gestapo, dawn, workability, america, bowell, interpret,
# Nearest to used: known, referred, found, seen, available, considered, called, sold,
# Nearest to zero: three, seven, wellesley, four, eight, two, bucaram, h,
# Nearest to three: seven, six, eight, five, four, two, zero, nine,
# Nearest to been: become, ambients, rubble, inexperience, amine, consistory, be, visionary,
# Average loss at step 22000: 3.328513
# Average loss at step 24000: 3.329906
# Average loss at step 26000: 3.340496
# Average loss at step 28000: 3.302743
# Average loss at step 30000: 3.318757
# Nearest to such: well, described, seen, known, result, regarded, far, beja,
# Nearest to can: could, may, will, would, should, might, must, cannot,
# Nearest to at: within, before, depot, ambush, deposited, caricatured, fangio, troubleshooting,
# Nearest to people: individuals, those, animals, companies, players, kings, slings, women,
# Nearest to united: grimoires, taxa, conjure, zx, objector, parry, constituted, downplayed,
# Nearest to will: would, can, may, could, should, must, might, cannot,
# Nearest to a: another, the, any, this, every, no, an, continuity,
# Nearest to that: which, what, however, where, although, this, fez, when,
# Nearest to their: its, his, her, our, iggy, the, your, maddox,
# Nearest to during: until, before, throughout, after, since, when, in, against,
# Nearest to other: various, different, those, smaller, alphorn, amylase, several, individual,
# Nearest to american: america, british, workability, gibbs, kodansha, foobar, teborg, defy,
# Nearest to used: referred, found, known, available, considered, seen, described, called,
# Nearest to zero: five, seven, three, eight, six, nine, four, archdukes,
# Nearest to three: seven, five, four, eight, six, zero, two, nine,
# Nearest to been: become, inexperience, amine, occurred, paternal, rubble, selfishness, consistory,
# Average loss at step 32000: 3.239177
# Average loss at step 34000: 3.182169
# Average loss at step 36000: 3.176055
# Average loss at step 38000: 3.175378
# Average loss at step 40000: 3.146691
# Nearest to such: well, described, seen, known, opposed, regarded, follows, result,
# Nearest to can: could, may, must, might, should, would, will, cannot,
# Nearest to at: fangio, during, within, ambush, when, forma, until, demolished,
# Nearest to people: those, children, individuals, students, women, players, countries, animals,
# Nearest to united: grimoires, anxious, objector, lining, conjure, hardback, zx, retreat,
# Nearest to will: would, should, must, could, can, may, might, cannot,
# Nearest to a: another, the, any, his, every, each, emissary, an,
# Nearest to that: which, although, however, what, fez, methodism, dwight, how,
# Nearest to their: his, its, her, the, our, your, these, maddox,
# Nearest to during: before, in, throughout, until, since, after, against, through,
# Nearest to other: various, different, rather, others, these, literary, maceo, sherbrooke,
# Nearest to american: british, litchfield, foobar, luisa, canadian, english, peanuts, picturesque,
# Nearest to used: referred, known, seen, considered, found, available, designed, given,
# Nearest to zero: five, four, seven, six, eight, nine, million, two,
# Nearest to three: four, five, six, two, seven, eight, tau, zero,
# Nearest to been: become, occurred, inexperience, ashore, evolved, rubble, consistory, was,
# Average loss at step 42000: 3.176162
# Average loss at step 44000: 3.002648
# Average loss at step 46000: 3.116159
# Average loss at step 48000: 3.102579
# Average loss at step 50000: 3.055995
# Nearest to such: well, seen, known, opposed, just, follows, described, abiword,
# Nearest to can: may, could, should, might, must, cannot, would, shall,
# Nearest to at: fangio, near, in, before, towards, micros, advertise, catastrophism,
# Nearest to people: children, those, players, individuals, someone, speakers, ink, person,
# Nearest to united: grimoires, member, anxious, zx, lining, rationalize, namath, retreat,
# Nearest to will: would, should, must, may, could, might, does, did,
# Nearest to a: another, the, any, bertha, oracles, every, cedric, wenham,
# Nearest to that: which, where, what, if, because, this, however, although,
# Nearest to their: its, his, her, our, the, your, whose, both,
# Nearest to during: throughout, before, until, after, in, since, through, following,
# Nearest to other: various, different, smaller, uzbek, riverside, rather, sinauer, individual,
# Nearest to american: america, canadian, indian, german, french, british, hui, glycosylation,
# Nearest to used: seen, referred, available, considered, found, known, defined, applied,
# Nearest to zero: five, seven, six, eight, nine, three, four, fy,
# Nearest to three: four, five, seven, six, eight, zero, two, nine,
# Nearest to been: become, evolved, several, inexperience, occurred, grown, gone, fallen,
# Average loss at step 52000: 3.009297
# Average loss at step 54000: 2.974525
# Average loss at step 56000: 3.110112
# Average loss at step 58000: 3.052065
# Average loss at step 60000: 2.892377
# Nearest to such: well, opposed, seen, known, described, regarded, result, follows,
# Nearest to can: could, should, may, must, might, cannot, would, will,
# Nearest to at: near, towards, troubleshooting, moron, on, in, fangio, during,
# Nearest to people: individuals, children, men, others, things, players, women, figures,
# Nearest to united: grimoires, mckinley, member, anxious, smash, hardback, zx, rationalize,
# Nearest to will: would, must, should, could, can, might, may, cannot,
# Nearest to a: another, the, any, every, oracles, enough, pumice, emissary,
# Nearest to that: which, when, what, where, this, though, however, how,
# Nearest to their: its, his, her, the, our, your, iggy, any,
# Nearest to during: throughout, before, until, since, after, in, following, neologism,
# Nearest to other: various, individual, smaller, different, gluck, regional, those, local,
# Nearest to american: canadian, british, australian, america, italian, indian, bois, extradition,
# Nearest to used: referred, seen, considered, found, available, known, described, designed,
# Nearest to zero: five, nine, eight, six, four, two, nonsensical, kilometers,
# Nearest to three: four, five, six, seven, eight, chubut, two, zero,
# Nearest to been: become, fallen, occurred, evolved, be, existed, was, begun,
# Average loss at step 62000: 3.039007
# Average loss at step 64000: 3.064242
# Average loss at step 66000: 3.019204
# Average loss at step 68000: 2.912410
# Average loss at step 70000: 2.975775
# Nearest to such: well, opposed, serve, seen, result, known, far, follows,
# Nearest to can: could, should, may, must, might, will, would, cannot,
# Nearest to at: near, towards, fangio, in, press, carnap, on, during,
# Nearest to people: individuals, players, children, men, someone, persons, fans, jews,
# Nearest to united: grimoires, jong, anxious, change, hardback, case, addition, uk,
# Nearest to will: would, can, must, could, should, might, may, cannot,
# Nearest to a: another, any, the, every, no, emissary, each, this,
# Nearest to that: which, this, what, however, where, brumaire, how, courant,
# Nearest to their: its, his, her, your, the, our, my, iggy,
# Nearest to during: throughout, before, in, since, until, within, despite, through,
# Nearest to other: various, different, fewer, tremendous, both, sherbrooke, multiple, these,
# Nearest to american: canadian, america, australian, italian, americans, hui, myr, professional,
# Nearest to used: referred, designed, applied, seen, described, found, intended, written,
# Nearest to zero: million, bc, eight, seven, six, two, nine, three,
# Nearest to three: five, four, seven, six, eight, two, zero, p,
# Nearest to been: become, occurred, evolved, gone, come, fallen, grown, remained,
# Average loss at step 72000: 2.971348
# Average loss at step 74000: 2.985368
# Average loss at step 76000: 2.921872
# Average loss at step 78000: 2.914738
# Average loss at step 80000: 2.947883
# Nearest to such: well, opposed, seen, result, known, far, serve, follows,
# Nearest to can: may, could, must, might, cannot, will, should, would,
# Nearest to at: near, towards, during, fangio, mozambican, ries, micros, after,
# Nearest to people: individuals, persons, players, companies, children, those, men, person,
# Nearest to united: member, addition, anxious, dhekelia, us, case, uk, simultaneously,
# Nearest to will: would, might, should, can, must, could, may, cannot,
# Nearest to a: any, another, the, lutenist, this, every, wenham, bertha,
# Nearest to that: which, where, although, feuding, celestial, ultrasound, following, however,
# Nearest to their: its, his, your, her, our, my, iggy, the,
# Nearest to during: throughout, until, in, after, since, before, despite, at,
# Nearest to other: various, multiple, different, smaller, others, fewer, those, vary,
# Nearest to american: america, canadian, australian, freight, indian, international, horror, fencing,
# Nearest to used: referred, designed, seen, available, found, written, applied, required,
# Nearest to zero: five, seven, two, three, four, mctell, appel, bc,
# Nearest to three: seven, five, six, eight, four, two, nine, centimeters,
# Nearest to been: become, occurred, evolved, gone, fallen, remained, existed, be,
# Average loss at step 82000: 2.916584
# Average loss at step 84000: 2.497711
# Average loss at step 86000: 2.626015
# Average loss at step 88000: 2.866619
# Average loss at step 90000: 2.849061
# Nearest to such: well, far, regarded, seen, result, follows, opposed, serve,
# Nearest to can: could, must, cannot, might, will, should, may, would,
# Nearest to at: near, during, haut, in, norepinephrine, towards, troubleshooting, since,
# Nearest to people: individuals, persons, students, writers, henriette, players, someone, jews,
# Nearest to united: simultaneously, uk, us, rivalry, dhekelia, member, medallist, goldeneye,
# Nearest to will: would, must, might, should, could, can, cannot, may,
# Nearest to a: another, the, any, every, an, emissary, camus, this,
# Nearest to that: which, where, when, fez, however, although, how, this,
# Nearest to their: his, its, her, your, our, whose, the, iggy,
# Nearest to during: until, throughout, in, despite, at, within, since, following,
# Nearest to other: various, smaller, others, different, multiple, these, regional, both,
# Nearest to american: canadian, australian, english, indian, irish, dutch, italian, british,
# Nearest to used: referred, seen, designed, needed, given, described, employed, intended,
# Nearest to zero: five, three, four, two, nine, million, seven, eight,
# Nearest to three: five, four, six, seven, eight, zero, nine, two,
# Nearest to been: become, gone, evolved, remained, existed, inexperience, occurred, fallen,
# Average loss at step 92000: 2.939247
# Average loss at step 94000: 2.917964
# Average loss at step 96000: 2.751532
# Average loss at step 98000: 2.888223
# Average loss at step 100000: 2.923599
# Nearest to such: well, follows, far, seen, serve, regarded, known, result,
# Nearest to can: must, may, cannot, could, should, might, will, would,
# Nearest to at: near, during, when, in, mozambican, towards, press, before,
# Nearest to people: individuals, players, students, persons, speakers, children, jews, someone,
# Nearest to united: simultaneously, us, dhekelia, outcrops, pillaging, anxious, uk, vendor,
# Nearest to will: would, must, should, might, can, could, may, shall,
# Nearest to a: the, another, every, any, emissary, an, each, his,
# Nearest to that: which, however, although, where, when, what, because, if,
# Nearest to their: its, his, her, your, our, my, whose, these,
# Nearest to during: in, throughout, until, after, before, since, at, despite,
# Nearest to other: multiple, various, others, different, fewer, these, those, developing,
# Nearest to american: australian, canadian, italian, british, americans, dutch, korean, indian,
# Nearest to used: referred, found, designed, seen, employed, known, intended, available,
# Nearest to zero: five, million, eight, seven, six, four, r, three,
# Nearest to three: four, five, six, seven, two, eight, zero, blount,
# Nearest to been: become, evolved, occurred, existed, gone, remained, fallen, inexperience,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# Some clusters are less obvious (like the standalone characters), but it clearly totaly works.
