# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'anarchism', 'originated', 'term', 'originated', 'of', 'term', 'as']

# %% [markdown]
# Note: the labels is a sliding random value of the word surrounding the words of the batch.

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.891223
# Nearest to many: impressionist, archelaus, provost, anthropos, fashioning, sure, oint, shriver,
# Nearest to been: kuznetsova, laid, edwin, kettle, smalltalk, gaze, satan, genotype,
# Nearest to can: cycladic, ostend, salvaged, guggenheim, decreased, toms, brevity, fragrant,
# Nearest to has: isometric, babe, kosi, ajanta, syllable, conformed, involvement, faltered,
# Nearest to about: regulars, wahhab, functioning, farad, nearly, montpellier, negroponte, regardless,
# Nearest to as: mount, nicolay, asuras, enamoured, cryogenics, paullus, knight, irresponsible,
# Nearest to some: liaisons, courting, chubut, ornamental, visualization, contradict, credited, advisor,
# Nearest to not: aristocrats, summit, surface, gbc, altogether, lingual, boleyn, bonded,
# Nearest to or: homeowners, catastrophism, boyz, lobster, laguna, publicised, chimp, famicom,
# Nearest to most: souk, directx, chronological, monkey, analyses, pouches, dodo, postmillennialism,
# Nearest to after: undefended, daiko, appetite, kv, fic, retired, landforms, valhalla,
# Nearest to seven: widens, livingston, optimally, cellos, fasttrack, phonological, valerius, deploy,
# Nearest to one: shout, purposeful, enjoyment, provocative, evidenced, spectacled, stung, menai,
# Nearest to into: woodlands, supportive, commencing, fem, faustina, blockbusters, facilitated, reggaeton,
# Nearest to they: obtains, nellie, fasciculata, receive, transoxiana, coupling, bite, manatees,
# Nearest to would: poole, unfortunately, goran, mohr, deontology, diamondbacks, heterosexual, volkswagen,
# Average loss at step 2000: 4.353631
# Average loss at step 4000: 3.857256
# Average loss at step 6000: 3.795298
# Average loss at step 8000: 3.687630
# Average loss at step 10000: 3.620116
# Nearest to many: some, sadism, these, ephemeral, sacrificial, other, chaired, signaling,
# Nearest to been: was, by, be, become, is, hydraulics, mya, correction,
# Nearest to can: will, would, tswana, dddddd, fragrant, intermediary, could, may,
# Nearest to has: was, had, is, have, peloponnesian, floppies, muppet, herrings,
# Nearest to about: regulars, wahhab, functioning, vacation, servo, sayed, bront, farad,
# Nearest to as: peppermint, influencing, asuras, intervening, symbolizing, mount, irresponsible, pietro,
# Nearest to some: courting, many, liaisons, these, immediately, any, various, several,
# Nearest to not: aristocrats, childe, it, altogether, also, will, they, boethius,
# Nearest to or: and, than, s, univ, synod, earnest, convenes, with,
# Nearest to most: outward, rehearsals, dictionary, gen, directx, ndnis, sculptured, chronological,
# Nearest to after: during, kv, before, blueprint, miki, audience, landforms, with,
# Nearest to seven: six, eight, three, nine, five, four, zero, two,
# Nearest to one: two, six, three, four, five, seven, eight, nine,
# Nearest to into: supportive, with, against, faustina, dot, blockbusters, dil, woodlands,
# Nearest to they: he, it, there, reproductions, not, who, rather, kibaki,
# Nearest to would: can, could, aviv, bioterrorism, diamondbacks, buckner, seth, ibiblio,
# Average loss at step 12000: 3.601115
# Average loss at step 14000: 3.572306
# Average loss at step 16000: 3.408440
# Average loss at step 18000: 3.456883
# Average loss at step 20000: 3.542748
# Nearest to many: some, several, these, other, all, the, most, ephemeral,
# Nearest to been: be, become, was, were, correction, had, smalltalk, hydraulics,
# Nearest to can: will, would, may, could, should, might, must, tswana,
# Nearest to has: had, was, have, is, floppies, peloponnesian, nia, immersion,
# Nearest to about: wahhab, bront, functioning, regulars, brundtland, vacation, sayed, over,
# Nearest to as: pidgin, screenplay, mount, rahul, gratitude, revivals, mischievous, crystallized,
# Nearest to some: many, several, these, any, all, various, most, the,
# Nearest to not: it, usually, they, aristocrats, also, to, still, eventually,
# Nearest to or: and, than, earnest, histology, locals, with, confucius, unanimously,
# Nearest to most: some, more, outward, many, widgets, rehearsals, insurrections, claire,
# Nearest to after: before, during, when, by, miki, with, pack, congregationalists,
# Nearest to seven: eight, five, four, nine, six, three, zero, two,
# Nearest to one: two, four, three, six, seven, eight, five, nine,
# Nearest to into: from, against, with, dot, in, supportive, hitters, dil,
# Nearest to they: he, there, it, she, who, we, not, you,
# Nearest to would: can, could, may, will, must, should, to, bioterrorism,
# Average loss at step 22000: 3.498453
# Average loss at step 24000: 3.490167
# Average loss at step 26000: 3.477641
# Average loss at step 28000: 3.482021
# Average loss at step 30000: 3.502450
# Nearest to many: some, several, these, most, all, other, sacrificial, such,
# Nearest to been: become, be, was, were, correction, stringing, adolf, hydraulics,
# Nearest to can: will, may, would, could, should, must, might, cannot,
# Nearest to has: had, have, was, is, hissarlik, immersion, since, zeppelin,
# Nearest to about: through, vacation, begins, sayed, wahhab, over, commutativity, bront,
# Nearest to as: mount, mischievous, intervening, debra, duffy, sutra, screenplay, when,
# Nearest to some: many, these, several, all, various, most, any, their,
# Nearest to not: they, it, still, usually, aristocrats, you, abstracted, often,
# Nearest to or: and, than, sprache, erasure, locals, wmo, owning, tait,
# Nearest to most: some, many, more, insurrections, outward, hiberno, rehearsals, kummer,
# Nearest to after: before, during, when, miki, lderlin, congregationalists, pack, scores,
# Nearest to seven: eight, nine, six, four, five, three, zero, one,
# Nearest to one: two, seven, four, eight, nine, five, six, three,
# Nearest to into: from, against, with, beelzebub, through, under, ldapv, magnificence,
# Nearest to they: there, he, we, it, you, not, who, she,
# Nearest to would: could, can, will, may, should, must, might, to,
# Average loss at step 32000: 3.503650
# Average loss at step 34000: 3.492953
# Average loss at step 36000: 3.455200
# Average loss at step 38000: 3.300127
# Average loss at step 40000: 3.425979
# Nearest to many: some, several, these, most, all, various, other, meiosis,
# Nearest to been: become, be, was, were, never, correction, already, mya,
# Nearest to can: could, will, may, would, should, must, might, cannot,
# Nearest to has: had, have, was, is, since, immersion, orchid, amazonian,
# Nearest to about: through, begins, over, sayed, wahhab, ldapv, vacation, insist,
# Nearest to as: pidgin, sutra, when, mount, revivals, irresponsible, criticised, gratitude,
# Nearest to some: many, several, these, various, any, their, most, meiosis,
# Nearest to not: usually, still, they, it, often, credited, abstracted, typically,
# Nearest to or: than, and, owning, sid, a, jomo, any, dialectics,
# Nearest to most: more, many, insurrections, several, some, outward, less, displacement,
# Nearest to after: before, during, when, while, without, pixel, congregationalists, miki,
# Nearest to seven: eight, five, nine, six, four, three, zero, two,
# Nearest to one: seven, six, eight, two, five, nine, three, four,
# Nearest to into: from, through, against, over, with, beelzebub, magnificence, up,
# Nearest to they: he, there, we, you, it, she, not, these,
# Nearest to would: could, can, will, may, should, might, must, did,
# Average loss at step 42000: 3.433914
# Average loss at step 44000: 3.448097
# Average loss at step 46000: 3.451398
# Average loss at step 48000: 3.354548
# Average loss at step 50000: 3.377226
# Nearest to many: some, several, these, various, other, most, meiosis, both,
# Nearest to been: become, be, was, had, received, already, were, naturalists,
# Nearest to can: could, may, will, would, must, should, might, cannot,
# Nearest to has: had, have, is, was, contains, since, nia, thrash,
# Nearest to about: through, over, norden, vacation, squealer, sayed, nye, pinker,
# Nearest to as: motorsport, intervening, confessional, irresponsible, organically, revivals, when, bouldering,
# Nearest to some: many, several, these, various, any, their, both, most,
# Nearest to not: usually, still, generally, they, aristocrats, credited, actually, casas,
# Nearest to or: and, than, noc, fry, qutb, histology, scarcity, owning,
# Nearest to most: more, many, less, insurrections, some, among, several, outward,
# Nearest to after: before, during, when, while, without, through, racer, miki,
# Nearest to seven: eight, nine, four, six, three, five, zero, two,
# Nearest to one: eight, six, two, seven, four, nine, five, three,
# Nearest to into: through, from, under, over, against, beelzebub, up, magnificence,
# Nearest to they: he, there, we, she, it, you, not, who,
# Nearest to would: could, will, may, can, should, might, must, did,
# Average loss at step 52000: 3.431370
# Average loss at step 54000: 3.425313
# Average loss at step 56000: 3.439031
# Average loss at step 58000: 3.396271
# Average loss at step 60000: 3.394738
# Nearest to many: some, several, various, these, most, other, meiosis, both,
# Nearest to been: become, be, were, was, had, remained, naturalists, bedrock,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to has: had, have, was, is, contains, having, trivalent, immersion,
# Nearest to about: over, sayed, vacation, pneumatic, closest, through, vivien, squealer,
# Nearest to as: irresponsible, motorsport, afflicted, holiness, vigilant, overlapped, maimed, resin,
# Nearest to some: many, several, these, various, any, all, most, this,
# Nearest to not: usually, still, they, actually, generally, nanking, now, we,
# Nearest to or: and, than, transformers, catenary, mayfair, salome, noc, existential,
# Nearest to most: more, many, some, less, insurrections, among, solitary, outward,
# Nearest to after: before, during, when, while, without, following, under, if,
# Nearest to seven: eight, six, five, nine, four, three, zero, one,
# Nearest to one: four, six, eight, two, nine, seven, five, three,
# Nearest to into: through, from, over, within, under, beelzebub, against, in,
# Nearest to they: we, there, you, he, she, i, it, not,
# Nearest to would: could, will, can, may, might, should, must, cannot,
# Average loss at step 62000: 3.239338
# Average loss at step 64000: 3.253037
# Average loss at step 66000: 3.398841
# Average loss at step 68000: 3.393826
# Average loss at step 70000: 3.359594
# Nearest to many: some, several, various, most, these, all, other, those,
# Nearest to been: become, be, was, were, remained, had, previously, received,
# Nearest to can: may, could, would, will, should, must, might, cannot,
# Nearest to has: had, have, is, was, contains, since, having, hopwood,
# Nearest to about: over, halen, sayed, vacation, pneumatic, closest, xaver, bront,
# Nearest to as: irresponsible, motorsport, like, using, is, parr, when, pvt,
# Nearest to some: many, several, various, these, all, any, their, most,
# Nearest to not: usually, still, generally, actually, nanking, now, chalker, anhalt,
# Nearest to or: and, any, than, reaffirm, bua, the, noc, histology,
# Nearest to most: more, many, less, some, insurrections, use, among, solitary,
# Nearest to after: before, during, when, while, without, if, through, despite,
# Nearest to seven: eight, six, nine, four, five, three, one, zero,
# Nearest to one: six, seven, four, two, eight, nine, five, three,
# Nearest to into: through, from, within, under, supportive, horizontal, cosby, merry,
# Nearest to they: we, there, he, you, it, she, who, eventually,
# Nearest to would: could, will, can, may, might, should, must, cannot,
# Average loss at step 72000: 3.375049
# Average loss at step 74000: 3.345708
# Average loss at step 76000: 3.314601
# Average loss at step 78000: 3.348768
# Average loss at step 80000: 3.376820
# Nearest to many: some, several, various, these, most, those, all, numerous,
# Nearest to been: become, be, remained, previously, was, already, were, had,
# Nearest to can: could, may, would, will, must, should, cannot, might,
# Nearest to has: had, have, is, was, since, contains, having, hopwood,
# Nearest to about: over, squealer, pneumatic, mor, sayed, norden, vacation, purview,
# Nearest to as: irresponsible, including, motorsport, treehouse, bouldering, enters, intervening, confessional,
# Nearest to some: many, several, various, these, most, any, meiosis, certain,
# Nearest to not: usually, still, actually, typically, generally, it, often, never,
# Nearest to or: and, than, sid, noc, insignia, but, westminster, while,
# Nearest to most: many, more, less, some, insurrections, among, very, manipulating,
# Nearest to after: before, during, when, while, without, despite, upon, in,
# Nearest to seven: six, eight, five, four, nine, three, zero, one,
# Nearest to one: six, seven, four, two, eight, three, five, nine,
# Nearest to into: through, from, within, over, across, dot, horizontal, around,
# Nearest to they: we, he, there, you, she, it, these, eventually,
# Nearest to would: could, will, can, may, should, might, must, cannot,
# Average loss at step 82000: 3.406076
# Average loss at step 84000: 3.405411
# Average loss at step 86000: 3.390689
# Average loss at step 88000: 3.354493
# Average loss at step 90000: 3.362148
# Nearest to many: several, some, various, these, all, most, numerous, few,
# Nearest to been: become, be, previously, was, already, remained, had, received,
# Nearest to can: may, could, should, will, would, must, might, cannot,
# Nearest to has: had, have, is, was, since, contains, having, contain,
# Nearest to about: over, pneumatic, sayed, xaver, vacation, regarding, vc, closest,
# Nearest to as: motorsport, including, irresponsible, confessional, elsevier, weizenbaum, afflicted, intervening,
# Nearest to some: many, several, any, these, meiosis, all, various, this,
# Nearest to not: actually, still, usually, abstracted, now, never, we, typically,
# Nearest to or: and, polka, histology, fuze, bua, uther, monaro, satavahana,
# Nearest to most: more, many, less, several, some, among, insurrections, all,
# Nearest to after: before, during, when, while, without, despite, under, through,
# Nearest to seven: eight, five, six, four, nine, three, zero, one,
# Nearest to one: seven, eight, two, four, six, five, nine, three,
# Nearest to into: from, through, over, under, within, around, between, cosby,
# Nearest to they: we, he, there, you, she, it, these, gz,
# Nearest to would: could, will, might, may, can, should, must, cannot,
# Average loss at step 92000: 3.394165
# Average loss at step 94000: 3.256066
# Average loss at step 96000: 3.358543
# Average loss at step 98000: 3.240726
# Average loss at step 100000: 3.355452
# Nearest to many: several, some, these, various, numerous, all, those, few,
# Nearest to been: become, be, previously, already, was, remained, received, had,
# Nearest to can: could, may, would, will, must, should, cannot, might,
# Nearest to has: had, have, is, was, since, contains, having, hopwood,
# Nearest to about: squealer, pneumatic, norden, closest, pinker, vc, companionship, over,
# Nearest to as: confessional, intervening, like, irresponsible, when, enamoured, elsevier, peppermint,
# Nearest to some: many, several, these, any, various, meiosis, all, certain,
# Nearest to not: never, actually, still, now, generally, chalker, they, almost,
# Nearest to or: and, than, owning, faire, distress, reestablishment, honorable, satavahana,
# Nearest to most: more, less, especially, several, many, particularly, use, among,
# Nearest to after: before, during, when, without, while, despite, under, although,
# Nearest to seven: eight, six, four, five, nine, three, zero, two,
# Nearest to one: two, six, four, seven, eight, five, nine, three,
# Nearest to into: through, from, within, cosby, over, around, magnificence, under,
# Nearest to they: we, he, there, you, she, it, i, gz,
# Nearest to would: could, will, can, might, may, should, must, cannot,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
