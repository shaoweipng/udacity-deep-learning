# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
print(data[:10])
print(count[:10])
print(dictionary.items()[:10])
print(reverse_dictionary.items()[:10])
# Out:
# [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]
# [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764), ('in', 372201), ('a', 325873), ('to', 316376), ('zero', 264975), ('nine', 250430)]
# [('fawn', 45848), ('homomorphism', 9648), ('nordisk', 39343), ('nunnery', 36075), ('chthonic', 33554), ('sowell', 40562), ('sonja', 38175), ('showa', 32906), ('woods', 6263), ('hsv', 44222)]
# [(0, 'UNK'), (1, 'the'), (2, 'of'), (3, 'and'), (4, 'one'), (5, 'in'), (6, 'a'), (7, 'to'), (8, 'zero'), (9, 'nine')]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=16, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(16)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term', 'of', 'of', 'abuse', 'abuse', 'first', 'first', 'used', 'used']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'of', 'a', 'abuse', 'term', 'first', 'of', 'abuse', 'used', 'against', 'first']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a', 'term', 'term', 'term', 'term', 'of', 'of', 'of', 'of']
#     labels: ['a', 'originated', 'term', 'anarchism', 'originated', 'term', 'as', 'of', 'abuse', 'of', 'as', 'a', 'first', 'abuse', 'a', 'term']

# %% [markdown]
# Note: the labels is a sliding random value of the word surrounding the words of the batch.

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.150133
# Nearest to called: atreus, sofa, matt, kyrgyz, microarchitecture, iy, decomposition, endgame,
# Nearest to into: hoaxes, gozo, histoire, pharaohs, bjp, melodrama, negatives, panentheism,
# Nearest to after: beatrice, amusement, mummies, grandmasters, elasticity, scrip, escher, gleaming,
# Nearest to than: mcs, venetian, redmond, slugging, felix, istrian, bhumi, chambers,
# Nearest to no: rann, mig, soften, giver, bosco, keeling, expired, handball,
# Nearest to more: circumcisions, sabrina, vicki, straus, reconquista, synopsis, justifiable, dahalo,
# Nearest to history: benno, lined, raft, lusitani, neighborhood, carly, scanned, ripping,
# Nearest to and: sicilian, esb, cancer, godfather, wallet, everest, msf, swastika,
# Nearest to UNK: lad, blackpool, uncharacteristically, pistol, intangible, westminster, editors, vehemently,
# Nearest to up: tractates, satavahana, visiting, translate, glastonbury, jost, rutland, autocorrelation,
# Nearest to b: countenance, managerial, uta, servile, decrypted, matriculation, restraints, melton,
# Nearest to be: drunkenness, staub, surnamed, propaganda, bagapsh, improvisations, traitor, themes,
# Nearest to american: shoal, gebhard, inventions, existence, dialogue, minimize, awakens, rabbits,
# Nearest to this: islets, nephites, substratum, pwnage, gpl, sheath, demeaning, xhosa,
# Nearest to have: beatboxing, moldovan, beak, segments, papua, officio, plankton, clinging,
# Nearest to use: tomasz, tennis, explainable, smilga, heliogabalus, fruity, bligh, fantasyland,
# Average loss at step 2000: 4.365011
# Average loss at step 4000: 3.858299
# Average loss at step 6000: 3.788945
# Average loss at step 8000: 3.687050
# Average loss at step 10000: 3.613512
# Nearest to called: sofa, used, matt, atreus, walkie, winning, zamora, decrease,
# Nearest to into: melodrama, ecclesiasticus, negatives, softer, obe, from, with, after,
# Nearest to after: grandmasters, thunder, sympathies, agate, escher, beatrice, spirit, into,
# Nearest to than: mcs, satirical, yana, chips, kyiv, niles, dominica, lenin,
# Nearest to no: rann, satrapy, honorary, peacock, expired, bosco, considerable, they,
# Nearest to more: edom, sabrina, reshaped, uptake, tailed, wayside, vicki, extermination,
# Nearest to history: scanned, raft, benno, mbta, carly, swede, detroit, battalion,
# Nearest to and: or, awarding, karo, who, d, margaret, in, jo,
# Nearest to UNK: mengistu, appellant, ceilings, posed, scipione, folks, ptc, six,
# Nearest to up: jost, glastonbury, facts, rutland, rif, fc, acquaintances, carver,
# Nearest to b: countenance, decrypted, bamboo, muentzer, servile, astrologer, guyanese, aida,
# Nearest to be: have, was, is, bartos, silent, been, fictionalised, materia,
# Nearest to american: concurrent, gebhard, shoal, canova, existence, ru, charlestown, and,
# Nearest to this: it, the, that, which, gpl, gast, christological, vardar,
# Nearest to have: had, be, has, are, passengers, were, outages, waved,
# Nearest to use: explainable, tomasz, anthropological, poole, robust, exalted, cilia, awarded,
# Average loss at step 12000: 3.601094
# Average loss at step 14000: 3.575147
# Average loss at step 16000: 3.408394
# Average loss at step 18000: 3.456236
# Average loss at step 20000: 3.541687
# Nearest to called: sofa, atreus, winning, falsetto, matt, used, walkie, zamora,
# Nearest to into: from, with, melodrama, after, ecclesiasticus, softer, negatives, by,
# Nearest to after: when, into, grandmasters, grids, yusupov, thunder, beatrice, studio,
# Nearest to than: or, chips, yana, kyiv, niles, dominica, mcs, analyse,
# Nearest to no: honorary, ethylene, located, sinope, rann, denominated, considerable, jester,
# Nearest to more: less, edom, most, sabrina, uptake, tailed, vicki, rather,
# Nearest to history: scanned, carly, detroit, benno, radek, mbta, alternate, zoran,
# Nearest to and: or, but, for, in, radars, nymphs, from, absentia,
# Nearest to UNK: manitoba, talked, services, cricketing, veto, physique, whitacre, neues,
# Nearest to up: him, carver, back, jost, adv, facts, improperly, glastonbury,
# Nearest to b: d, countenance, bioses, muentzer, guyanese, levi, niccol, anymore,
# Nearest to be: have, been, was, were, is, leclerc, by, become,
# Nearest to american: existence, verrocchio, austrian, gebhard, despotic, determinants, dios, canova,
# Nearest to this: it, which, the, gast, nephites, a, its, there,
# Nearest to have: had, has, be, were, are, waved, passengers, caicos,
# Nearest to use: explainable, robust, poole, anthropological, cilia, tomasz, awarded, adding,
# Average loss at step 22000: 3.500414
# Average loss at step 24000: 3.491163
# Average loss at step 26000: 3.478683
# Average loss at step 28000: 3.482480
# Average loss at step 30000: 3.503676
# Nearest to called: winning, used, considered, matt, zamora, decrease, falsetto, cosworth,
# Nearest to into: from, under, melodrama, with, over, yak, nick, softer,
# Nearest to after: when, before, during, from, grids, in, perry, into,
# Nearest to than: yana, chips, bikini, circuits, or, kyiv, hurriedly, dare,
# Nearest to no: a, ethylene, any, there, still, only, located, jester,
# Nearest to more: less, most, rather, edom, very, tailed, vicki, stable,
# Nearest to history: scanned, rollout, zoran, considering, benno, carly, radek, founder,
# Nearest to and: or, but, motors, racial, limewire, in, whose, american,
# Nearest to UNK: specialises, encountering, pips, intelligence, dispersed, cer, matsui, electrically,
# Nearest to up: him, them, back, carver, facts, adv, dumping, wedge,
# Nearest to b: d, countenance, guyanese, muentzer, anymore, shamans, levi, niccol,
# Nearest to be: been, have, was, were, is, being, become, rahilly,
# Nearest to american: british, australian, english, austrian, concurrent, lynda, implant, ru,
# Nearest to this: it, which, that, gast, some, there, the, preferred,
# Nearest to have: had, has, were, are, be, say, waved, outdoor,
# Nearest to use: robust, cilia, anthropological, explainable, poole, adding, awarded, cyclones,
# Average loss at step 32000: 3.499334
# Average loss at step 34000: 3.491767
# Average loss at step 36000: 3.459132
# Average loss at step 38000: 3.297478
# Average loss at step 40000: 3.425666
# Nearest to called: considered, winning, dismissed, falsetto, matt, like, used, cosworth,
# Nearest to into: from, through, melodrama, obe, swirling, over, between, lilongwe,
# Nearest to after: before, when, during, while, hipparcos, hoplites, without, navarro,
# Nearest to than: or, circuits, yana, kyiv, bikini, hurriedly, sane, dare,
# Nearest to no: any, jester, there, ethylene, denominated, little, probate, chmielnicki,
# Nearest to more: less, most, rather, very, edom, tailed, zu, greater,
# Nearest to history: scanned, list, historic, benno, alternate, psychedelic, works, slots,
# Nearest to and: or, but, recursion, silicates, gothic, venezia, s, m,
# Nearest to UNK: b, d, george, cricketing, obligatory, exodus, dolphins, annalen,
# Nearest to up: them, him, back, out, carver, improperly, madhuri, facts,
# Nearest to b: d, f, UNK, e, moneo, countenance, h, c,
# Nearest to be: have, been, being, is, require, was, were, rahilly,
# Nearest to american: australian, british, english, russian, implant, mexican, gebhard, arab,
# Nearest to this: which, it, the, that, there, some, jewels, hanged,
# Nearest to have: had, has, were, are, be, previously, already, waved,
# Nearest to use: robust, explainable, cilia, prisoner, cyclones, anthropological, poole, polskiej,
# Average loss at step 42000: 3.437606
# Average loss at step 44000: 3.457446
# Average loss at step 46000: 3.450741
# Average loss at step 48000: 3.361925
# Average loss at step 50000: 3.379501
# Nearest to called: used, expiring, dismissed, htp, flash, decrease, considered, matt,
# Nearest to into: from, through, obe, over, on, melodrama, by, under,
# Nearest to after: before, when, during, while, hoplites, studio, sputnik, yusupov,
# Nearest to than: or, bikini, but, circuits, yana, kyiv, hurriedly, theorizing,
# Nearest to no: any, jester, probate, denominated, a, chmielnicki, lamo, there,
# Nearest to more: less, most, very, rather, edom, quite, fairly, larger,
# Nearest to history: scanned, list, conveying, crown, hitomaro, considering, apl, psychedelic,
# Nearest to and: or, but, however, usury, ticketing, including, while, barcode,
# Nearest to UNK: overran, felons, piloted, edsger, optical, reformulated, inwo, cowdery,
# Nearest to up: them, him, back, out, madhuri, down, bloomberg, improperly,
# Nearest to b: d, f, c, laguardia, countenance, p, x, moneo,
# Nearest to be: been, have, was, being, become, is, were, are,
# Nearest to american: australian, english, british, existence, arab, implant, russian, dios,
# Nearest to this: which, it, some, abbeville, gast, symbolism, the, lauren,
# Nearest to have: had, has, were, are, be, already, tend, autoerotic,
# Nearest to use: robust, prisoner, anthropological, abuser, order, agricultural, nature, leisure,
# Average loss at step 52000: 3.433954
# Average loss at step 54000: 3.423764
# Average loss at step 56000: 3.437990
# Average loss at step 58000: 3.394296
# Average loss at step 60000: 3.393721
# Nearest to called: used, considered, known, named, expiring, assistive, austere, falsetto,
# Nearest to into: through, from, over, across, on, ecclesiasticus, in, obe,
# Nearest to after: before, during, when, without, while, following, from, despite,
# Nearest to than: or, but, bikini, chips, yana, kyiv, sane, metaphoric,
# Nearest to no: any, probate, jester, anticipate, denominated, little, shielding, chmielnicki,
# Nearest to more: less, rather, most, larger, very, edom, better, longer,
# Nearest to history: demographics, list, scanned, geography, sterne, crown, conveying, ifs,
# Nearest to and: or, but, although, including, sartre, ticketing, zeitung, in,
# Nearest to UNK: parks, vers, cricketing, uncompromising, baron, wildfire, nsync, talked,
# Nearest to up: them, out, him, back, down, madhuri, improperly, hesychast,
# Nearest to b: d, f, c, m, p, moneo, brisance, planina,
# Nearest to be: been, become, have, are, is, being, was, remain,
# Nearest to american: australian, british, arab, english, rockers, existence, shoal, despotic,
# Nearest to this: it, which, there, that, some, the, abbeville, symbolism,
# Nearest to have: has, had, are, were, be, tend, include, favourably,
# Nearest to use: robust, visigoths, cilia, know, abuser, most, leisure, sable,
# Average loss at step 62000: 3.236966
# Average loss at step 64000: 3.253417
# Average loss at step 66000: 3.404215
# Average loss at step 68000: 3.393625
# Average loss at step 70000: 3.362575
# Nearest to called: named, considered, used, expiring, palaestina, known, term, anand,
# Nearest to into: from, through, on, over, across, around, within, in,
# Nearest to after: before, during, when, without, while, at, despite, for,
# Nearest to than: or, while, bikini, chips, yana, but, hurriedly, celesta,
# Nearest to no: any, little, probate, lamo, jester, denominated, shielding, honored,
# Nearest to more: less, most, rather, very, fairly, quite, larger, sabrina,
# Nearest to history: list, scanned, demographics, constructions, conveying, period, england, considering,
# Nearest to and: or, while, like, but, zara, including, however, of,
# Nearest to UNK: constructs, swordsmanship, basie, baptiste, bearable, science, sowed, unnoticed,
# Nearest to up: them, out, down, back, him, off, improperly, madhuri,
# Nearest to b: d, f, moneo, x, urey, harker, planina, p,
# Nearest to be: been, being, become, have, is, were, are, was,
# Nearest to american: australian, british, english, knob, dios, existence, lynda, shoal,
# Nearest to this: which, it, the, that, there, some, locales, symbolism,
# Nearest to have: had, has, are, were, be, include, including, provide,
# Nearest to use: robust, share, most, prisoner, know, cilia, traitor, form,
# Average loss at step 72000: 3.372386
# Average loss at step 74000: 3.350016
# Average loss at step 76000: 3.310121
# Average loss at step 78000: 3.352299
# Average loss at step 80000: 3.375655
# Nearest to called: named, used, considered, known, palaestina, expiring, founded, austere,
# Nearest to into: through, from, across, within, over, on, around, obe,
# Nearest to after: before, during, when, without, while, despite, upon, from,
# Nearest to than: while, or, bikini, kyiv, analyse, conveniently, even, if,
# Nearest to no: little, any, probate, denominated, shielding, mechanized, lamo, strong,
# Nearest to more: less, most, very, rather, larger, fairly, quite, edom,
# Nearest to history: list, scanned, conveying, period, hitomaro, diffused, carly, knowledge,
# Nearest to and: or, but, while, including, by, hogshead, when, iom,
# Nearest to UNK: flashlight, chr, architect, frank, arnstadt, maclisp, et, joey,
# Nearest to up: out, down, them, back, him, off, madhuri, addressee,
# Nearest to b: d, f, moneo, c, harker, p, polisario, countenance,
# Nearest to be: been, being, have, become, get, bartos, is, refer,
# Nearest to american: british, australian, english, mexican, russian, international, european, french,
# Nearest to this: which, it, the, itself, each, jewels, osiris, some,
# Nearest to have: had, has, are, were, include, be, having, kundalini,
# Nearest to use: form, share, because, robust, way, fear, traitor, cilia,
# Average loss at step 82000: 3.407648
# Average loss at step 84000: 3.413616
# Average loss at step 86000: 3.388729
# Average loss at step 88000: 3.348391
# Average loss at step 90000: 3.369192
# Nearest to called: used, named, considered, expiring, known, founded, assistive, winning,
# Nearest to into: through, from, across, obe, over, within, around, on,
# Nearest to after: before, during, when, while, without, despite, formulaic, upon,
# Nearest to than: bikini, even, bio, kyiv, analyse, laura, and, much,
# Nearest to no: little, any, probate, expose, denominated, there, duplicates, only,
# Nearest to more: less, most, very, rather, longer, larger, quite, fairly,
# Nearest to history: list, scanned, period, diffused, study, unaltered, conveying, knowledge,
# Nearest to and: or, but, while, including, companionship, however, karo, yeni,
# Nearest to UNK: cth, morpork, onyx, anthony, untersuchungen, xliii, firenze, xs,
# Nearest to up: out, down, them, back, off, him, away, forth,
# Nearest to b: d, f, fantastic, moneo, highschool, anymore, surreal, koufax,
# Nearest to be: been, being, become, was, have, is, murdoc, refer,
# Nearest to american: british, australian, french, english, canadian, mexican, russian, arab,
# Nearest to this: it, which, the, some, he, another, gabor, abbeville,
# Nearest to have: had, has, were, are, be, having, appointments, tend,
# Nearest to use: share, because, most, support, validity, whomever, fear, form,
# Average loss at step 92000: 3.398877
# Average loss at step 94000: 3.250160
# Average loss at step 96000: 3.357832
# Average loss at step 98000: 3.240634
# Average loss at step 100000: 3.357811
# Nearest to called: named, used, expiring, austere, known, considered, surrey, palaestina,
# Nearest to into: through, within, from, across, obe, on, in, under,
# Nearest to after: before, during, when, without, despite, while, since, although,
# Nearest to than: or, bikini, chips, pledged, even, aer, mim, celesta,
# Nearest to no: any, little, denominated, probate, expose, lamo, positive, duplicates,
# Nearest to more: less, very, most, quite, larger, rather, longer, fairly,
# Nearest to history: list, diffused, demographics, confidant, geography, conveying, scanned, carly,
# Nearest to and: or, but, although, of, activating, like, however, while,
# Nearest to UNK: geospatial, strung, constructs, flashlight, gymnast, gell, cementing, rgb,
# Nearest to up: out, them, back, down, him, off, forth, pavia,
# Nearest to b: d, laguardia, anymore, niccol, alkyne, countenance, thoroughfares, surreal,
# Nearest to be: been, being, have, become, are, murdoc, refer, is,
# Nearest to american: british, australian, lynda, canadian, english, french, italian, austrian,
# Nearest to this: it, which, what, the, hanged, another, he, amathus,
# Nearest to have: had, has, were, tend, include, be, having, are,
# Nearest to use: validity, share, support, form, most, fear, because, bogies,

# %%
print(final_embeddings[0])
# Out:
# [  1.67166963e-01   6.22946536e-03   2.08268970e-01   7.89757371e-02
#    1.42688036e-01  -8.87722820e-02  -1.52835464e-02   4.27008979e-02
#   -7.43444562e-02  -3.63765843e-02  -9.96633917e-02   7.36598670e-03
#   -1.12164970e-02  -2.64963824e-02   4.87351567e-02   9.53175500e-02
#    1.33470297e-01   2.00576335e-01  -2.49266893e-01   2.09851265e-01
#    4.85547259e-03   1.15647897e-01   3.08167040e-02   9.11563188e-02
#    4.82263193e-02  -8.36281851e-02   3.84443589e-02   2.40292531e-02
#    4.38759625e-02   1.66460872e-01  -7.22727478e-02   3.74180935e-02
#    2.71297973e-02  -1.77290440e-02   1.20206838e-02  -1.76702917e-01
#    8.10265392e-02  -7.13970512e-02  -4.32182616e-03  -1.24967590e-01
#   -7.91490823e-03  -7.69039243e-02   1.06774718e-01  -1.04132444e-01
#   -1.63539089e-02   2.87926421e-02   1.40915900e-01   1.10896239e-02
#    1.90076977e-02   2.02606723e-01   1.27183393e-01  -7.25247413e-02
#    1.71562117e-02   3.28909382e-02  -3.95295732e-02   2.97603980e-02
#    2.57760510e-02  -8.07921439e-02  -5.55569269e-02  -8.74857605e-02
#   -1.25369243e-02  -1.20160781e-01  -1.56804528e-02  -7.58034885e-02
#   -1.04627632e-01  -2.69650687e-02   1.65569246e-01   9.35430899e-02
#    2.79354990e-01   9.71008278e-03  -6.58997446e-02  -1.10826172e-01
#   -6.45399764e-02   4.83546890e-02   6.50907680e-02  -6.10430427e-02
#   -1.21057108e-02   9.45882872e-02  -1.00479610e-01   2.43069977e-02
#   -3.43106091e-02  -1.93447843e-02   1.27596475e-04   6.33031800e-02
#   -2.56291255e-02   3.81477289e-02  -4.77004759e-02  -2.16691252e-02
#    5.62211871e-02  -5.45255691e-02   8.94759893e-02   5.72155565e-02
#   -2.84328163e-02  -1.81710228e-01  -1.06924593e-01   1.34015027e-02
#   -4.33298238e-02  -1.45854373e-02   1.20172523e-01   9.26489606e-02
#    2.14860821e-03  -3.23175751e-02   6.03336170e-02  -3.07369791e-03
#    7.99982692e-04   2.41117477e-02   2.71605831e-02  -1.09896600e-01
#    3.71016413e-02   2.35530622e-02   5.53305820e-02  -4.86004874e-02
#   -9.81624573e-02  -1.92203432e-01  -4.95622754e-02  -1.04815196e-02
#    1.13429330e-01  -1.38810799e-02   1.22294657e-01   1.13982623e-02
#    7.19769970e-02  -4.38515767e-02   4.03509922e-02   1.37905031e-02
#    6.41291887e-02  -7.45990723e-02  -8.30217451e-02   1.03964329e-01]

# %%
print(sum(final_embeddings[0])
# Out:
#   File "<ipython-input-13-9886ba08c488>", line 1
#     print(sum(final_embeddings[0])
#                                   ^
# SyntaxError: unexpected EOF while parsing

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
