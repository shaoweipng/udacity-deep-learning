# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Let's display the internal variables to better understand their structure:

# %%
print(data[:10])
print(count[:10])
print(dictionary.items()[:10])
print(reverse_dictionary.items()[:10])
# Out:
# [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]
# [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764), ('in', 372201), ('a', 325873), ('to', 316376), ('zero', 264975), ('nine', 250430)]
# [('fawn', 45848), ('homomorphism', 9648), ('nordisk', 39343), ('nunnery', 36075), ('chthonic', 33554), ('sowell', 40562), ('sonja', 38175), ('showa', 32906), ('woods', 6263), ('hsv', 44222)]
# [(0, 'UNK'), (1, 'the'), (2, 'of'), (3, 'and'), (4, 'one'), (5, 'in'), (6, 'a'), (7, 'to'), (8, 'zero'), (9, 'nine')]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:32]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=16, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(16)])
    
for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 1
    batch, labels = generate_batch(batch_size=16, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(16)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'UNK', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term', 'of', 'of', 'abuse', 'abuse', 'first', 'first', 'used', 'used']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'of', 'a', 'abuse', 'term', 'first', 'of', 'used', 'abuse', 'first', 'against']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a', 'term', 'term', 'term', 'term', 'of', 'of', 'of', 'of']
#     labels: ['anarchism', 'a', 'originated', 'term', 'term', 'originated', 'of', 'as', 'of', 'a', 'as', 'abuse', 'a', 'first', 'term', 'abuse']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['as', 'as', 'a', 'a', 'term', 'term', 'of', 'of', 'abuse', 'abuse', 'first', 'first', 'used', 'used', 'against', 'against']
#     labels: ['a', 'originated', 'term', 'as', 'of', 'a', 'term', 'abuse', 'of', 'first', 'abuse', 'used', 'first', 'against', 'used', 'early']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['a', 'a', 'a', 'a', 'term', 'term', 'term', 'term', 'of', 'of', 'of', 'of', 'abuse', 'abuse', 'abuse', 'abuse']
#     labels: ['of', 'originated', 'term', 'as', 'abuse', 'of', 'as', 'a', 'first', 'term', 'a', 'abuse', 'first', 'term', 'used', 'of']

# %% [markdown]
# Note: the labels is a sliding random value of the word surrounding the words of the batch.

# %% [markdown]
# It is not obvious with the output above, but all the data are based on index, and not the word directly.

# %%
print(batch)
print(labels)
# Out:
# [   6    6    6    6  195  195  195  195    2    2    2    2 3137 3137 3137
#  3137]
# [[   2]
#  [3084]
#  [ 195]
#  [  12]
#  [3137]
#  [   2]
#  [  12]
#  [   6]
#  [  46]
#  [ 195]
#  [   6]
#  [3137]
#  [  46]
#  [ 195]
#  [  59]
#  [   2]]

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From <ipython-input-9-01669d5c739a>:4: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 8.073391
# Nearest to b: macros, micas, toppling, spellings, interwar, magie, coin, wit,
# Nearest to who: shusui, sponsored, bogomils, retainers, hinder, lay, attribution, jubilees,
# Nearest to from: tumult, wingspan, haram, leipzig, solaris, acrobatics, allophone, boston,
# Nearest to an: prostitution, remarking, murron, enlil, rocked, drinks, hypotension, carburetor,
# Nearest to if: flop, btr, fossil, mactutor, ration, capitoline, watertown, retinue,
# Nearest to also: delegation, spo, coleridge, wisely, dw, introns, constable, tillman,
# Nearest to eight: circumcised, sprinkling, positron, multiplexing, cryogenic, nagoya, fetus, reverts,
# Nearest to american: ueshiba, bear, springboard, montego, contesting, annoy, hampton, satisfies,
# Nearest to many: ascertained, hormone, bissau, reviewers, benevento, ms, marshalling, laughter,
# Nearest to nine: lamprey, ruled, tagore, enlarge, constraint, aargau, coupe, tightened,
# Nearest to will: bandmates, presenter, vanities, cai, signage, jussive, crozier, barbosa,
# Nearest to two: lavin, arius, vab, garnering, boycotted, buckner, gym, angus,
# Nearest to in: mortals, haden, assemblers, marry, lycos, colosseum, theorizes, hartley,
# Nearest to with: quadriceps, spirals, cohesive, volcano, trolley, therefrom, issa, northrop,
# Nearest to would: awacs, participate, effected, articulation, mikvah, pinstripes, bandage, nevada,
# Nearest to five: imams, cavitation, cayuga, restlessness, astor, fennel, thunderstorm, escudo,
# Average loss at step 2000: 4.361439
# Average loss at step 4000: 3.866730
# Average loss at step 6000: 3.783569
# Average loss at step 8000: 3.691761
# Average loss at step 10000: 3.616421
# Nearest to b: micas, voor, interwar, weakens, ricardo, wit, dimaggio, d,
# Nearest to who: he, spiritualism, they, sponsored, dinosauria, stretch, there, aer,
# Nearest to from: tumult, in, by, with, into, at, browne, haram,
# Nearest to an: the, prostitution, probation, eccl, democratically, porpoises, wind, belize,
# Nearest to if: fossil, flop, capitoline, mastermind, miggins, bothwell, addictions, btr,
# Nearest to also: which, sometimes, not, delegation, there, often, it, considered,
# Nearest to eight: nine, six, five, seven, four, three, zero, two,
# Nearest to american: profiled, satisfies, cowan, arrowhead, consul, and, montego, ueshiba,
# Nearest to many: some, having, eug, perihelion, vertically, humble, badges, ascertained,
# Nearest to nine: eight, five, seven, six, zero, four, three, two,
# Nearest to will: may, presenter, would, fp, alboin, could, bandmates, warr,
# Nearest to two: five, three, four, eight, six, seven, nine, zero,
# Nearest to in: of, on, at, from, during, remo, for, phrase,
# Nearest to with: between, for, from, friulian, by, ropes, in, commotion,
# Nearest to would: can, could, may, must, pinstripes, might, will, suffix,
# Nearest to five: eight, six, four, seven, three, nine, two, zero,
# Average loss at step 12000: 3.608153
# Average loss at step 14000: 3.574663
# Average loss at step 16000: 3.412797
# Average loss at step 18000: 3.461764
# Average loss at step 20000: 3.540701
# Nearest to b: d, weakens, voor, investigators, aberrations, eleazar, ricardo, methodism,
# Nearest to who: he, they, which, she, dinosauria, sponsored, there, often,
# Nearest to from: into, in, at, and, tumult, through, with, unmolested,
# Nearest to an: probation, the, eccl, prostitution, moorehead, carts, mannerist, evading,
# Nearest to if: is, when, mastermind, finishing, fossil, differs, resumed, though,
# Nearest to also: which, often, sometimes, delegation, not, furious, quarry, who,
# Nearest to eight: nine, seven, six, four, five, three, two, zero,
# Nearest to american: satisfies, british, cowan, wilmot, canadian, montag, shriver, hain,
# Nearest to many: some, several, these, other, all, tra, unbeknownst, hotspots,
# Nearest to nine: eight, six, seven, four, five, three, zero, two,
# Nearest to will: would, may, could, can, to, but, fp, presenter,
# Nearest to two: three, four, five, six, one, eight, seven, nine,
# Nearest to in: at, from, on, for, during, and, remo, phrase,
# Nearest to with: between, for, friulian, by, while, through, in, ropes,
# Nearest to would: could, can, may, will, must, might, should, to,
# Nearest to five: four, six, three, eight, seven, two, zero, nine,
# Average loss at step 22000: 3.504506
# Average loss at step 24000: 3.491881
# Average loss at step 26000: 3.479738
# Average loss at step 28000: 3.478810
# Average loss at step 30000: 3.501162
# Nearest to b: d, weakens, voor, kilometre, filmmaking, investigators, hinted, answers,
# Nearest to who: he, they, she, dinosauria, spiritualism, often, which, sponsored,
# Nearest to from: into, in, through, by, like, between, after, with,
# Nearest to an: prostitution, probation, eccl, moorehead, recursion, murdoc, natalie, boosts,
# Nearest to if: when, though, is, finishing, but, since, so, resumed,
# Nearest to also: which, often, sometimes, delegation, now, consensus, furious, who,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to american: canadian, british, montag, satisfies, international, singapore, danish, profiled,
# Nearest to many: some, several, these, tra, all, most, various, benevolence,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to will: would, could, may, can, must, should, cannot, to,
# Nearest to two: three, four, five, one, six, seven, eight, zero,
# Nearest to in: at, during, and, of, from, with, on, by,
# Nearest to with: between, in, for, from, denunciations, friulian, spanning, into,
# Nearest to would: could, can, will, may, must, might, should, to,
# Nearest to five: four, eight, six, seven, three, nine, zero, two,
# Average loss at step 32000: 3.501039
# Average loss at step 34000: 3.495005
# Average loss at step 36000: 3.458702
# Average loss at step 38000: 3.297173
# Average loss at step 40000: 3.430421
# Nearest to b: d, weakens, c, johnson, methodism, hinted, UNK, filmmaking,
# Nearest to who: he, she, which, often, they, dinosauria, there, also,
# Nearest to from: into, through, in, like, after, of, cannes, during,
# Nearest to an: prostitution, the, probation, dunant, carts, murdoc, evading, boosts,
# Nearest to if: when, finishing, though, for, where, fossil, cannot, workday,
# Nearest to also: which, often, usually, sometimes, delegation, generally, now, there,
# Nearest to eight: nine, six, seven, four, five, three, zero, one,
# Nearest to american: british, canadian, wilmot, international, danish, standardized, english, satisfies,
# Nearest to many: some, several, these, various, all, those, both, tra,
# Nearest to nine: eight, seven, six, four, five, zero, three, one,
# Nearest to will: would, can, could, may, must, should, might, cannot,
# Nearest to two: four, three, five, seven, six, one, eight, zero,
# Nearest to in: during, of, within, at, since, and, for, from,
# Nearest to with: by, between, when, friulian, after, regimens, spanning, while,
# Nearest to would: could, will, can, may, must, might, should, shall,
# Nearest to five: seven, six, four, three, eight, zero, nine, two,
# Average loss at step 42000: 3.437823
# Average loss at step 44000: 3.452295
# Average loss at step 46000: 3.448011
# Average loss at step 48000: 3.357168
# Average loss at step 50000: 3.386632
# Nearest to b: d, weakens, c, reestablished, r, pearl, futurama, methodism,
# Nearest to who: he, which, she, often, they, there, oiled, usually,
# Nearest to from: into, through, unmolested, across, during, after, in, scouts,
# Nearest to an: prostitution, probation, moorehead, eccl, murdoc, dunant, nx, evading,
# Nearest to if: when, where, though, before, do, cannot, autonegotiation, culturally,
# Nearest to also: often, which, sometimes, usually, bitters, generally, brooklynites, now,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to american: canadian, standardized, association, satisfies, montag, international, wilmot, english,
# Nearest to many: some, several, these, various, both, those, such, tra,
# Nearest to nine: eight, seven, six, four, three, five, zero, two,
# Nearest to will: would, could, can, may, must, should, cannot, might,
# Nearest to two: three, one, six, five, four, eight, seven, zero,
# Nearest to in: on, of, during, within, since, remo, from, florian,
# Nearest to with: between, blinds, while, close, when, by, friulian, compatibles,
# Nearest to would: will, could, can, may, must, might, should, cannot,
# Nearest to five: four, six, eight, seven, three, zero, nine, two,
# Average loss at step 52000: 3.439919
# Average loss at step 54000: 3.429007
# Average loss at step 56000: 3.438753
# Average loss at step 58000: 3.398356
# Average loss at step 60000: 3.390899
# Nearest to b: d, c, r, m, chemically, p, futurama, mot,
# Nearest to who: she, he, which, responsibilities, now, dinosauria, they, usually,
# Nearest to from: through, into, in, across, including, during, between, within,
# Nearest to an: prostitution, probation, eccl, boosts, moorehead, evading, nx, murdoc,
# Nearest to if: when, though, where, before, because, since, cannot, although,
# Nearest to also: now, often, sometimes, usually, still, there, bitters, generally,
# Nearest to eight: nine, six, seven, four, five, three, zero, one,
# Nearest to american: canadian, german, international, association, standardized, british, montag, russian,
# Nearest to many: some, several, various, these, both, all, other, those,
# Nearest to nine: eight, six, seven, four, five, three, zero, one,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to two: three, four, five, six, one, eight, seven, nine,
# Nearest to in: within, during, from, on, throughout, of, near, with,
# Nearest to with: between, in, countable, by, when, columbo, friulian, into,
# Nearest to would: could, will, can, may, must, might, should, cannot,
# Nearest to five: four, six, three, seven, eight, nine, zero, two,
# Average loss at step 62000: 3.243677
# Average loss at step 64000: 3.259413
# Average loss at step 66000: 3.404212
# Average loss at step 68000: 3.396822
# Average loss at step 70000: 3.361243
# Nearest to b: d, p, r, f, chemically, weakens, n, futurama,
# Nearest to who: he, she, which, they, always, dinosauria, traditionally, oiled,
# Nearest to from: into, through, across, in, within, by, during, constructing,
# Nearest to an: prostitution, boosts, the, moorehead, recursion, eccl, infringing, probation,
# Nearest to if: when, though, where, before, however, closest, because, since,
# Nearest to also: now, often, still, which, sometimes, generally, usually, actually,
# Nearest to eight: nine, six, seven, four, five, zero, three, one,
# Nearest to american: canadian, british, association, standardized, montag, irish, german, savant,
# Nearest to many: some, several, various, these, all, numerous, most, those,
# Nearest to nine: eight, six, seven, five, four, three, zero, one,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to two: three, four, one, six, five, seven, eight, zero,
# Nearest to in: within, during, on, for, from, throughout, between, since,
# Nearest to with: between, countable, by, while, when, subnational, silica, genteel,
# Nearest to would: could, will, can, may, must, might, should, cannot,
# Nearest to five: six, four, eight, seven, three, zero, nine, two,
# Average loss at step 72000: 3.371316
# Average loss at step 74000: 3.347359
# Average loss at step 76000: 3.318959
# Average loss at step 78000: 3.353003
# Average loss at step 80000: 3.380329
# Nearest to b: d, c, m, r, p, weakens, mot, idol,
# Nearest to who: he, she, they, which, usually, always, contraindicated, often,
# Nearest to from: through, into, within, across, during, in, by, tumult,
# Nearest to an: prostitution, probation, larsen, natalie, remarking, murdoc, devolved, routing,
# Nearest to if: when, though, where, since, before, cannot, because, culturally,
# Nearest to also: often, sometimes, now, still, which, never, gradually, actually,
# Nearest to eight: nine, six, seven, five, four, three, zero, one,
# Nearest to american: british, canadian, international, association, standardized, irish, montag, german,
# Nearest to many: some, several, various, numerous, these, most, all, few,
# Nearest to nine: eight, seven, six, five, four, three, zero, pmid,
# Nearest to will: would, could, may, can, must, should, might, cannot,
# Nearest to two: three, six, four, one, five, seven, eight, isbn,
# Nearest to in: during, within, on, at, since, through, throughout, until,
# Nearest to with: between, friulian, when, among, stifle, bian, while, conjectures,
# Nearest to would: will, could, can, may, must, might, should, cannot,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Average loss at step 82000: 3.406566
# Average loss at step 84000: 3.411282
# Average loss at step 86000: 3.389762
# Average loss at step 88000: 3.353367
# Average loss at step 90000: 3.364086
# Nearest to b: d, c, m, r, p, weakens, chemically, futurama,
# Nearest to who: he, she, but, also, they, often, which, thereabouts,
# Nearest to from: through, into, across, during, while, within, under, in,
# Nearest to an: prostitution, devolved, boosts, eccl, inquiring, disallow, probation, natalie,
# Nearest to if: when, where, though, since, before, although, so, culturally,
# Nearest to also: still, often, now, which, actually, never, sometimes, bitters,
# Nearest to eight: seven, six, nine, five, four, three, zero, one,
# Nearest to american: british, canadian, association, irish, italian, standardized, german, french,
# Nearest to many: several, some, various, these, all, numerous, most, both,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to will: would, could, can, must, may, should, might, cannot,
# Nearest to two: three, four, five, six, one, eight, seven, zero,
# Nearest to in: within, during, between, from, of, under, near, fare,
# Nearest to with: between, by, instantly, in, chapterhouse, friulian, using, duomo,
# Nearest to would: could, will, can, may, must, might, should, did,
# Nearest to five: seven, eight, four, six, three, nine, zero, two,
# Average loss at step 92000: 3.395863
# Average loss at step 94000: 3.246554
# Average loss at step 96000: 3.360045
# Average loss at step 98000: 3.244434
# Average loss at step 100000: 3.360911
# Nearest to b: d, weakens, janet, fred, c, mot, mebyon, laureate,
# Nearest to who: he, which, she, thereabouts, also, traditionally, initially, contraindicated,
# Nearest to from: through, into, in, across, during, within, haram, by,
# Nearest to an: prostitution, boosts, moorehead, inquiring, devolved, eccl, natalie, mannerist,
# Nearest to if: when, though, where, before, since, although, because, autonegotiation,
# Nearest to also: now, still, actually, often, sometimes, never, generally, which,
# Nearest to eight: seven, nine, six, five, four, three, zero, two,
# Nearest to american: british, canadian, irish, association, italian, russian, french, hieroglyphs,
# Nearest to many: some, several, various, numerous, these, few, those, all,
# Nearest to nine: eight, seven, six, four, five, three, zero, pmid,
# Nearest to will: would, could, can, must, may, should, might, cannot,
# Nearest to two: four, three, six, five, one, seven, eight, zero,
# Nearest to in: during, within, on, from, at, near, throughout, of,
# Nearest to with: between, including, into, in, by, ojibwa, bian, when,
# Nearest to would: will, could, can, may, might, must, should, did,
# Nearest to five: seven, eight, four, six, zero, three, nine, two,

# %% [markdown]
# This is what an embedding looks like:

# %%
print(final_embeddings[0])
# Out:
# [-0.12122478 -0.01902349 -0.09313591  0.05868665 -0.03991868  0.09608125
#  -0.02266055 -0.22881182  0.10254864  0.0607186  -0.12019204 -0.00642453
#  -0.04478906  0.14849851  0.14005367  0.03822371 -0.06441485  0.03513648
#   0.11199319 -0.0562965  -0.05640128 -0.033358   -0.14845163  0.05513405
#   0.06771296  0.02941288  0.1635278   0.06984718  0.0270487   0.06034598
#  -0.07181006  0.08228688 -0.15997091  0.01637356 -0.00640768 -0.00671684
#  -0.04410979  0.01145381  0.077897    0.0351081   0.05614802 -0.04760002
#   0.06311899 -0.09789023 -0.07909353 -0.16877672  0.05244043  0.0784855
#   0.04188913 -0.06152521 -0.15277468  0.02312862  0.02853524  0.02897454
#   0.0442699   0.06490956  0.03878655 -0.07482991  0.01069755  0.08903505
#  -0.00069799 -0.16128017 -0.11984489 -0.20493312  0.21534477  0.02881374
#   0.15479858  0.12041439 -0.01248318 -0.08998153  0.0159614  -0.04440024
#  -0.19343558 -0.04015164  0.01428059 -0.05320336 -0.09698831  0.15762559
#   0.03562273 -0.0546818  -0.09100006  0.08357658 -0.17127326 -0.04963628
#   0.06649329  0.04166397 -0.13683365 -0.02786819  0.08811648 -0.07308046
#   0.03172879 -0.00453282 -0.0290311  -0.01573947  0.01605109  0.00393256
#  -0.04872711  0.08316744 -0.07637297  0.02232242  0.06282664 -0.02034972
#  -0.06557748 -0.00967228 -0.08175975  0.02856425  0.07728812 -0.2430058
#   0.03488373  0.07727977  0.07893546  0.15355393 -0.07265115 -0.03044241
#   0.02295625  0.06505867  0.09288152 -0.09493876 -0.15444711  0.02115123
#   0.15560351 -0.0016126   0.02268638  0.01625068 -0.06388704 -0.09512352
#   0.08450346 -0.04170411]

# %% [markdown]
# All the values are abstract, there is practical meaning of the them. Moreover, the final embeddings are normalized as you can see here:

# %%
print(np.sum(np.square(final_embeddings[0])))
# Out:
# 1.0

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# For the continuous bag of words, the train inputs are slightly different from the skip-gram:

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    # just for testing
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    # iterate to the next buffer
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
  data_index = 0
  batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
  print('\nwith bag_window = %d:' % (bag_window))  
  print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %% [markdown]
# Note the instruction change on the loss function, with ``reduce_sum`` to sum the word vectors in the context:

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
###skip_window = 1 # How many words to consider left and right.
###num_skips = 2 # How many times to reuse an input to generate a label.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases= softmax_biases, inputs=tf.reduce_sum(embeds, 1),
                               labels = train_labels, num_sampled= num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From <ipython-input-16-7cc72aa7b9c1>:4: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 7.803591
# Nearest to one: malpighi, constructible, tempted, morris, em, brien, rebbe, mitchell,
# Nearest to two: people, berman, churches, creators, pharmacies, actual, pudding, gamete,
# Nearest to also: claws, stir, insignificance, miggins, krakatau, adsorption, hampshire, mcveigh,
# Nearest to states: racial, paige, parkinson, barks, analyse, copa, presided, metamorphoses,
# Nearest to war: honeybee, rudolph, bean, abdurrahman, shortened, reggae, judas, eretz,
# Nearest to be: mosquitia, reflectivity, thatcher, suda, greet, wiesenthal, banach, domesticated,
# Nearest to called: coquitlam, vie, edmunds, erne, consists, beak, fissile, preyed,
# Nearest to system: convicts, pseudopods, collisions, eligible, scaled, init, parker, tiresias,
# Nearest to for: monos, oligocene, janeiro, tfl, carbine, crawford, franchisee, sprites,
# Nearest to all: jumpers, kruger, anabaptist, upsets, widgets, uses, cactus, pond,
# Nearest to who: dignified, amazon, aten, subdivided, colonized, condoms, sachet, disproved,
# Nearest to which: ably, bolshevism, stringed, denison, lebanon, dare, emerson, sammon,
# Nearest to four: walrus, ils, predecessors, lutz, darmstadt, stocked, waterman, mcc,
# Nearest to after: kelp, antenna, another, encke, perthshire, weymouth, estimates, chiles,
# Nearest to of: pointwise, damien, attorneys, delusions, might, ripple, asu, goldeneye,
# Nearest to such: dinner, asia, carbohydrates, rulings, handshake, altars, ubu, dharmas,
# Average loss at step 2000: 4.600984
# Average loss at step 4000: 3.937777
# Average loss at step 6000: 3.718069
# Average loss at step 8000: 3.530216
# Average loss at step 10000: 3.468885
# Nearest to one: weu, two, samba, henotheism, zero, killers, squarely, geoff,
# Nearest to two: zero, four, five, three, nine, six, one, eight,
# Nearest to also: which, selectively, not, optimally, plugging, frequencies, infocom, wordplay,
# Nearest to states: kingdom, nations, responsa, poorer, fostered, shines, racial, oven,
# Nearest to war: downey, marriage, honeybee, bean, blockers, rebuild, socks, faisal,
# Nearest to be: have, refer, hubs, is, nave, make, become, sported,
# Nearest to called: wombat, flemish, miso, known, eyre, jamaica, yttrium, suitor,
# Nearest to system: vh, adamantium, tombs, rights, collisions, pursuant, oi, kristofferson,
# Nearest to for: polygamy, cathal, delivers, of, from, animosity, shawn, towards,
# Nearest to all: many, antioxidant, goaltender, impaled, iphigenia, some, these, those,
# Nearest to who: he, which, underworld, swapped, cotten, that, lama, she,
# Nearest to which: that, who, this, also, what, spitfire, optimally, gary,
# Nearest to four: zero, eight, five, three, six, nine, two, seven,
# Nearest to after: before, delano, purported, hardliners, instructed, solicit, equ, roque,
# Nearest to of: in, batgirl, for, jaw, winograd, philemon, claes, spoons,
# Nearest to such: well, known, far, clem, shrew, sued, tensile, secede,
# Average loss at step 12000: 3.485062
# Average loss at step 14000: 3.430321
# Average loss at step 16000: 3.437406
# Average loss at step 18000: 3.399183
# Average loss at step 20000: 3.226127
# Nearest to one: kildall, dmitri, stoke, two, kiki, soci, stemmed, byte,
# Nearest to two: three, five, four, zero, reformed, one, legislator, demonstrators,
# Nearest to also: below, still, often, usually, mason, hindustan, widely, kerr,
# Nearest to states: kingdom, nations, leviathan, oven, responsa, poorer, hine, transposition,
# Nearest to war: honeybee, moshoeshoe, marriage, branch, wars, socks, card, essequibo,
# Nearest to be: being, refer, become, have, majlis, czarist, hubs, produce,
# Nearest to called: named, made, used, known, distinctions, butt, wombat, lettering,
# Nearest to system: systems, costumes, musa, morphology, lesbians, edmunds, nada, aorta,
# Nearest to for: after, deontological, violating, towards, delano, icann, shawn, nevado,
# Nearest to all: solicitor, those, many, these, various, impaled, fascinated, each,
# Nearest to who: he, which, cantonal, omniscience, that, she, fortunate, hauk,
# Nearest to which: that, this, what, it, who, where, infringed, often,
# Nearest to four: six, three, five, eight, seven, two, zero, dodge,
# Nearest to after: before, hypertension, during, following, tristar, for, through, solicit,
# Nearest to of: claes, jaeger, lengthwise, midday, nashwaak, jaw, like, frontispiece,
# Nearest to such: well, regarded, described, blockbusters, known, far, shrew, ahaziah,
# Average loss at step 22000: 3.366208
# Average loss at step 24000: 3.288278
# Average loss at step 26000: 3.256263
# Average loss at step 28000: 3.286492
# Average loss at step 30000: 3.229868
# Nearest to one: seven, two, nils, gates, brett, psc, mercosur, couture,
# Nearest to two: three, four, six, five, one, imposter, eight, midi,
# Nearest to also: below, now, often, still, usually, entscheidungsproblem, parlance, cheetah,
# Nearest to states: kingdom, nations, oven, srinagar, infections, bogies, inconspicuous, wow,
# Nearest to war: essequibo, branch, barberini, honeybee, marriage, moshoeshoe, stringing, rationalize,
# Nearest to be: become, refer, lead, being, perform, relating, produce, occur,
# Nearest to called: named, used, known, see, termed, considered, jed, principalities,
# Nearest to system: systems, hermitian, musa, melos, laine, millennium, helix, hmmwv,
# Nearest to for: after, of, despite, deontological, following, through, delano, boundless,
# Nearest to all: many, some, those, various, both, several, these, certain,
# Nearest to who: she, editorial, that, which, he, townships, steadily, rai,
# Nearest to which: that, what, this, where, typically, conjugal, worries, who,
# Nearest to four: five, six, three, seven, eight, two, zero, nine,
# Nearest to after: before, during, through, since, for, until, following, while,
# Nearest to of: in, including, claes, for, jaw, following, since, flushed,
# Nearest to such: well, described, regarded, known, soon, far, result, slavonia,
# Average loss at step 32000: 3.015939
# Average loss at step 34000: 3.204718
# Average loss at step 36000: 3.210352
# Average loss at step 38000: 3.162325
# Average loss at step 40000: 3.163458
# Nearest to one: three, six, two, nw, scarecrow, four, ellipsis, microscope,
# Nearest to two: three, four, zero, six, one, five, blog, eight,
# Nearest to also: still, now, below, often, sometimes, kerr, usually, generally,
# Nearest to states: kingdom, nations, cooperation, bogies, freeway, state, transposition, monk,
# Nearest to war: wars, honeybee, oldest, shortened, marriage, lectured, essequibo, moshoeshoe,
# Nearest to be: produce, refer, lead, being, become, occur, represent, remain,
# Nearest to called: named, considered, known, used, termed, created, produced, included,
# Nearest to system: systems, process, sunglasses, hermitian, laine, musa, equipment, ellipsis,
# Nearest to for: during, without, towards, although, tei, after, of, mobygames,
# Nearest to all: every, many, any, certain, auditorium, some, several, variations,
# Nearest to who: she, ackroyd, cleaned, enthroned, he, editorial, voyaging, whose,
# Nearest to which: that, usually, this, where, what, these, indistinguishable, generally,
# Nearest to four: five, six, eight, seven, three, zero, two, nine,
# Nearest to after: before, during, since, despite, delano, when, while, following,
# Nearest to of: frontispiece, during, condon, marrow, jaw, claes, for, without,
# Nearest to such: well, far, opposed, regarded, result, described, seen, just,
# Average loss at step 42000: 3.208737
# Average loss at step 44000: 3.138104
# Average loss at step 46000: 3.140606
# Average loss at step 48000: 3.060631
# Average loss at step 50000: 3.057962
# Nearest to one: motif, sieve, two, sportsmanship, laconic, codata, infuriated, nonprofit,
# Nearest to two: five, three, four, six, eight, one, zero, hosni,
# Nearest to also: below, still, now, disambiguation, actually, usually, sometimes, often,
# Nearest to states: kingdom, nations, countries, bogies, accomplish, cooperation, parts, decorating,
# Nearest to war: wars, oldest, essequibo, branch, monks, camille, enters, nis,
# Nearest to be: refer, lead, produce, remain, being, become, run, contain,
# Nearest to called: named, used, known, considered, termed, referred, jia, created,
# Nearest to system: systems, nikolaevich, area, admissions, helix, caption, banda, costumes,
# Nearest to for: including, after, tradesmen, although, shawn, adar, midshipman, humphreys,
# Nearest to all: many, some, several, these, various, every, any, antioxidant,
# Nearest to who: she, he, uda, which, cantonal, genoese, births, jackson,
# Nearest to which: that, this, what, these, where, actually, whose, usually,
# Nearest to four: three, six, seven, five, eight, two, xin, perutz,
# Nearest to after: before, during, until, since, afterwards, for, later, delano,
# Nearest to of: including, during, for, batgirl, throughout, claes, beyond, ktav,
# Nearest to such: well, follows, seen, far, regarded, known, described, result,
# Average loss at step 52000: 3.092438
# Average loss at step 54000: 3.090590
# Average loss at step 56000: 2.923548
# Average loss at step 58000: 3.019640
# Average loss at step 60000: 3.055370
# Nearest to one: two, sonorants, bleak, ulvaeus, codata, mercosur, patricio, five,
# Nearest to two: five, three, four, six, eight, zero, bc, one,
# Nearest to also: below, now, still, never, actually, disambiguation, usually, which,
# Nearest to states: kingdom, nations, cooperation, countries, bogies, parts, stuarts, parallelism,
# Nearest to war: wars, essequibo, massacred, oldest, monks, honeybee, dich, gunship,
# Nearest to be: remain, refer, lead, produce, cause, being, get, have,
# Nearest to called: named, considered, criticized, used, termed, held, rendered, designated,
# Nearest to system: systems, process, technique, jahn, chico, area, region, unit,
# Nearest to for: after, delano, towards, mendel, boundless, icann, cliques, during,
# Nearest to all: many, some, these, various, several, certain, those, every,
# Nearest to who: she, he, whom, that, hildesheim, cantonal, istanbul, devito,
# Nearest to which: that, where, this, what, actually, also, currently, however,
# Nearest to four: five, three, six, eight, seven, zero, two, nine,
# Nearest to after: before, during, following, despite, equ, until, since, through,
# Nearest to of: sucker, catchphrase, marrow, mauss, genomics, claes, spoons, whereby,
# Nearest to such: well, follows, regarded, opposed, described, result, known, whole,
# Average loss at step 62000: 3.018141
# Average loss at step 64000: 2.926728
# Average loss at step 66000: 2.926680
# Average loss at step 68000: 2.967357
# Average loss at step 70000: 3.004065
# Nearest to one: two, laconic, kildall, kenning, codata, rembrandt, moles, props,
# Nearest to two: three, five, four, zero, six, seven, raucous, one,
# Nearest to also: now, below, currently, usually, still, already, sometimes, disambiguation,
# Nearest to states: kingdom, nations, decorating, stuarts, cooperation, provinces, felipe, bogies,
# Nearest to war: wars, dich, essequibo, massacred, monks, gunship, oldest, enters,
# Nearest to be: refer, lead, remain, being, become, cause, produce, move,
# Nearest to called: named, considered, termed, held, criticized, placed, awarded, known,
# Nearest to system: systems, process, design, ov, confronts, cpu, myriad, beverage,
# Nearest to for: icann, after, towards, of, cliques, dakuten, before, shawn,
# Nearest to all: many, some, several, various, certain, every, thirteen, both,
# Nearest to who: whose, he, she, whom, padua, carbines, actually, spinoff,
# Nearest to which: that, actually, where, this, what, these, but, also,
# Nearest to four: five, six, seven, three, two, zero, kenjutsu, eight,
# Nearest to after: before, during, following, until, through, despite, when, equ,
# Nearest to of: including, for, utilizing, while, frontispiece, nashwaak, spoons, claes,
# Nearest to such: well, follows, opposed, described, known, regarded, result, seen,
# Average loss at step 72000: 2.938582
# Average loss at step 74000: 2.866645
# Average loss at step 76000: 2.990015
# Average loss at step 78000: 2.996968
# Average loss at step 80000: 2.843740
# Nearest to one: two, polarized, ulvaeus, kenning, geocities, lfar, dipole, chanel,
# Nearest to two: three, four, one, six, seven, zero, five, eight,
# Nearest to also: now, below, currently, disambiguation, still, often, hindustan, already,
# Nearest to states: kingdom, nations, provinces, seasons, countries, bogies, parts, ham,
# Nearest to war: wars, monks, massacred, mano, shortened, politics, hamza, islanders,
# Nearest to be: refer, remain, become, produce, lead, occur, being, represent,
# Nearest to called: named, considered, termed, used, criticized, added, known, released,
# Nearest to system: systems, branch, process, boundary, hmmwv, myriad, preparatory, laine,
# Nearest to for: icann, towards, boundless, deontological, violating, cliques, cathal, napkin,
# Nearest to all: many, every, any, various, thirteen, several, some, most,
# Nearest to who: whom, which, actually, uda, by, cornered, vengeful, parrish,
# Nearest to which: that, this, actually, what, where, who, whom, widgery,
# Nearest to four: seven, six, five, three, eight, zero, nine, two,
# Nearest to after: before, following, during, afterwards, despite, until, since, equ,
# Nearest to of: behind, spoons, tiered, including, while, claes, condon, following,
# Nearest to such: well, follows, opposed, seen, described, referred, result, just,
# Average loss at step 82000: 2.936525
# Average loss at step 84000: 2.896184
# Average loss at step 86000: 2.921521
# Average loss at step 88000: 2.951413
# Average loss at step 90000: 2.834126
# Nearest to one: two, seven, codata, four, petrels, three, polarized, motif,
# Nearest to two: three, four, six, five, zero, one, both, nine,
# Nearest to also: still, below, which, currently, disambiguation, actually, often, sometimes,
# Nearest to states: kingdom, nations, provinces, ham, countries, claims, bogies, concluded,
# Nearest to war: wars, monks, massacred, islanders, gangsters, gahan, honeybee, smithers,
# Nearest to be: refer, lead, represent, being, occur, produce, remain, move,
# Nearest to called: named, termed, used, considered, known, awarded, released, criticized,
# Nearest to system: systems, network, process, branch, costumes, constitution, authority, program,
# Nearest to for: carolinas, icann, cliques, boundless, rel, agonists, kut, adjoined,
# Nearest to all: many, some, various, always, certain, waterford, every, most,
# Nearest to who: whom, actually, which, cornered, parrish, that, typically, melilla,
# Nearest to which: that, where, actually, this, what, also, whom, whatever,
# Nearest to four: six, three, seven, five, eight, two, zero, langle,
# Nearest to after: before, during, until, despite, within, following, when, beyond,
# Nearest to of: following, claes, in, containing, jaeger, including, include, morava,
# Nearest to such: well, follows, seen, described, result, opposed, regarded, classified,
# Average loss at step 92000: 2.904950
# Average loss at step 94000: 2.888823
# Average loss at step 96000: 2.708159
# Average loss at step 98000: 2.453868
# Average loss at step 100000: 2.710119
# Nearest to one: geocities, polka, lfar, platypus, nonprofit, internationale, aces, frankenchrist,
# Nearest to two: three, four, five, seven, zero, six, eight, pessimism,
# Nearest to also: often, actually, still, currently, already, which, below, disambiguation,
# Nearest to states: kingdom, nations, countries, state, things, provinces, psychic, transposition,
# Nearest to war: wars, monks, essequibo, gahan, dubs, islanders, massacred, smithers,
# Nearest to be: remain, being, refer, lead, exist, produce, occur, become,
# Nearest to called: named, considered, termed, used, referred, released, asked, added,
# Nearest to system: systems, program, process, branch, network, unit, edmunds, method,
# Nearest to for: cliques, without, alexey, midshipman, after, towards, carolinas, despite,
# Nearest to all: both, various, some, certain, many, every, always, waterford,
# Nearest to who: which, whom, actually, uda, vengeful, cornered, whose, and,
# Nearest to which: that, where, also, this, who, actually, what, typically,
# Nearest to four: three, seven, five, six, eight, two, zero, nine,
# Nearest to after: before, following, afterwards, despite, prior, without, within, hypertension,
# Nearest to of: claes, in, marrow, spoons, frontispiece, represents, through, flushed,
# Nearest to such: well, follows, seen, described, opposed, result, regarded, known,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# Some clusters are less obvious (like the standalone characters), but it clearly totaly works!

# %% [markdown]
# How does your CBOW model perform compared to the given Word2Vec model? (to be answered)

# %% [markdown]
# At the first sight, they look similar. The CBOW is a more compact.
